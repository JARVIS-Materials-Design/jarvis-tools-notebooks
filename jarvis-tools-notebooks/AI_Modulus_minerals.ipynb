# %% [markdown]
# <a href="https://colab.research.google.com/github/knc6/jarvis-tools-notebooks/blob/master/jarvis-tools-notebooks/AI_Modulus_minerals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/conda-forge/miniforge/releases/download/23.11.0-0/Mambaforge-23.11.0-0-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:17
# 🔁 Restarting kernel...

# %%
import condacolab
condacolab.check()
# Out:
# ✨🍰✨ Everything looks OK!

# %%
# %%time
# !conda install alignn pytorch torchvision torchaudio pytorch-cuda -c pytorch -c nvidia -y --quiet
# Out:
# Channels:
#  - pytorch
#  - nvidia
#  - conda-forge
# Platform: linux-64
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - alignn
#     - pytorch
#     - pytorch-cuda
#     - torchaudio
#     - torchvision
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _openmp_mutex-4.5          |       2_kmp_llvm           6 KB  conda-forge
#     absl-py-2.1.0              |     pyhd8ed1ab_0         105 KB  conda-forge
#     aiohttp-3.9.5              |  py310h2372a71_0         682 KB  conda-forge
#     aiosignal-1.3.1            |     pyhd8ed1ab_0          12 KB  conda-forge
#     alignn-2024.4.10           |     pyhd8ed1ab_0          71 KB  conda-forge
#     annotated-types-0.7.0      |     pyhd8ed1ab_0          18 KB  conda-forge
# ...

# %%
pos=""" talc-monoclinic-Mainprice
1.0
        5.3948421478         0.0000000000         0.0000000000
        0.0000000000         9.3419561386         0.0000000000
       -3.9760622283         0.0000000000        20.6355270462
    H   Mg    O   Si
    8   12   48   16
Direct
     0.239750996         0.832424998         0.098095998
     0.760249019         0.167575002         0.901903987
     0.760249019         0.832424998         0.401903003
     0.239750996         0.167575002         0.598097026
     0.739750981         0.332424998         0.098095998
     0.260248989         0.667575002         0.901903987
     0.260248989         0.332424998         0.401903003
     0.739750981         0.667575002         0.598097026
     0.000000000         0.000000000         0.000000000
     0.000000000         0.000000000         0.500000000
     0.500000000         0.500000000         0.000000000
     0.500000000         0.500000000         0.500000000
     0.007662000         0.335884988         0.000011000
     0.992338002         0.664115012         0.999988973
     0.992338002         0.335884988         0.499989003
     0.007662000         0.664115012         0.500011027
     0.507661998         0.835884988         0.000011000
     0.492338002         0.164114997         0.999988973
     0.492338002         0.835884988         0.499989003
     0.507661998         0.164114997         0.500011027
     0.206928000         0.500962019         0.053428002
     0.793071985         0.499038011         0.946572006
     0.793071985         0.500962019         0.446572006
     0.206928000         0.499038011         0.553427994
     0.706928015         0.000962000         0.053428002
     0.293071985         0.999037981         0.946572006
     0.293071985         0.000962000         0.446572006
     0.706928015         0.999037981         0.553427994
     0.204217002         0.166626006         0.053424999
     0.795782983         0.833374023         0.946574986
     0.795782983         0.166626006         0.446574986
     0.204217002         0.833374023         0.553425014
     0.704217017         0.666625977         0.053424999
     0.295783013         0.333373994         0.946574986
     0.295783013         0.666625977         0.446574986
     0.704217017         0.333373994         0.553425014
     0.205412999         0.832026005         0.050824001
     0.794587016         0.167973995         0.949176013
     0.794587016         0.832026005         0.449176997
     0.205412999         0.167973995         0.550822973
     0.705412984         0.332026005         0.050824001
     0.294586986         0.667973995         0.949176013
     0.294586986         0.332026005         0.449176997
     0.705412984         0.667973995         0.550822973
     0.038676001         0.079025000         0.159734994
     0.961323977         0.920975029         0.840264976
     0.961323977         0.079025000         0.340265006
     0.038676001         0.920974016         0.659735024
     0.538676023         0.579024971         0.159734994
     0.461324006         0.420975000         0.840264976
     0.461324006         0.579025984         0.340265006
     0.538676023         0.420975000         0.659735024
     0.538533986         0.088661999         0.159385994
     0.461466014         0.911337972         0.840614021
     0.461466014         0.088661999         0.340613991
     0.538533986         0.911337972         0.659385979
     0.038534001         0.588662028         0.159385994
     0.961466014         0.411338001         0.840614021
     0.961466014         0.588662028         0.340613991
     0.038534001         0.411338001         0.659385979
     0.274084985         0.333781987         0.159334004
     0.725915015         0.666217983         0.840665996
     0.725915015         0.333781987         0.340665996
     0.274084985         0.666217983         0.659334004
     0.774084985         0.833782017         0.159334004
     0.225915000         0.166217998         0.840665996
     0.225915000         0.833782017         0.340665996
     0.774084985         0.166217998         0.659334004
     0.765061975         0.000564000         0.133754998
     0.234937996         0.999436021         0.866244972
     0.234937996         0.000564000         0.366245002
     0.765061975         0.999436021         0.633755028
     0.265062004         0.500563979         0.133754998
     0.734938025         0.499435991         0.866244972
     0.734938025         0.500563979         0.366245002
     0.265062004         0.499435991         0.633755028
     0.264474005         0.166998997         0.133753002
     0.735526025         0.833001018         0.866246998
     0.735526025         0.166998997         0.366246998
     0.264474005         0.833001018         0.633753002
     0.764473975         0.666998982         0.133753002
     0.235525995         0.333000988         0.866246998
     0.235525995         0.666998982         0.366246998
     0.764473975         0.333000988         0.633753002
"""
with open('Test_POSCAR.vasp', 'w') as f:
    f.write(pos)
from jarvis.io.vasp.inputs import Poscar
atoms = Poscar.from_string(pos)
print(atoms)
# Out:
#  talc-monoclinic-Mainprice
# 1.0
# 5.3948421478 0.0 0.0
# 0.0 9.3419561386 0.0
# -3.9760622283 0.0 20.6355270462
# H Mg O Si
# 8 12 48 16
# direct
# 0.239750996 0.832424998 0.098095998
# 0.760249019 0.167575002 0.901903987
# 0.760249019 0.832424998 0.401903003
# 0.239750996 0.167575002 0.598097026
# 0.739750981 0.332424998 0.098095998
# 0.260248989 0.667575002 0.901903987
# 0.260248989 0.332424998 0.401903003
# 0.739750981 0.667575002 0.598097026
# 0.507661998 0.164114997 0.500011027
# 0.492338002 0.835884988 0.499989003
# 0.492338002 0.164114997 0.999988973
# 0.507661998 0.835884988 1.1e-05
# 0.992338002 0.335884988 0.499989003
# 0.007662 0.664115012 0.500011027
# 0.007662 0.335884988 1.1e-05
# 0.5 0.5 0.5
# 0.5 0.5 0.0
# 0.0 0.0 0.5
# 0.0 0.0 0.0
# 0.992338002 0.664115012 0.999988973
# 0.461466014 0.088661999 0.340613991
# 0.461466014 0.911337972 0.840614021
# 0.538533986 0.088661999 0.159385994
# 0.538676023 0.420975 0.659735024
# 0.538676023 0.579024971 0.159734994
# ...

# %%
# !pretrained.py --model_name jv_formation_energy_peratom_alignn --file_format poscar --file_path Test_POSCAR.vasp
# Out:
# 100% 47.5M/47.5M [00:02<00:00, 21.6MiB/s]
# Using chk file jv_formation_energy_peratom_alignn/checkpoint_300.pt from  ['jv_formation_energy_peratom_alignn/checkpoint_300.pt']
# Path /usr/local/bin/jv_formation_energy_peratom_alignn.zip
# Config /content/jv_formation_energy_peratom_alignn/config.json
# Predicted value: jv_formation_energy_peratom_alignn Test_POSCAR.vasp [-2.6965928077697754]

# %%
# !pretrained.py --model_name jv_bulk_modulus_kv_alignn --file_format poscar --file_path Test_POSCAR.vasp
# Out:
# 100% 45.8M/45.8M [00:02<00:00, 20.3MiB/s]
# Using chk file jv_bulk_modulus_kv_alignn/checkpoint_300.pt from  ['jv_bulk_modulus_kv_alignn/checkpoint_300.pt']
# Path /usr/local/bin/jv_bulk_modulus_kv_alignn.zip
# Config /content/jv_bulk_modulus_kv_alignn/config.json
# Predicted value: jv_bulk_modulus_kv_alignn Test_POSCAR.vasp [78.4733657836914]

# %%
# !pretrained.py --model_name jv_shear_modulus_gv_alignn --file_format poscar --file_path Test_POSCAR.vasp
# Out:
# 100% 45.8M/45.8M [00:02<00:00, 19.0MiB/s]
# Using chk file jv_shear_modulus_gv_alignn/checkpoint_300.pt from  ['jv_shear_modulus_gv_alignn/checkpoint_300.pt']
# Path /usr/local/bin/jv_shear_modulus_gv_alignn.zip
# Config /content/jv_shear_modulus_gv_alignn/config.json
# Predicted value: jv_shear_modulus_gv_alignn Test_POSCAR.vasp [51.095340728759766]

# %%
import numpy as np
tmp=atoms.atoms
strain = np.arange(-0.1, 1, 0.01)
vols=[]
for i in strain:
  new_atoms=tmp.strain_atoms (i)
  vols.append(new_atoms.volume)
  fname='POSCAR-'+str(i)
  with open(fname, 'w') as f:
    f.write(Poscar(new_atoms).to_string())
    print(i)
    # !pretrained.py --model_name jv_shear_modulus_gv_alignn --file_format poscar --file_path fname

  #print (new_atoms)

# %%
import numpy as np
tmp=atoms.atoms
strain = [0.01,0.02] #np.arange(-0.1, 1, 0.01)
vols=[]
for i in strain:
  new_atoms=tmp.strain_atoms (i)
  vols.append(new_atoms.volume)
  fname='POSCAR-'+str(i)
  with open(fname, 'w') as f:
    f.write(Poscar(new_atoms).to_string())
    print(i)
    # !pretrained.py --model_name jv_shear_modulus_gv_alignn --file_format poscar --file_path fname

  #print (new_atoms)
# Out:
# Streaming output truncated to the last 5000 lines.
#
# 0.30999999999999983
# Traceback (most recent call last):
#   File "/usr/local/bin/pretrained.py", line 440, in <module>
#     atoms = Atoms.from_poscar(file_path)
#   File "/usr/local/lib/python3.10/site-packages/jarvis/core/atoms.py", line 636, in from_poscar
#     return Poscar.from_file(filename).atoms
#   File "/usr/local/lib/python3.10/site-packages/jarvis/io/vasp/inputs.py", line 36, in from_file
#     with open(filename, "r") as f:
# FileNotFoundError: [Errno 2] No such file or directory: 'fname'
# System
# 1.0
# 9662.882410064705 0.0 0.0
# 0.0 16732.690442867886 0.0
# -7121.658190282804 0.0 36960.983445725935
# H Mg O Si
# 8 12 48 16
# direct
# 0.239750996 0.832424998 0.098095998 H
# 0.760249019 0.167575002 0.901903987 H
# 0.760249019 0.832424998 0.401903003 H
# 0.239750996 0.167575002 0.598097026 H
# 0.739750981 0.332424998 0.098095998 H
# 0.260248989 0.667575002 0.901903987 H
# 0.260248989 0.332424998 0.401903003 H
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.plot(strain,vols)
