# %% [markdown]
# <a href="https://colab.research.google.com/github/knc6/jarvis-tools-notebooks/blob/master/jarvis-tools-notebooks/matminer_jarvis_leaderboard.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/conda-forge/miniforge/releases/download/23.11.0-0/Mambaforge-23.11.0-0-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:17
# 🔁 Restarting kernel...

# %%
# !conda install matminer
# Out:
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 23.11.0
#     latest version: 24.7.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - matminer
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     brotli-1.1.0               |       hd590300_1          19 KB  conda-forge
#     brotli-bin-1.1.0           |       hd590300_1          19 KB  conda-forge
#     ca-certificates-2024.7.4   |       hbcca054_0         151 KB  conda-forge
#     certifi-2024.7.4           |     pyhd8ed1ab_0         156 KB  conda-forge
#     contourpy-1.2.1            |  py310hd41b1e2_0         236 KB  conda-forge
#     cycler-0.12.1              |     pyhd8ed1ab_0          13 KB  conda-forge
#     dnspython-2.6.1            |     pyhd8ed1ab_1         165 KB  conda-forge
#     fonttools-4.53.1           |  py310h5b4e0ec_0         2.3 MB  conda-forge
#     freetype-2.12.1            |       h267a509_2         620 KB  conda-forge
#     future-1.0.0               |     pyhd8ed1ab_0         356 KB  conda-forge
#     gmp-6.3.0                  |       hac33072_2         449 KB  conda-forge
#     gmpy2-2.1.5                |  py310hc7909c9_1         201 KB  conda-forge
#     importlib-resources-6.4.4  |     pyhd8ed1ab_0           9 KB  conda-forge
#     importlib_resources-6.4.4  |     pyhd8ed1ab_0          32 KB  conda-forge
#     joblib-1.4.2               |     pyhd8ed1ab_0         215 KB  conda-forge
#     kiwisolver-1.4.5           |  py310hd41b1e2_1          71 KB  conda-forge
#     latexcodec-2.0.1           |     pyh9f0ad1d_0          18 KB  conda-forge
#     lcms2-2.16                 |       hb7c19ff_0         239 KB  conda-forge
#     lerc-4.0.0                 |       h27087fc_0         275 KB  conda-forge
#     libblas-3.9.0              |23_linux64_openblas          15 KB  conda-forge
#     libbrotlicommon-1.1.0      |       hd590300_1          68 KB  conda-forge
#     libbrotlidec-1.1.0         |       hd590300_1          32 KB  conda-forge
#     libbrotlienc-1.1.0         |       hd590300_1         276 KB  conda-forge
#     libcblas-3.9.0             |23_linux64_openblas          14 KB  conda-forge
#     libdeflate-1.20            |       hd590300_0          70 KB  conda-forge
#     libgfortran-ng-13.2.0      |      h69a702a_13          47 KB  conda-forge
#     libgfortran5-13.2.0        |      h3d2ce59_13         1.4 MB  conda-forge
#     libjpeg-turbo-3.0.0        |       hd590300_1         604 KB  conda-forge
#     liblapack-3.9.0            |23_linux64_openblas          14 KB  conda-forge
#     libopenblas-0.3.27         |pthreads_hac2b453_1         5.3 MB  conda-forge
#     libpng-1.6.43              |       h2797004_0         281 KB  conda-forge
#     libtiff-4.6.0              |       h1dd3fc0_3         276 KB  conda-forge
#     libwebp-base-1.4.0         |       hd590300_0         429 KB  conda-forge
#     libxcb-1.15                |       h0b41bf4_0         375 KB  conda-forge
#     matminer-0.9.2             |     pyhd8ed1ab_1         1.0 MB  conda-forge
#     matplotlib-base-3.9.2      |  py310hf02ac8c_0         6.6 MB  conda-forge
#     monty-2024.7.30            |     pyhd8ed1ab_0          43 KB  conda-forge
#     mpc-1.3.1                  |       hfe3b2da_0         114 KB  conda-forge
#     mpfr-4.2.1                 |       h38ae2d0_2         626 KB  conda-forge
#     mpmath-1.3.0               |     pyhd8ed1ab_0         428 KB  conda-forge
#     munkres-1.1.4              |     pyh9f0ad1d_0          12 KB  conda-forge
#     networkx-3.3               |     pyhd8ed1ab_1         1.1 MB  conda-forge
#     numpy-1.26.4               |  py310hb13e2d6_0         6.7 MB  conda-forge
#     openjpeg-2.5.2             |       h488ebb8_0         334 KB  conda-forge
#     openssl-3.3.1              |       hb9d3cd8_3         2.8 MB  conda-forge
#     palettable-3.3.3           |     pyhd8ed1ab_0          79 KB  conda-forge
#     pandas-2.2.2               |  py310hf9f9076_1        12.4 MB  conda-forge
#     pillow-10.3.0              |  py310hf73ecf8_0        39.8 MB  conda-forge
#     plotly-5.23.0              |     pyhd8ed1ab_0         6.1 MB  conda-forge
#     pthread-stubs-0.4          |    h36c2ea0_1001           5 KB  conda-forge
#     pybtex-0.24.0              |     pyhd8ed1ab_2          71 KB  conda-forge
#     pymatgen-2024.5.31         |  py310h8a78493_0         3.9 MB  conda-forge
#     pymongo-4.8.0              |  py310h76e45a6_0         1.6 MB  conda-forge
#     pyparsing-3.1.2            |     pyhd8ed1ab_0          87 KB  conda-forge
#     python-dateutil-2.9.0      |     pyhd8ed1ab_0         218 KB  conda-forge
#     python-tzdata-2024.1       |     pyhd8ed1ab_0         141 KB  conda-forge
#     pytz-2024.1                |     pyhd8ed1ab_0         184 KB  conda-forge
#     pyyaml-6.0.2               |  py310h5b4e0ec_0         177 KB  conda-forge
#     qhull-2020.2               |       h434a139_5         540 KB  conda-forge
#     scikit-learn-1.5.1         |  py310h146d792_0         8.8 MB  conda-forge
#     scipy-1.14.0               |  py310h3fe0a75_2        16.0 MB  conda-forge
#     six-1.16.0                 |     pyh6c4a22f_0          14 KB  conda-forge
#     sniffio-1.3.1              |     pyhd8ed1ab_0          15 KB  conda-forge
#     spglib-2.5.0               |  py310h355b990_1         635 KB  conda-forge
#     sympy-1.13.2               | pypyh2585a3b_103         4.4 MB  conda-forge
#     tabulate-0.9.0             |     pyhd8ed1ab_1          35 KB  conda-forge
#     tenacity-9.0.0             |     pyhd8ed1ab_0          24 KB  conda-forge
#     threadpoolctl-3.5.0        |     pyhc1e730c_0          23 KB  conda-forge
#     typing-extensions-4.12.2   |       hd8ed1ab_0          10 KB  conda-forge
#     typing_extensions-4.12.2   |     pyha770c72_0          39 KB  conda-forge
#     uncertainties-3.2.2        |     pyhd8ed1ab_1          54 KB  conda-forge
#     unicodedata2-15.1.0        |  py310h2372a71_0         365 KB  conda-forge
#     xorg-libxau-1.0.11         |       hd590300_0          14 KB  conda-forge
#     xorg-libxdmcp-1.1.3        |       h7f98852_0          19 KB  conda-forge
#     yaml-0.2.5                 |       h7f98852_2          87 KB  conda-forge
#     zipp-3.20.0                |     pyhd8ed1ab_0          20 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       130.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   brotli             conda-forge/linux-64::brotli-1.1.0-hd590300_1
#   brotli-bin         conda-forge/linux-64::brotli-bin-1.1.0-hd590300_1
#   contourpy          conda-forge/linux-64::contourpy-1.2.1-py310hd41b1e2_0
#   cycler             conda-forge/noarch::cycler-0.12.1-pyhd8ed1ab_0
#   dnspython          conda-forge/noarch::dnspython-2.6.1-pyhd8ed1ab_1
#   fonttools          conda-forge/linux-64::fonttools-4.53.1-py310h5b4e0ec_0
#   freetype           conda-forge/linux-64::freetype-2.12.1-h267a509_2
#   future             conda-forge/noarch::future-1.0.0-pyhd8ed1ab_0
#   gmp                conda-forge/linux-64::gmp-6.3.0-hac33072_2
#   gmpy2              conda-forge/linux-64::gmpy2-2.1.5-py310hc7909c9_1
#   importlib-resourc~ conda-forge/noarch::importlib-resources-6.4.4-pyhd8ed1ab_0
#   importlib_resourc~ conda-forge/noarch::importlib_resources-6.4.4-pyhd8ed1ab_0
#   joblib             conda-forge/noarch::joblib-1.4.2-pyhd8ed1ab_0
#   kiwisolver         conda-forge/linux-64::kiwisolver-1.4.5-py310hd41b1e2_1
#   latexcodec         conda-forge/noarch::latexcodec-2.0.1-pyh9f0ad1d_0
#   lcms2              conda-forge/linux-64::lcms2-2.16-hb7c19ff_0
#   lerc               conda-forge/linux-64::lerc-4.0.0-h27087fc_0
#   libblas            conda-forge/linux-64::libblas-3.9.0-23_linux64_openblas
#   libbrotlicommon    conda-forge/linux-64::libbrotlicommon-1.1.0-hd590300_1
#   libbrotlidec       conda-forge/linux-64::libbrotlidec-1.1.0-hd590300_1
#   libbrotlienc       conda-forge/linux-64::libbrotlienc-1.1.0-hd590300_1
#   libcblas           conda-forge/linux-64::libcblas-3.9.0-23_linux64_openblas
#   libdeflate         conda-forge/linux-64::libdeflate-1.20-hd590300_0
#   libgfortran-ng     conda-forge/linux-64::libgfortran-ng-13.2.0-h69a702a_13
#   libgfortran5       conda-forge/linux-64::libgfortran5-13.2.0-h3d2ce59_13
#   libjpeg-turbo      conda-forge/linux-64::libjpeg-turbo-3.0.0-hd590300_1
#   liblapack          conda-forge/linux-64::liblapack-3.9.0-23_linux64_openblas
#   libopenblas        conda-forge/linux-64::libopenblas-0.3.27-pthreads_hac2b453_1
#   libpng             conda-forge/linux-64::libpng-1.6.43-h2797004_0
#   libtiff            conda-forge/linux-64::libtiff-4.6.0-h1dd3fc0_3
#   libwebp-base       conda-forge/linux-64::libwebp-base-1.4.0-hd590300_0
#   libxcb             conda-forge/linux-64::libxcb-1.15-h0b41bf4_0
#   matminer           conda-forge/noarch::matminer-0.9.2-pyhd8ed1ab_1
#   matplotlib-base    conda-forge/linux-64::matplotlib-base-3.9.2-py310hf02ac8c_0
#   monty              conda-forge/noarch::monty-2024.7.30-pyhd8ed1ab_0
#   mpc                conda-forge/linux-64::mpc-1.3.1-hfe3b2da_0
#   mpfr               conda-forge/linux-64::mpfr-4.2.1-h38ae2d0_2
#   mpmath             conda-forge/noarch::mpmath-1.3.0-pyhd8ed1ab_0
#   munkres            conda-forge/noarch::munkres-1.1.4-pyh9f0ad1d_0
#   networkx           conda-forge/noarch::networkx-3.3-pyhd8ed1ab_1
#   numpy              conda-forge/linux-64::numpy-1.26.4-py310hb13e2d6_0
#   openjpeg           conda-forge/linux-64::openjpeg-2.5.2-h488ebb8_0
#   palettable         conda-forge/noarch::palettable-3.3.3-pyhd8ed1ab_0
#   pandas             conda-forge/linux-64::pandas-2.2.2-py310hf9f9076_1
#   pillow             conda-forge/linux-64::pillow-10.3.0-py310hf73ecf8_0
#   plotly             conda-forge/noarch::plotly-5.23.0-pyhd8ed1ab_0
#   pthread-stubs      conda-forge/linux-64::pthread-stubs-0.4-h36c2ea0_1001
#   pybtex             conda-forge/noarch::pybtex-0.24.0-pyhd8ed1ab_2
#   pymatgen           conda-forge/linux-64::pymatgen-2024.5.31-py310h8a78493_0
#   pymongo            conda-forge/linux-64::pymongo-4.8.0-py310h76e45a6_0
#   pyparsing          conda-forge/noarch::pyparsing-3.1.2-pyhd8ed1ab_0
#   python-dateutil    conda-forge/noarch::python-dateutil-2.9.0-pyhd8ed1ab_0
#   python-tzdata      conda-forge/noarch::python-tzdata-2024.1-pyhd8ed1ab_0
#   pytz               conda-forge/noarch::pytz-2024.1-pyhd8ed1ab_0
#   pyyaml             conda-forge/linux-64::pyyaml-6.0.2-py310h5b4e0ec_0
#   qhull              conda-forge/linux-64::qhull-2020.2-h434a139_5
#   scikit-learn       conda-forge/linux-64::scikit-learn-1.5.1-py310h146d792_0
#   scipy              conda-forge/linux-64::scipy-1.14.0-py310h3fe0a75_2
#   six                conda-forge/noarch::six-1.16.0-pyh6c4a22f_0
#   sniffio            conda-forge/noarch::sniffio-1.3.1-pyhd8ed1ab_0
#   spglib             conda-forge/linux-64::spglib-2.5.0-py310h355b990_1
#   sympy              conda-forge/noarch::sympy-1.13.2-pypyh2585a3b_103
#   tabulate           conda-forge/noarch::tabulate-0.9.0-pyhd8ed1ab_1
#   tenacity           conda-forge/noarch::tenacity-9.0.0-pyhd8ed1ab_0
#   threadpoolctl      conda-forge/noarch::threadpoolctl-3.5.0-pyhc1e730c_0
#   typing-extensions  conda-forge/noarch::typing-extensions-4.12.2-hd8ed1ab_0
#   typing_extensions  conda-forge/noarch::typing_extensions-4.12.2-pyha770c72_0
#   uncertainties      conda-forge/noarch::uncertainties-3.2.2-pyhd8ed1ab_1
#   unicodedata2       conda-forge/linux-64::unicodedata2-15.1.0-py310h2372a71_0
#   xorg-libxau        conda-forge/linux-64::xorg-libxau-1.0.11-hd590300_0
#   xorg-libxdmcp      conda-forge/linux-64::xorg-libxdmcp-1.1.3-h7f98852_0
#   yaml               conda-forge/linux-64::yaml-0.2.5-h7f98852_2
#   zipp               conda-forge/noarch::zipp-3.20.0-pyhd8ed1ab_0
#
# The following packages will be UPDATED:
#
#   ca-certificates                     2023.11.17-hbcca054_0 --> 2024.7.4-hbcca054_0
#   certifi                           2023.11.17-pyhd8ed1ab_0 --> 2024.7.4-pyhd8ed1ab_0
#   openssl                                  3.2.0-hd590300_1 --> 3.3.1-hb9d3cd8_3
#
#
#
# Downloading and Extracting Packages:
# pillow-10.3.0        | 39.8 MB   | :   0% 0/1 [00:00<?, ?it/s]
# scipy-1.14.0         | 16.0 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
# pandas-2.2.2         | 12.4 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
# scikit-learn-1.5.1   | 8.8 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# numpy-1.26.4         | 6.7 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# matplotlib-base-3.9. | 6.6 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# plotly-5.23.0        | 6.1 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# libopenblas-0.3.27   | 5.3 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# sympy-1.13.2         | 4.4 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# pymatgen-2024.5.31   | 3.9 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# openssl-3.3.1        | 2.8 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# fonttools-4.53.1     | 2.3 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
# pymongo-4.8.0        | 1.6 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# libgfortran5-13.2.0  | 1.4 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# networkx-3.3         | 1.1 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# matminer-0.9.2       | 1.0 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# spglib-2.5.0         | 635 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mpfr-4.2.1           | 626 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# freetype-2.12.1      | 620 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-10.3.0        | 39.8 MB   | :   0% 0.00039211863560808174/1 [00:00<06:33, 393.78s/it]
#
# pandas-2.2.2         | 12.4 MB   | :   0% 0.0012579190974676164/1 [00:00<02:22, 142.80s/it]
#
#
#
# numpy-1.26.4         | 6.7 MB    | :   0% 0.002337542641177788/1 [00:00<01:17, 77.58s/it]
#
#
# scikit-learn-1.5.1   | 8.8 MB    | :   0% 0.0017744689400244877/1 [00:00<01:51, 112.20s/it]
# pillow-10.3.0        | 39.8 MB   | :   7% 0.07136559168067087/1 [00:00<00:02,  2.92s/it]
#
# pandas-2.2.2         | 12.4 MB   | :  19% 0.18617202642520722/1 [00:00<00:00,  1.22s/it]
#
#
#
# numpy-1.26.4         | 6.7 MB    | :  35% 0.3482938535354904/1 [00:00<00:00,  1.53it/s]
#
#
# scikit-learn-1.5.1   | 8.8 MB    | :  22% 0.2200341485630365/1 [00:00<00:00,  1.10s/it]
# pillow-10.3.0        | 39.8 MB   | :  15% 0.1521420306159357/1 [00:00<00:01,  1.88s/it]
#
# pandas-2.2.2         | 12.4 MB   | :  50% 0.49562012440224085/1 [00:00<00:00,  1.70it/s]
#
#
#
# numpy-1.26.4         | 6.7 MB    | :  75% 0.7456761025357145/1 [00:00<00:00,  2.47it/s]
#
#
# scikit-learn-1.5.1   | 8.8 MB    | :  64% 0.6388088184088155/1 [00:00<00:00,  2.13it/s]
# pillow-10.3.0        | 39.8 MB   | :  23% 0.23331058818680864/1 [00:00<00:01,  1.58s/it]
#
# pandas-2.2.2         | 12.4 MB   | :  80% 0.8025523841843392/1 [00:00<00:00,  2.16it/s]
# pillow-10.3.0        | 39.8 MB   | :  34% 0.3403589757078149/1 [00:00<00:00,  1.28s/it]
# scipy-1.14.0         | 16.0 MB   | :  79% 0.791173036214946/1 [00:00<00:00,  1.80it/s]
#
#
#
#
# pillow-10.3.0        | 39.8 MB   | :  45% 0.4485837191356455/1 [00:00<00:00,  1.15s/it]
# scipy-1.14.0         | 16.0 MB   | :  99% 0.987991944238861/1 [00:00<00:00,  1.85it/s]
#
#
#
#
#
# plotly-5.23.0        | 6.1 MB    | :   0% 0.0025541808576429233/1 [00:00<04:37, 278.25s/it]
#
#
#
#
# pillow-10.3.0        | 39.8 MB   | :  54% 0.5379867680542881/1 [00:00<00:00,  1.34s/it]
#
#
#
#
#
# plotly-5.23.0        | 6.1 MB    | :  53% 0.5261612566744421/1 [00:00<00:00,  1.17s/it]
#
#
#
#
# matplotlib-base-3.9. | 6.6 MB    | :  75% 0.752026647601678/1 [00:00<00:00,  1.26it/s]
#
#
#
#
#
# pillow-10.3.0        | 39.8 MB   | :  62% 0.6171947324471206/1 [00:00<00:00,  1.51s/it]
#
#
#
#
#
#
# pillow-10.3.0        | 39.8 MB   | :  70% 0.7011081204672501/1 [00:01<00:00,  1.41s/it]
#
#
#
#
#
#
# pillow-10.3.0        | 39.8 MB   | :  78% 0.7760027798683937/1 [00:01<00:00,  1.42s/it]
#
#
#
#
#
#
#
# sympy-1.13.2         | 4.4 MB    | :   0% 0.0035862723518189214/1 [00:01<05:24, 325.29s/it]
#
#
#
#
#
#
# libopenblas-0.3.27   | 5.3 MB    | : 100% 1.0/1 [00:01<00:00,  1.27it/s]
#
#
#
#
#
#
#
#
# pymatgen-2024.5.31   | 3.9 MB    | :   0% 0.004045800716164016/1 [00:01<05:09, 310.40s/it]
#
#
#
#
#
#
#
# pillow-10.3.0        | 39.8 MB   | :  85% 0.848936846091497/1 [00:01<00:00,  1.50s/it]
#
#
#
#
#
#
#
#
#
# openssl-3.3.1        | 2.8 MB    | :   1% 0.005665201266095029/1 [00:01<03:52, 233.46s/it]
#
#
#
#
#
#
#
#
# pillow-10.3.0        | 39.8 MB   | :  92% 0.9175576073229113/1 [00:01<00:00,  1.51s/it]
#
#
#
#
#
#
#
#
#
# openssl-3.3.1        | 2.8 MB    | :  88% 0.8781061962447295/1 [00:01<00:00,  1.17s/it]
#
#
#
#
#
#
#
#
#
#
# fonttools-4.53.1     | 2.3 MB    | :   1% 0.006942414065168183/1 [00:01<03:30, 212.47s/it]
#
#
#
#
#
#
#
#
#
#
#
# pillow-10.3.0        | 39.8 MB   | :  99% 0.9850020126475013/1 [00:01<00:00,  1.57s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# libgfortran5-13.2.0  | 1.4 MB    | :   1% 0.011226654533693668/1 [00:01<02:15, 136.71s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# networkx-3.3         | 1.1 MB    | :   1% 0.013818347432253493/1 [00:01<01:52, 114.06s/it]
#
#
#
#
#
#
#
#
#
#
# fonttools-4.53.1     | 2.3 MB    | :  94% 0.9372258987977047/1 [00:01<00:00,  1.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# matminer-0.9.2       | 1.0 MB    | :   2% 0.015471681364952826/1 [00:01<01:44, 106.53s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# spglib-2.5.0         | 635 KB    | :   3% 0.02521441641645647/1 [00:01<01:04, 66.30s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mpfr-4.2.1           | 626 KB    | :   3% 0.02556093968903769/1 [00:01<01:04, 66.23s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# freetype-2.12.1      | 620 KB    | :   3% 0.025802712560553852/1 [00:01<01:05, 66.81s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
# numpy-1.26.4         | 6.7 MB    | : 100% 1.0/1 [00:03<00:00,  2.47it/s]
#
#
# scikit-learn-1.5.1   | 8.8 MB    | : 100% 1.0/1 [00:03<00:00,  4.90s/it]
#
#
# scikit-learn-1.5.1   | 8.8 MB    | : 100% 1.0/1 [00:03<00:00,  4.90s/it]
#
#
#
#
# matplotlib-base-3.9. | 6.6 MB    | : 100% 1.0/1 [00:05<00:00,  1.26it/s]
#
# pandas-2.2.2         | 12.4 MB   | : 100% 1.0/1 [00:07<00:00,  2.16it/s]
# scipy-1.14.0         | 16.0 MB   | : 100% 1.0/1 [00:09<00:00,  1.85it/s]
#
#
#
#
#
#
# libopenblas-0.3.27   | 5.3 MB    | : 100% 1.0/1 [00:10<00:00,  1.27it/s]
#
#
#
#
#
#
#
# sympy-1.13.2         | 4.4 MB    | : 100% 1.0/1 [00:11<00:00,  1.27s/it]
#
#
#
#
#
#
#
#
# pymatgen-2024.5.31   | 3.9 MB    | : 100% 1.0/1 [00:12<00:00,  1.26s/it]
#
#
#
#
#
#
#
#
#
# openssl-3.3.1        | 2.8 MB    | : 100% 1.0/1 [00:13<00:00,  1.17s/it]
#
#
#
#
#
#
#
#
#
#
#
# pymongo-4.8.0        | 1.6 MB    | : 100% 1.0/1 [00:15<00:00, 14.69s/it]
#
#
#
#
#
#
#
#
#
#
#
# pymongo-4.8.0        | 1.6 MB    | : 100% 1.0/1 [00:15<00:00, 14.69s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# libgfortran5-13.2.0  | 1.4 MB    | : 100% 1.0/1 [00:15<00:00, 14.83s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# libgfortran5-13.2.0  | 1.4 MB    | : 100% 1.0/1 [00:15<00:00, 14.83s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# networkx-3.3         | 1.1 MB    | : 100% 1.0/1 [00:15<00:00, 15.42s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# networkx-3.3         | 1.1 MB    | : 100% 1.0/1 [00:15<00:00, 15.42s/it]
#
#
#
#
#
#
#
#
#
#
# fonttools-4.53.1     | 2.3 MB    | : 100% 1.0/1 [00:16<00:00,  1.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# matminer-0.9.2       | 1.0 MB    | : 100% 1.0/1 [00:17<00:00, 16.59s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# matminer-0.9.2       | 1.0 MB    | : 100% 1.0/1 [00:17<00:00, 16.59s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# spglib-2.5.0         | 635 KB    | : 100% 1.0/1 [00:19<00:00, 18.65s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# spglib-2.5.0         | 635 KB    | : 100% 1.0/1 [00:19<00:00, 18.65s/it]
#
#
#
#
#
# plotly-5.23.0        | 6.1 MB    | : 100% 1.0/1 [00:19<00:00,  1.35it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mpfr-4.2.1           | 626 KB    | : 100% 1.0/1 [00:19<00:00, 18.76s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mpfr-4.2.1           | 626 KB    | : 100% 1.0/1 [00:19<00:00, 18.76s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# freetype-2.12.1      | 620 KB    | : 100% 1.0/1 [00:19<00:00, 18.78s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# freetype-2.12.1      | 620 KB    | : 100% 1.0/1 [00:19<00:00, 18.78s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-10.3.0        | 39.8 MB   | : 100% 1.0/1 [00:22<00:00,  1.57s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# done

# %% [markdown]
# Restart session

# %%
import matminer
#

# %%
import os
if not os.path.exists('/content/Software'):
    os.makedirs('/content/Software')
os.chdir('/content/Software')
# !git clone https://github.com/usnistgov/jarvis_leaderboard.git
os.chdir('jarvis_leaderboard')

# !pip install -e .
os.chdir('/content')
# Out:
# fatal: destination path 'jarvis_leaderboard' already exists and is not an empty directory.
# Obtaining file:///content/Software/jarvis_leaderboard
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.10/site-packages (from jarvis-leaderboard==2024.4.26) (1.26.4)
# Requirement already satisfied: scipy>=1.6.3 in /usr/local/lib/python3.10/site-packages (from jarvis-leaderboard==2024.4.26) (1.14.0)
# Requirement already satisfied: jarvis-tools>=2021.07.19 in /usr/local/lib/python3.10/site-packages (from jarvis-leaderboard==2024.4.26) (2024.5.10)
# Requirement already satisfied: scikit-learn>=0.24.1 in /usr/local/lib/python3.10/site-packages (from jarvis-leaderboard==2024.4.26) (1.5.1)
# Requirement already satisfied: pandas>=1.2.4 in /usr/local/lib/python3.10/site-packages (from jarvis-leaderboard==2024.4.26) (2.2.2)
# Requirement already satisfied: rouge>=1.0.1 in /usr/local/lib/python3.10/site-packages (from jarvis-leaderboard==2024.4.26) (1.0.1)
# Requirement already satisfied: mkdocs>=1.5.2 in /usr/local/lib/python3.10/site-packages (from jarvis-leaderboard==2024.4.26) (1.6.0)
# Requirement already satisfied: mkdocs-material>=9.0.5 in /usr/local/lib/python3.10/site-packages (from jarvis-leaderboard==2024.4.26) (9.5.33)
# Requirement already satisfied: pydantic>=2.3.0 in /usr/local/lib/python3.10/site-packages (from jarvis-leaderboard==2024.4.26) (2.8.2)
# Requirement already satisfied: markdown>=3.2.1 in /usr/local/lib/python3.10/site-packages (from jarvis-leaderboard==2024.4.26) (3.7)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/site-packages (from jarvis-leaderboard==2024.4.26) (5.23.0)
# Requirement already satisfied: absl-py==1.4.0 in /usr/local/lib/python3.10/site-packages (from jarvis-leaderboard==2024.4.26) (1.4.0)
# Requirement already satisfied: nltk==3.8.1 in /usr/local/lib/python3.10/site-packages (from jarvis-leaderboard==2024.4.26) (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/site-packages (from nltk==3.8.1->jarvis-leaderboard==2024.4.26) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/site-packages (from nltk==3.8.1->jarvis-leaderboard==2024.4.26) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/site-packages (from nltk==3.8.1->jarvis-leaderboard==2024.4.26) (2024.7.24)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/site-packages (from nltk==3.8.1->jarvis-leaderboard==2024.4.26) (4.66.1)
# Requirement already satisfied: matplotlib>=3.0.0 in /usr/local/lib/python3.10/site-packages (from jarvis-tools>=2021.07.19->jarvis-leaderboard==2024.4.26) (3.9.2)
# Requirement already satisfied: spglib>=1.14.1 in /usr/local/lib/python3.10/site-packages (from jarvis-tools>=2021.07.19->jarvis-leaderboard==2024.4.26) (2.5.0)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/site-packages (from jarvis-tools>=2021.07.19->jarvis-leaderboard==2024.4.26) (2.31.0)
# Requirement already satisfied: toolz>=0.9.0 in /usr/local/lib/python3.10/site-packages (from jarvis-tools>=2021.07.19->jarvis-leaderboard==2024.4.26) (0.12.1)
# Requirement already satisfied: xmltodict>=0.11.0 in /usr/local/lib/python3.10/site-packages (from jarvis-tools>=2021.07.19->jarvis-leaderboard==2024.4.26) (0.13.0)
# Requirement already satisfied: inflect in /usr/local/lib/python3.10/site-packages (from jarvis-tools>=2021.07.19->jarvis-leaderboard==2024.4.26) (7.3.1)
# Requirement already satisfied: ghp-import>=1.0 in /usr/local/lib/python3.10/site-packages (from mkdocs>=1.5.2->jarvis-leaderboard==2024.4.26) (2.1.0)
# Requirement already satisfied: jinja2>=2.11.1 in /usr/local/lib/python3.10/site-packages (from mkdocs>=1.5.2->jarvis-leaderboard==2024.4.26) (3.1.4)
# Requirement already satisfied: markupsafe>=2.0.1 in /usr/local/lib/python3.10/site-packages (from mkdocs>=1.5.2->jarvis-leaderboard==2024.4.26) (2.1.5)
# Requirement already satisfied: mergedeep>=1.3.4 in /usr/local/lib/python3.10/site-packages (from mkdocs>=1.5.2->jarvis-leaderboard==2024.4.26) (1.3.4)
# Requirement already satisfied: mkdocs-get-deps>=0.2.0 in /usr/local/lib/python3.10/site-packages (from mkdocs>=1.5.2->jarvis-leaderboard==2024.4.26) (0.2.0)
# Requirement already satisfied: packaging>=20.5 in /usr/local/lib/python3.10/site-packages (from mkdocs>=1.5.2->jarvis-leaderboard==2024.4.26) (23.2)
# Requirement already satisfied: pathspec>=0.11.1 in /usr/local/lib/python3.10/site-packages (from mkdocs>=1.5.2->jarvis-leaderboard==2024.4.26) (0.12.1)
# Requirement already satisfied: pyyaml-env-tag>=0.1 in /usr/local/lib/python3.10/site-packages (from mkdocs>=1.5.2->jarvis-leaderboard==2024.4.26) (0.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/site-packages (from mkdocs>=1.5.2->jarvis-leaderboard==2024.4.26) (6.0.2)
# Requirement already satisfied: watchdog>=2.0 in /usr/local/lib/python3.10/site-packages (from mkdocs>=1.5.2->jarvis-leaderboard==2024.4.26) (4.0.2)
# Requirement already satisfied: babel~=2.10 in /usr/local/lib/python3.10/site-packages (from mkdocs-material>=9.0.5->jarvis-leaderboard==2024.4.26) (2.16.0)
# Requirement already satisfied: colorama~=0.4 in /usr/local/lib/python3.10/site-packages (from mkdocs-material>=9.0.5->jarvis-leaderboard==2024.4.26) (0.4.6)
# Requirement already satisfied: mkdocs-material-extensions~=1.3 in /usr/local/lib/python3.10/site-packages (from mkdocs-material>=9.0.5->jarvis-leaderboard==2024.4.26) (1.3.1)
# Requirement already satisfied: paginate~=0.5 in /usr/local/lib/python3.10/site-packages (from mkdocs-material>=9.0.5->jarvis-leaderboard==2024.4.26) (0.5.6)
# Requirement already satisfied: pygments~=2.16 in /usr/local/lib/python3.10/site-packages (from mkdocs-material>=9.0.5->jarvis-leaderboard==2024.4.26) (2.18.0)
# Requirement already satisfied: pymdown-extensions~=10.2 in /usr/local/lib/python3.10/site-packages (from mkdocs-material>=9.0.5->jarvis-leaderboard==2024.4.26) (10.9)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/site-packages (from pandas>=1.2.4->jarvis-leaderboard==2024.4.26) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/site-packages (from pandas>=1.2.4->jarvis-leaderboard==2024.4.26) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/site-packages (from pandas>=1.2.4->jarvis-leaderboard==2024.4.26) (2024.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/site-packages (from pydantic>=2.3.0->jarvis-leaderboard==2024.4.26) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/site-packages (from pydantic>=2.3.0->jarvis-leaderboard==2024.4.26) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/site-packages (from pydantic>=2.3.0->jarvis-leaderboard==2024.4.26) (4.12.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/site-packages (from rouge>=1.0.1->jarvis-leaderboard==2024.4.26) (1.16.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/site-packages (from scikit-learn>=0.24.1->jarvis-leaderboard==2024.4.26) (3.5.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/site-packages (from plotly->jarvis-leaderboard==2024.4.26) (9.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/site-packages (from matplotlib>=3.0.0->jarvis-tools>=2021.07.19->jarvis-leaderboard==2024.4.26) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/site-packages (from matplotlib>=3.0.0->jarvis-tools>=2021.07.19->jarvis-leaderboard==2024.4.26) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/site-packages (from matplotlib>=3.0.0->jarvis-tools>=2021.07.19->jarvis-leaderboard==2024.4.26) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/site-packages (from matplotlib>=3.0.0->jarvis-tools>=2021.07.19->jarvis-leaderboard==2024.4.26) (1.4.5)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.10/site-packages (from matplotlib>=3.0.0->jarvis-tools>=2021.07.19->jarvis-leaderboard==2024.4.26) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/site-packages (from matplotlib>=3.0.0->jarvis-tools>=2021.07.19->jarvis-leaderboard==2024.4.26) (3.1.2)
# Requirement already satisfied: platformdirs>=2.2.0 in /usr/local/lib/python3.10/site-packages (from mkdocs-get-deps>=0.2.0->mkdocs>=1.5.2->jarvis-leaderboard==2024.4.26) (4.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/site-packages (from requests>=2.23.0->jarvis-tools>=2021.07.19->jarvis-leaderboard==2024.4.26) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/site-packages (from requests>=2.23.0->jarvis-tools>=2021.07.19->jarvis-leaderboard==2024.4.26) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/site-packages (from requests>=2.23.0->jarvis-tools>=2021.07.19->jarvis-leaderboard==2024.4.26) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/site-packages (from requests>=2.23.0->jarvis-tools>=2021.07.19->jarvis-leaderboard==2024.4.26) (2024.7.4)
# Requirement already satisfied: more-itertools>=8.5.0 in /usr/local/lib/python3.10/site-packages (from inflect->jarvis-tools>=2021.07.19->jarvis-leaderboard==2024.4.26) (10.4.0)
# Requirement already satisfied: typeguard>=4.0.1 in /usr/local/lib/python3.10/site-packages (from inflect->jarvis-tools>=2021.07.19->jarvis-leaderboard==2024.4.26) (4.3.0)
# Installing collected packages: jarvis-leaderboard
#   Attempting uninstall: jarvis-leaderboard
#     Found existing installation: jarvis-leaderboard 2024.4.26
#     Uninstalling jarvis-leaderboard-2024.4.26:
#       Successfully uninstalled jarvis-leaderboard-2024.4.26
#   Running setup.py develop for jarvis-leaderboard
# Successfully installed jarvis-leaderboard-2024.4.26

# %%
# !ls /content/Software/jarvis_leaderboard/jarvis_leaderboard/benchmarks/
# Out:
# AI  benchmark_dois.json  descriptions.csv  ES  EXP  FF	__init__.py  QC

# %% [markdown]
# https://github.com/usnistgov/jarvis_leaderboard/blob/main/jarvis_leaderboard/contributions/matminer_rf/run.py

# %%
os.chdir("/content/Software/jarvis_leaderboard/jarvis_leaderboard/contributions/matminer_rf")

# %%
"""Module to run matminer results."""
#%%
import random
import os
import shutil
import pandas as pd
from tqdm import tqdm
import csv
import numpy as np
import math
from jarvis.ai.pkgs.utils import regr_scores
from jarvis.db.figshare import data, get_request_data
from jarvis.core.atoms import Atoms
import zipfile
import json
import time

tqdm.pandas()

#%%
'''
Define regressor and featurizer
'''

from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier

def get_model(task):
    if task == 'SinglePropertyPrediction':
        model =  RandomForestRegressor
    elif task == 'SinglePropertyClass':
        model =  RandomForestClassifier

    reg = Pipeline([
                ('imputer', SimpleImputer()),
                ('scaler', StandardScaler()),
                ('model', model(n_estimators=100, max_features=1/3, n_jobs=-1,bootstrap=False,random_state=0))
            ])
    return reg


def to_unitcell(structure):
    '''
    Make sure coordinates are within the unit cell.
    Used before using structural featurizer.

    Parameters
    ----------
    structure :  pymatgen.core.structure.Structure

    Returns
    -------
    structure :  pymatgen.core.structure.Structure
    '''
    [site.to_unit_cell(in_place=True) for site in structure.sites]
    return structure


def Featurizer(
        df,
        col_id='structure',
        ignore_errors=True,
        chunksize=20
        ):
    """
    Featurize a dataframe using Matminter featurizers

    Parameters
    ----------
    df : Pandas.DataFrame
        DataFrame with a column named "structure"

    Returns
    -------
    A DataFrame containing labels as the first columns and features as the rest

    """
    # For featurization
    from matminer.featurizers.base import MultipleFeaturizer
    from matminer.featurizers.conversions import StrToComposition
    from matminer.featurizers.composition import (ElementProperty,
                                                  Stoichiometry,
                                                  ValenceOrbital,
                                                  IonProperty)
    from matminer.featurizers.structure import (SiteStatsFingerprint,
                                                StructuralHeterogeneity,
                                                ChemicalOrdering,
                                                StructureComposition,
                                                MaximumPackingEfficiency)
    # Make sure df is a DataFrame
    if isinstance(df, pd.Series):
        df = df.to_frame()
    # Use composition featurizers if inputs are compositions, otherwise use
    # both composition and structure featurizers
    if col_id != 'structure':
        # convert string to composition
        a = StrToComposition()
        a._overwrite_data = True
        df[col_id] = a.featurize_dataframe(df,col_id,pbar=False)['composition']
        # no structural features
        struc_feat = []
        # 145 compositional features
        compo_feat = [
            Stoichiometry(),
            ElementProperty.from_preset("magpie"),
            ValenceOrbital(props=['frac']),
            IonProperty(fast=True)
            ]
    else:
        # Ensure sites are within unit cells
        df[col_id] = df[col_id].apply(to_unitcell)
        # 128 structural feature
        struc_feat = [
            SiteStatsFingerprint.from_preset("CoordinationNumber_ward-prb-2017"),
            SiteStatsFingerprint.from_preset("LocalPropertyDifference_ward-prb-2017"),
            StructuralHeterogeneity(),
            MaximumPackingEfficiency(),
            ChemicalOrdering()
            ]
        # 145 compositional features
        compo_feat = [
            StructureComposition(Stoichiometry()),
            StructureComposition(ElementProperty.from_preset("magpie")),
            StructureComposition(ValenceOrbital(props=['frac'])),
            StructureComposition(IonProperty(fast=True))
            ]
    # Define the featurizer
    featurizer = MultipleFeaturizer(struc_feat+compo_feat)
    # Set the chunksize used for Pool.map parallelisation
    featurizer.set_chunksize(chunksize=chunksize)
    X = featurizer.featurize_dataframe(df,col_id,ignore_errors=ignore_errors)
    # check failed entries
    failed = np.any(pd.isnull(X.iloc[:,df.shape[1]:]), axis=1)
    if np.sum(failed) > 0:
        print(f'Number failed: {np.sum(failed)}/{len(failed)}')
    print('Featurization completed.')
    return X, failed


# get the available properties for the database db
def get_props(db):
    dir = f"../../benchmarks/AI/{task}"
    # get all the files that starts with db and ends with .json.zip in dir
    files = [f for f in os.listdir(dir) if f.startswith(db) and f.endswith(".json.zip")]
    # remove the db name and .json.zip from the file name
    files = [f.replace(db+"_", "").replace(".json.zip", "") for f in files]
    return files

#%%

task = 'SinglePropertyPrediction' # 'SinglePropertyClass', 'SinglePropertyPrediction',
reg = get_model(task)

special_dbs = ['ssub','supercon_chem','mag2d_chem']

#for db in special_dbs: # 'hmof','megnet','qe_tb', 'dft_3d', 'snumat',
for db in ['snumat',]:

    # Get the whole dataset and featurize for once and for all properties

    if db in special_dbs:
        if db == 'ssub':
            dat = get_request_data(js_tag="ssub.json",url="https://figshare.com/ndownloader/files/40084921")
        elif db == 'supercon_chem':
            dat = get_request_data(js_tag="supercon_chem.json",url="https://figshare.com/ndownloader/files/40719260")
        elif db == 'mag2d_chem':
            dat = get_request_data(js_tag="mag2d_chem.json",url="https://figshare.com/ndownloader/files/40720004")

        n_features = 145
        col_id = 'formula'

    else:
        dat = data(db)
        n_features = 273
        col_id = 'structure'

    df = pd.DataFrame(dat)

    # some cleaning
    if  db == 'supercon_chem':
        df['formula']= df['formula'].apply(lambda x: x.replace('+',''))
        df['formula']= df['formula'].apply(lambda x: x.replace('-',''))
        df['formula']= df['formula'].apply(lambda x: x.replace('=z',''))
        df['formula']= df['formula'].apply(lambda x: x.replace('!1.5',''))

    # X_file = f"X_{db}.csv"
    X_file = f"../../../../X_{db}.csv"

    if not os.path.exists(X_file):
        # if atomic structure, get the structure
        if db not in special_dbs:
            structure = f'structure_{db}.pkl'
            if os.path.exists(structure):
                df = pd.read_pickle(structure)
            else:
                df["structure"] = df["atoms"].progress_apply(
                    lambda x: Atoms.from_dict(x).pymatgen_converter()
                )
                df.to_pickle(structure)

        df = df.sample(frac=1, random_state=123)
        X, failed = Featurizer(df,col_id=col_id)
        X.to_csv(X_file)

    df = pd.read_csv(X_file)

    for index_name in ['id','jid','SNUMAT_id']:
        if index_name in df.columns:
            df.set_index(index_name,inplace=True)
            df.index = df.index.astype(str)

    for prop in get_props(db):
        print('')
        print('----------------------------')
        print('')
        print("Running", db, prop)

        if task == 'SinglePropertyPrediction':
            fname = f"AI-{task}-{prop}-{db}-test-mae.csv"
        elif task == 'SinglePropertyClass':
            fname = f"AI-{task}-{prop}-{db}-test-acc.csv"

        # skip this loop if the file already exists
        if os.path.exists(fname) or os.path.exists(fname + ".zip"):
            print("Benchmark already done, skipping", fname)
            continue

        json_zip = f"../../benchmarks/AI/{task}/{db}_{prop}.json.zip"
        temp2 = f"{db}_{prop}.json"
        zp = zipfile.ZipFile(json_zip)
        train_val_test = json.loads(zp.read(temp2))

        train = train_val_test["train"]
        if 'val' in train_val_test:
            val = train_val_test["val"]
        else:
            val = {}
        test = train_val_test["test"]

        n_train = len(train)
        n_val = len(val)
        n_test = len(test)

        print("number of training samples", n_train)
        print("number of validation samples", n_val)
        print("number of test samples", n_test)

        ids = list(train.keys()) + list(val.keys()) + list(test.keys())
        id_test = ids[-n_test:]

        features = df.columns[-n_features:]
        X = df.loc[ids,features]
        y = list(train.values()) + list(val.values()) + list(test.values())
        X = np.array(X)
        y = np.array(y).reshape(-1, 1).astype(np.float64)

        X_train, y_train = X[:n_train], y[:n_train]
        X_val, y_val = X[-(n_val + n_test) : -n_test], y[-(n_val + n_test) : -n_test]
        X_test, y_test = X[-n_test:], y[-n_test:]

        t1 = time.time()
        reg.fit(X_train, y_train)
        pred = reg.predict(X_test)
        t2 = time.time()

        # write the predictions to a csv file
        f = open(fname, "w")
        line = "id,prediction\n"
        f.write(line)
        for j, k in zip(id_test, pred):
            line = str(j) + "," + str(k) + "\n"
            f.write(line)
        f.close()
        # zip the csv file
        os.system("zip " + fname + ".zip " + fname)
        # remove the csv file
        os.remove(fname)

        # print time and metrics
        print("Time", t2 - t1)
        if task == 'SinglePropertyPrediction':
            reg_sc = regr_scores(y_test, pred)
            print(prop, reg_sc["mae"])
        elif task == 'SinglePropertyClass':
            from sklearn.metrics import accuracy_score
            acc = accuracy_score(y_test, pred)
            print(prop, acc)




# %%
# Out:
# Obtaining SNUMAT Hybrid functional dataset 10k...
# Reference:https://www.nature.com/articles/s41597-020-00723-8
# Loading the zipfile...
# Loading completed.
# MultipleFeaturizer:   0%|          | 0/10481 [00:00<?, ?it/s]
