# %% [markdown]
# <a href="https://colab.research.google.com/github/knc6/jarvis-tools-notebooks/blob/master/jarvis-tools-notebooks/Train_SNAP_FF_Ni.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Install LAMMPS

# %%
pip install scikit-learn==0.22.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting scikit-learn==0.22.1
#   Downloading scikit-learn-0.22.1.tar.gz (6.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 39.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==0.22.1) (1.22.4)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==0.22.1) (1.10.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==0.22.1) (1.2.0)
# Building wheels for collected packages: scikit-learn
#   Building wheel for scikit-learn (setup.py) ... done
#   Created wheel for scikit-learn: filename=scikit_learn-0.22.1-cp310-cp310-linux_x86_64.whl size=23199658 sha256=372b08d27f693c6d73b24ec59dcf439ec19c3e85427748085688e95a5d59b077
#   Stored in directory: /root/.cache/pip/wheels/ca/81/17/bedd2679672da7fb35b1984624fa1513d04e026878d72d6a42
# Successfully built scikit-learn
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# yellowbrick 1.5 requires scikit-learn>=1.0.0, but you have scikit-learn 0.22.1 which is incompatible.
# sklearn-pandas 2.2.0 requires scikit-learn>=0.23.0, but you have scikit-learn 0.22.1 which is incompatible.
# imbalanced-learn 0.10.1 requires scikit-learn>=1.0.2, but you have scikit-learn 0.22.1 which is incompatible.
# Successfully installed scikit-learn-0.22.1

# %%
import os
# %env LD_PRELOAD=
# !apt install cmake build-essential git ccache
# Clone the LAMMPS git
if not os.path.exists('lammps'):
   os.system('git clone https://github.com/lammps/lammps.git')

# %%
os.chdir('lammps/src')
# !make yes-MANYBODY
# !make serial
# Out:
# Installing package MANYBODY
# make[1]: Entering directory '/content/lammps/src/STUBS'
# g++ -O -fPIC -I.  -c mpi.cpp
# ar rs libmpi_stubs.a mpi.o
# ar: creating libmpi_stubs.a
# make[1]: Leaving directory '/content/lammps/src/STUBS'
# Gathering installed package information (may take a little while)
# make[1]: Entering directory '/content/lammps/src'
# Gathering git version information
# make[1]: Leaving directory '/content/lammps/src'
# Compiling LAMMPS for machine serial
# make[1]: Entering directory '/content/lammps/src/Obj_serial'
# cc -O -o fastdep.exe ../DEPEND/fastdep.c
# make[1]: Leaving directory '/content/lammps/src/Obj_serial'
# make[1]: Entering directory '/content/lammps/src/Obj_serial'
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../main.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../compute_cluster_atom.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../npair_half_size_bin_newtoff.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../imbalance_neigh.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../ntopo_improper_all.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../compute_erotate_sphere.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../npair_skip.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../npair_half_multi_old_newton_tri.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_external.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../math_special.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_momentum.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../ntopo_dihedral_template.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../image.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../npair_skip_respa.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_ave_histo.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../tokenizer.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../displace_atoms.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../reader_xyz.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../pair_deprecated.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../npair_full_bin_ghost.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../angle_deprecated.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_deform.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../rerun.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../atom.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../dump_grid_vtk.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../compute_chunk_atom.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../math_extra.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_store_atom.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_qeq_comb.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../atom_vec_charge.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../compute_deprecated.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../compute_rdf.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../table_file_reader.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../pair_rebo.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../npair_full_multi.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../lattice.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../npair_full_nsq.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../input.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../npair_full_bin_atomonly.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../compute_angle_local.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../neigh_list.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../region_plane.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../kspace_deprecated.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../npair_halffull_newton.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_nph_sphere.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_lineforce.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_wall_region.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../platform.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../create_box.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_store_state.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../pair_lj_expand.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../compute_temp_sphere.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_wall.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../compute_gyration_chunk.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../atom_vec_line.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_nph.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../pair_gw_zbl.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../rcb.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../pair_buck_coul_cut.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../dump_custom.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../compute_pair_local.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../npair_halffull_newtoff_trim.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_wall_lj93.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../random_mars.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../imbalance_var.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../dump_local.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_indent.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../my_page.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_addforce.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../write_data.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../compute_centroid_stress_atom.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../dump_grid.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_ave_histo_weight.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../pair_meam_sw_spline.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_store_force.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../region_block.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../pair_edip.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../universe.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../bond_deprecated.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../compute_property_chunk.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../special.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../pair_hybrid_overlay.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../compute_ke_atom.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_ave_grid.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../ntopo_bond_all.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../region_deprecated.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../compute_count_type.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../npair_copy.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../nstencil_full_multi_old_3d.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_ave_time.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../write_dump.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../compute_chunk_spread_atom.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_minimize.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../change_box.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../region_prism.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../atom_vec_body.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_spring_chunk.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_nvt_sphere.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../pair_bop.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../pair_nb3b_harmonic.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../compute_dipole.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../nstencil_full_multi_2d.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../npair_half_size_multi_newton.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../region_cylinder.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../npair_half_size_nsq_newton.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../npair_half_respa_nsq_newton.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../read_dump.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../run.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../group.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../dump_xyz.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../pair_eam_alloy.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_balance.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_deposit.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../pair_coul_wolf.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../pair_coul_debye.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_heat.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../label_map.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../npair_half_multi_old_newtoff.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_nve_limit.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_temp_berendsen.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../compute_temp_profile.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../pair_born.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_ave_chunk.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_aveforce.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../npair_half_nsq_newton.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../compute_com_chunk.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../compute_centro_atom.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../npair_half_multi_newton_tri.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../dump_image.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../pair_gw.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_move.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../nstencil_half_bin_2d.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_neigh_history.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../create_atoms.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../ntopo.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../atom_map.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../replicate.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../ntopo_angle_partial.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_nve.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_read_restart.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../compute_com.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../timer.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../improper_hybrid.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../npair_full_nsq_ghost.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../npair_half_nsq_newtoff_ghost.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../nstencil_half_multi_3d.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../compute_msd.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_recenter.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../min_quickmin.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../pair_coul_dsf.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../thermo.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../improper_zero.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../region_sphere.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../region_intersect.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_langevin.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../compute_angmom_chunk.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_nvt.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../npair_full_bin.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../angle_write.cpp
# ../angle_write.cpp: In member function ‘virtual void LAMMPS_NS::AngleWrite::command(int, char**)’:
# ../angle_write.cpp:155:12: warning: ignoring return value of ‘char* fgets(char*, int, FILE*)’, declared with attribute warn_unused_result [-Wunused-result]
#   155 |       fgets(line, MAXLINE, coeffs);
#       |       ~~~~~^~~~~~~~~~~~~~~~~~~~~~~
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_planeforce.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_ave_correlate.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../bond.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../compute_coord_atom.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../compute_slice.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../compute_reduce_chunk.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../ntopo_angle_template.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../compute_reduce.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../nstencil_full_multi_old_2d.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../npair_half_size_multi_old_newton.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../dihedral.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../region.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../ntopo_dihedral_partial.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../imbalance_time.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../nstencil_half_multi_old_3d.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../my_pool_chunk.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_deprecated.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../create_bonds.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../region_union.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_temp_rescale.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../neighbor.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../pair_table.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_vector.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../dump_deprecated.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../write_restart.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../npair_half_multi_old_newton.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../compute_temp_deform.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../compute_cna_atom.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../write_coeff.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../velocity.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../min_cg.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../procmap.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../compute_gyration.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../compute_stress_atom.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../ntopo_angle_all.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../npair_half_size_multi_newtoff.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../imbalance_store.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_wall_reflect.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../npair_half_size_nsq_newtoff.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../npair_half_respa_nsq_newtoff.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../reader_native.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../modify.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../compute_dihedral_local.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../pair_eam_he.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_spring.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../compute_erotate_sphere_atom.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../nstencil_half_multi_old_2d.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../balance.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../error.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_nh.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_property_atom.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../compute_global_atom.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../compute_displace_atom.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../npair.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../npair_half_bin_newton.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../dump.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../npair_half_size_bin_newton_tri.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../reset_atoms_id.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../update.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../citeme.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../compute_improper_local.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../lammps.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../nstencil_half_bin_3d_tri.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../ntopo_dihedral_all.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../pair_morse.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../pair_comb.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../atom_vec_hybrid.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../random_park.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../set.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_npt_sphere.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_nve_noforce.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../pair_hybrid_scaled.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../compute_bond.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../npair_full_multi_old.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_bond_history.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_update_special_bonds.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../reset_atoms_image.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../compute_torque_chunk.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../pair.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../angle.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../compute_inertia_chunk.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../ntopo_improper_partial.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_npt.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../lmppython.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../pair_airebo_morse.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../compute_property_atom.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../text_file_reader.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../compute.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../atom_vec_sphere.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_nve_sphere.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../verlet.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../min_fire.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../pair_eam_fs.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../pair_buck.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../kspace.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../pair_meam_spline.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../pair_sw_angle_table.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../integrate.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../compute_temp_chunk.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../atom_vec_ellipsoid.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../npair_half_size_multi_old_newtoff.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../nstencil_half_multi_2d.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../min_sd.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../compute_ke.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../pair_coul_cut.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_adapt.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../compute_msd_chunk.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fmtlib_os.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../pair_tersoff_mod_c.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../compute_temp_ramp.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../nstencil_full_ghost_bin_3d.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../npair_half_multi_newton.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../compute_chunk.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../compute_temp_partial.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../atom_vec_atomic.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../npair_half_size_multi_newton_tri.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../pair_extep.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_restrain.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../nstencil_full_bin_3d.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../dihedral_hybrid.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../compute_reduce_region.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../dump_atom.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../compute_orientorder_atom.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../pair_adp.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../bond_zero.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../deprecated.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../nstencil_half_multi_3d_tri.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../dump_cfg.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../min_deprecated.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../dihedral_zero.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../nbin.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../pair_vashishta_table.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_halt.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_wall_morse.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_ave_atom.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../compute_temp_com.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_wall_lj126.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../variable.cpp
# ../variable.cpp: In member function ‘int LAMMPS_NS::Variable::next(int, char**)’:
# ../variable.cpp:764:14: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’, declared with attribute warn_unused_result [-Wunused-result]
#   764 |         fread(buf,1,64,fp);
#       |         ~~~~~^~~~~~~~~~~~~
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../pair_edip_multi.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../atom_vec_tri.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../npair_half_respa_bin_newtoff.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../irregular.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_store_local.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_thermal_conductivity.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../memory.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../npair_skip_size_off2on_oneside.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../pair_tersoff.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../npair_half_bin_newtoff_ghost.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_setforce.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../pair_atm.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../nstencil_half_bin_2d_tri.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_wall_table.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../minimize.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_nh_sphere.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../tabular_function.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../compute_property_grid.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../pair_local_density.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../reader.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../pair_lj_cut.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_box_relax.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../read_restart.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../imbalance.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../compute_group_group.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../region_ellipsoid.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_wall_lj1043.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../compute_dipole_chunk.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../potential_file_reader.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_efield.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../reset_atoms_mol.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../output.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../comm.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../npair_halffull_newtoff.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../neigh_request.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../domain.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../compute_improper.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../read_data.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../pair_polymorphic.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_enforce2d.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../respa.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../info.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../utils.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../pair_lj_cut_coul_cut.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../compute_vcm_chunk.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../finish.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_evaporate.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../compute_pe.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../imbalance_group.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../nstencil.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../npair_skip_size.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../npair_half_size_multi_old_newton_tri.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../molecule.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../grid3d.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../pair_zbl.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../nstencil_half_multi_old_3d_tri.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../pair_eim.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../ntopo_bond_partial.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../compute_omega_chunk.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../pair_eam_cd.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../nstencil_full_ghost_bin_2d.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../grid2d.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../comm_brick.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../pair_tersoff_mod.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../compute_fragment_atom.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../body.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../region_cone.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../npair_half_bin_newtoff.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../math_eigen.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../hashlittle.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../min_linesearch.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../nstencil_half_multi_2d_tri.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../nbin_multi.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_press_berendsen.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../min.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_print.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../arg_info.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../ntopo_bond_template.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../pair_comb3.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_pair.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../pair_lcbop.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_gravity.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../dump_movie.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_nvt_sllod.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../ntopo_improper_template.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../comm_tiled.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../compute_property_local.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../npair_half_bin_atomonly_newton.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../improper.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../force.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../pair_soft.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../nstencil_full_multi_3d.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../library.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../npair_half_size_bin_newton.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_spring_self.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../pair_hybrid.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../angle_hybrid.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../compute_angle.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../npair_halffull_newton_trim.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_dummy.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../compute_pe_atom.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../npair_skip_size_off2on.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../min_hftn.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../pair_zero.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../compute_heat_flux.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../compute_temp_region.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../pair_threebody_table.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_wall_harmonic.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../atom_vec.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../pair_tersoff_zbl.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../bond_hybrid.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../compute_aggregate_atom.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_respa.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../pair_tersoff_table.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../dihedral_write.cpp
# ../dihedral_write.cpp: In member function ‘virtual void LAMMPS_NS::DihedralWrite::command(int, char**)’:
# ../dihedral_write.cpp:158:12: warning: ignoring return value of ‘char* fgets(char*, int, FILE*)’, declared with attribute warn_unused_result [-Wunused-result]
#   158 |       fgets(line, MAXLINE, coeffs);
#       |       ~~~~~^~~~~~~~~~~~~~~~~~~~~~~
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../pair_eam.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../pair_sw_mod.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_viscous.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../npair_half_respa_bin_newton.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_store_global.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../improper_deprecated.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../compute_pair.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../compute_temp.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../compute_pressure.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../nbin_standard.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../npair_half_multi_newtoff.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../npair_half_nsq_newtoff.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../delete_atoms.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../nstencil_half_bin_3d.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../pair_sw.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../compute_dihedral.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../pair_yukawa.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../delete_bonds.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../pair_vashishta.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../nstencil_half_multi_old_2d_tri.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fmtlib_format.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../compute_bond_local.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../npair_half_respa_bin_newton_tri.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_group.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../angle_zero.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../fix_dt_reset.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../dihedral_deprecated.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../pair_airebo.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../npair_trim.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../compute_vacf.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../npair_half_bin_newton_tri.cpp
# g++ -g -O3 -std=c++11  -DLAMMPS_GZIP -DLAMMPS_MEMALIGN=64    -I../STUBS     -c ../nstencil_full_bin_2d.cpp
# ar -rc ../liblammps_serial.a compute_cluster_atom.o npair_half_size_bin_newtoff.o imbalance_neigh.o ntopo_improper_all.o compute_erotate_sphere.o npair_skip.o npair_half_multi_old_newton_tri.o fix_external.o math_special.o fix_momentum.o ntopo_dihedral_template.o image.o npair_skip_respa.o fix_ave_histo.o tokenizer.o displace_atoms.o reader_xyz.o pair_deprecated.o npair_full_bin_ghost.o angle_deprecated.o fix_deform.o rerun.o atom.o dump_grid_vtk.o compute_chunk_atom.o math_extra.o fix_store_atom.o fix_qeq_comb.o atom_vec_charge.o compute_deprecated.o compute_rdf.o table_file_reader.o pair_rebo.o npair_full_multi.o lattice.o npair_full_nsq.o input.o npair_full_bin_atomonly.o compute_angle_local.o neigh_list.o region_plane.o kspace_deprecated.o npair_halffull_newton.o fix_nph_sphere.o fix_lineforce.o fix_wall_region.o platform.o create_box.o fix_store_state.o pair_lj_expand.o compute_temp_sphere.o fix_wall.o compute_gyration_chunk.o atom_vec_line.o fix_nph.o pair_gw_zbl.o rcb.o pair_buck_coul_cut.o dump_custom.o compute_pair_local.o npair_halffull_newtoff_trim.o fix_wall_lj93.o random_mars.o imbalance_var.o dump_local.o fix_indent.o my_page.o fix_addforce.o write_data.o compute_centroid_stress_atom.o dump_grid.o fix_ave_histo_weight.o pair_meam_sw_spline.o fix_store_force.o region_block.o pair_edip.o universe.o bond_deprecated.o compute_property_chunk.o special.o pair_hybrid_overlay.o compute_ke_atom.o fix_ave_grid.o ntopo_bond_all.o region_deprecated.o compute_count_type.o npair_copy.o nstencil_full_multi_old_3d.o fix_ave_time.o write_dump.o compute_chunk_spread_atom.o fix_minimize.o change_box.o region_prism.o atom_vec_body.o fix_spring_chunk.o fix_nvt_sphere.o pair_bop.o pair_nb3b_harmonic.o compute_dipole.o nstencil_full_multi_2d.o npair_half_size_multi_newton.o region_cylinder.o npair_half_size_nsq_newton.o npair_half_respa_nsq_newton.o read_dump.o run.o group.o dump_xyz.o pair_eam_alloy.o fix_balance.o fix_deposit.o pair_coul_wolf.o pair_coul_debye.o fix_heat.o label_map.o npair_half_multi_old_newtoff.o fix_nve_limit.o fix_temp_berendsen.o compute_temp_profile.o pair_born.o fix_ave_chunk.o fix_aveforce.o npair_half_nsq_newton.o compute_com_chunk.o compute_centro_atom.o npair_half_multi_newton_tri.o dump_image.o pair_gw.o fix_move.o nstencil_half_bin_2d.o fix_neigh_history.o create_atoms.o ntopo.o atom_map.o replicate.o ntopo_angle_partial.o fix_nve.o fix_read_restart.o compute_com.o timer.o improper_hybrid.o npair_full_nsq_ghost.o npair_half_nsq_newtoff_ghost.o nstencil_half_multi_3d.o compute_msd.o fix_recenter.o min_quickmin.o pair_coul_dsf.o thermo.o improper_zero.o region_sphere.o region_intersect.o fix_langevin.o compute_angmom_chunk.o fix_nvt.o npair_full_bin.o angle_write.o fix_planeforce.o fix_ave_correlate.o bond.o compute_coord_atom.o compute_slice.o compute_reduce_chunk.o ntopo_angle_template.o compute_reduce.o nstencil_full_multi_old_2d.o npair_half_size_multi_old_newton.o dihedral.o region.o ntopo_dihedral_partial.o imbalance_time.o nstencil_half_multi_old_3d.o my_pool_chunk.o fix_deprecated.o create_bonds.o region_union.o fix_temp_rescale.o neighbor.o pair_table.o fix_vector.o dump_deprecated.o write_restart.o npair_half_multi_old_newton.o compute_temp_deform.o compute_cna_atom.o write_coeff.o velocity.o min_cg.o procmap.o compute_gyration.o compute_stress_atom.o ntopo_angle_all.o npair_half_size_multi_newtoff.o imbalance_store.o fix_wall_reflect.o npair_half_size_nsq_newtoff.o npair_half_respa_nsq_newtoff.o reader_native.o modify.o compute_dihedral_local.o pair_eam_he.o fix_spring.o compute_erotate_sphere_atom.o nstencil_half_multi_old_2d.o balance.o error.o fix_nh.o fix_property_atom.o compute_global_atom.o fix.o compute_displace_atom.o npair.o npair_half_bin_newton.o dump.o npair_half_size_bin_newton_tri.o reset_atoms_id.o update.o citeme.o compute_improper_local.o lammps.o nstencil_half_bin_3d_tri.o ntopo_dihedral_all.o pair_morse.o pair_comb.o atom_vec_hybrid.o random_park.o set.o fix_npt_sphere.o fix_n ...
# g++ -g -O -std=c++11 main.o  -L../STUBS    -L. -llammps_serial  -lmpi_stubs    -ldl  -o ../lmp_serial
# size ../lmp_serial
#    text	   data	    bss	    dec	    hex	filename
# 7582640	 179272	   1808	7763720	 767708	../lmp_serial
# make[1]: Leaving directory '/content/lammps/src/Obj_serial'

# %%
# !export LMP_EXE=/content/lammps/src/lmp_serial

# %%
import os
os.chdir('/content')

# %%
# !ls
# Out:
# lammps	sample_data  Software

# %%
import mlearn

# %%
os.makedirs('Software')
os.chdir('Software')
if not os.path.exists('mlearn'):
  # !git clone https://github.com/materialsvirtuallab/mlearn.git
os.chdir('mlearn')
# !pip install -e .
os.chdir('/content')
# Out:
# Cloning into 'mlearn'...
# remote: Enumerating objects: 1139, done.
# remote: Counting objects: 100% (84/84), done.
# remote: Compressing objects: 100% (51/51), done.
# remote: Total 1139 (delta 42), reused 71 (delta 32), pack-reused 1055
# Receiving objects: 100% (1139/1139), 72.37 MiB | 4.54 MiB/s, done.
# Resolving deltas: 100% (558/558), done.
# Updating files: 100% (157/157), done.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining file:///content/Software/mlearn
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mlearn==0.1.0) (1.22.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from mlearn==0.1.0) (0.22.1)
# Collecting pymatgen
#   Downloading pymatgen-2023.5.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 55.9 MB/s eta 0:00:00
# Collecting monty
#   Downloading monty-2023.5.8-py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 6.9 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from mlearn==0.1.0) (1.5.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->mlearn==0.1.0) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->mlearn==0.1.0) (2.8.2)
# Requirement already satisfied: matplotlib>=1.5 in /usr/local/lib/python3.10/dist-packages (from pymatgen->mlearn==0.1.0) (3.7.1)
# Collecting ruamel.yaml>=0.17.0
#   Downloading ruamel.yaml-0.17.24-py3-none-any.whl (109 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.0/109.0 kB 512.3 kB/s eta 0:00:00
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from pymatgen->mlearn==0.1.0) (0.8.10)
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from pymatgen->mlearn==0.1.0) (1.10.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from pymatgen->mlearn==0.1.0) (1.11.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from pymatgen->mlearn==0.1.0) (2.27.1)
# Collecting pybtex
#   Downloading pybtex-0.24.0-py2.py3-none-any.whl (561 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 561.4/561.4 kB 32.2 MB/s eta 0:00:00
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from pymatgen->mlearn==0.1.0) (3.1)
# Collecting uncertainties>=3.1.4
#   Downloading uncertainties-3.1.7-py2.py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.4/98.4 kB 10.6 MB/s eta 0:00:00
# Requirement already satisfied: palettable>=3.1.1 in /usr/local/lib/python3.10/dist-packages (from pymatgen->mlearn==0.1.0) (3.3.3)
# Collecting mp-api>=0.27.3
#   Downloading mp_api-0.33.1-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.5/75.5 kB 7.5 MB/s eta 0:00:00
# Requirement already satisfied: plotly>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from pymatgen->mlearn==0.1.0) (5.13.1)
# Collecting spglib>=2.0.2
#   Downloading spglib-2.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (515 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 515.3/515.3 kB 31.6 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from pymatgen->mlearn==0.1.0) (4.65.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->mlearn==0.1.0) (1.2.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.5->pymatgen->mlearn==0.1.0) (8.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.5->pymatgen->mlearn==0.1.0) (4.39.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.5->pymatgen->mlearn==0.1.0) (23.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.5->pymatgen->mlearn==0.1.0) (1.0.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.5->pymatgen->mlearn==0.1.0) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.5->pymatgen->mlearn==0.1.0) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.5->pymatgen->mlearn==0.1.0) (0.11.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from mp-api>=0.27.3->pymatgen->mlearn==0.1.0) (67.7.2)
# Requirement already satisfied: typing-extensions>=3.7.4.1 in /usr/local/lib/python3.10/dist-packages (from mp-api>=0.27.3->pymatgen->mlearn==0.1.0) (4.5.0)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.10/dist-packages (from mp-api>=0.27.3->pymatgen->mlearn==0.1.0) (1.0.5)
# Collecting emmet-core>=0.54.0
#   Downloading emmet_core-0.54.3-py3-none-any.whl (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.6/151.6 kB 14.5 MB/s eta 0:00:00
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=4.5.0->pymatgen->mlearn==0.1.0) (8.2.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->mlearn==0.1.0) (1.16.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->pymatgen->mlearn==0.1.0) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->pymatgen->mlearn==0.1.0) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->pymatgen->mlearn==0.1.0) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->pymatgen->mlearn==0.1.0) (1.26.15)
# Collecting ruamel.yaml.clib>=0.2.7
#   Downloading ruamel.yaml.clib-0.2.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (485 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.6/485.6 kB 33.3 MB/s eta 0:00:00
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from uncertainties>=3.1.4->pymatgen->mlearn==0.1.0) (0.18.3)
# Requirement already satisfied: PyYAML>=3.01 in /usr/local/lib/python3.10/dist-packages (from pybtex->pymatgen->mlearn==0.1.0) (6.0)
# Collecting latexcodec>=1.0.4
#   Downloading latexcodec-2.0.1-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->pymatgen->mlearn==0.1.0) (1.3.0)
# Requirement already satisfied: pydantic>=1.10.2 in /usr/local/lib/python3.10/dist-packages (from emmet-core>=0.54.0->mp-api>=0.27.3->pymatgen->mlearn==0.1.0) (1.10.7)
# Installing collected packages: uncertainties, spglib, ruamel.yaml.clib, monty, latexcodec, ruamel.yaml, pybtex, emmet-core, mp-api, pymatgen, mlearn
#   Running setup.py develop for mlearn
# Successfully installed emmet-core-0.54.3 latexcodec-2.0.1 mlearn-0.1.0 monty-2023.5.8 mp-api-0.33.1 pybtex-0.24.0 pymatgen-2023.5.8 ruamel.yaml-0.17.24 ruamel.yaml.clib-0.2.7 spglib-2.0.2 uncertainties-3.1.7

# %%
# !ls Software/mlearn/data/Ni
# Out:
# test.json  training.json

# %%
from pymatgen.core import Structure
from pymatgen.core.lattice import Lattice
from pymatgen.core.composition import Element
from monty.serialization import loadfn

# data = loadfn('data.json')
data = loadfn("Software/mlearn/data/Ni/training.json")
train_structures = [d['structure'] for d in data]
train_energies = [d['outputs']['energy'] for d in data]
train_forces = [d['outputs']['forces'] for d in data]
train_stresses = [d['outputs']['virial_stress'] for d in data]


data = loadfn("Software/mlearn/data/Ni/test.json")
test_structures = [d['structure'] for d in data]
test_energies = [d['outputs']['energy'] for d in data]
test_forces = [d['outputs']['forces'] for d in data]
test_stresses = [d['outputs']['virial_stress'] for d in data]

# %% [markdown]
# Modify line 9 to from pymatgen.core.structure import Structure in data.py if you encounter error import Structure from pymatgen

# %%
import numpy as np
from mlearn.data import pool_from, convert_docs

train_pool = pool_from(train_structures, train_energies, train_forces)
_, df = convert_docs(train_pool)

weights = np.ones(len(df['dtype']), )

# set the weights for energy equal to 100
weights[df['dtype'] == 'energy'] = 100

# %%
# pip install scikit-learn==0.22.2.post1

# %% [markdown]
# # snap.py line 10:from pymatgen.core.periodic_table import Element

# %% [markdown]
# calcs.py line 21 from pymatgen.core.structure import Structure, Lattice, Element

# %%
# !/content/lammps/src/lmp_serial
# Out:
# LAMMPS (28 Mar 2023 - Development)
# ^C

# %%
# !cp /content/lammps/src/lmp_serial .

# %%
# !export LMP_EXE=lmp_serial

# %%
import os

from mlearn.describers import BispectrumCoefficients
from mlearn.models import LinearModel
from mlearn.potentials.snap import SNAPotential
#from: https://github.com/materialsvirtuallab/maml/blob/master/mvl_models/pes/Si/snap.2020.01/SNAPotential.snapparam
element_profile = {'Ni': {'r': 0.5, 'w': 1.9}}
describer = BispectrumCoefficients(rcutfac=4.1, twojmax=8, element_profile=element_profile, 
                                   quadratic=False, pot_fit=True)
model = LinearModel(describer=describer)
snap = SNAPotential(model=model)
snap.train(train_structures, train_energies, train_forces, weights=weights,)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-38-348d557fc668> in <cell line: 12>()
#      10 model = LinearModel(describer=describer)
#      11 snap = SNAPotential(model=model)
# ---> 12 snap.train(train_structures, train_energies, train_forces, weights=weights,)
#
# /content/Software/mlearn/mlearn/potentials/snap.py in train(self, train_structures, energies, forces, stresses, **kwargs)
#      58         _, df = convert_docs(train_pool)
#      59         ytrain = df['y_orig'] / df['n']
# ---> 60         self.model.fit(inputs=train_structures, outputs=ytrain, **kwargs)
#      61         self.specie = Element(train_structures[0].symbol_set[0])
#      62
#
# /content/Software/mlearn/mlearn/models.py in fit(self, inputs, outputs, weights, override)
#      53         """
#      54         if self._xtrain is None or override:
# ---> 55             xtrain = self.describer.describe_all(inputs)
#      56         else:
#      57             warnings.warn("Feature vectors retrieved from cache "
#
# /content/Software/mlearn/mlearn/describers.py in describe_all(self, structures, include_stress)
#     123                                 itertools.combinations_with_replacement(self.subscripts, 2)))
#     124
# --> 125         raw_data = self.calculator.calculate(structures)
#     126
#     127         def process(output, combine, idx, include_stress):
#
# /content/Software/mlearn/mlearn/potentials/lammps/calcs.py in calculate(self, structures)
#     105                 ld = LammpsData.from_structure(s, ff_elements)
#     106                 ld.write_file('data.static')
# --> 107                 self.LMP_EXE="/content/lammps/src/lmp_serial"
#     108                 p = subprocess.Popen([self.LMP_EXE, '-in', input_file],
#     109                                      stdout=subprocess.PIPE)
#
# /usr/lib/python3.10/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize)
#     969                             encoding=encoding, errors=errors)
#     970
# --> 971             self._execute_child(args, executable, preexec_fn, close_fds,
#     972                                 pass_fds, cwd, env,
#     973                                 startupinfo, creationflags, shell,
#
# /usr/lib/python3.10/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session)
#    1861                     if errno_num != 0:
#    1862                         err_msg = os.strerror(errno_num)
# -> 1863                     raise child_exception_type(errno_num, err_msg, err_filename)
#    1864                 raise child_exception_type(err_msg)
#    1865
#
# FileNotFoundError: [Errno 2] No such file or directory: 'lmp_serial'

# %%
import pymatgen

# %%
from pymatgen.core.structure import Structure
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-11-c2f75d9178db> in <cell line: 1>()
# ----> 1 from pymatgen.core.structure import Structure
#
# ModuleNotFoundError: No module named 'pymatgen.core'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !ls -altr lammps/src
# Out:
# total 9548
# -rw-r--r--  1 root root  32835 May  8 11:26 .gitignore
# -rw-r--r--  1 root root   1282 May  8 11:26 .clang-format
# drwxr-xr-x  2 root root   4096 May  8 11:26 ADIOS
# drwxr-xr-x  2 root root   4096 May  8 11:26 AMOEBA
# drwxr-xr-x  2 root root   4096 May  8 11:26 ATC
# drwxr-xr-x  2 root root   4096 May  8 11:26 ASPHERE
# drwxr-xr-x  2 root root   4096 May  8 11:26 AWPMD
# drwxr-xr-x  2 root root   4096 May  8 11:26 BOCS
# drwxr-xr-x  2 root root   4096 May  8 11:26 BODY
# drwxr-xr-x  2 root root   4096 May  8 11:26 BROWNIAN
# drwxr-xr-x  2 root root   4096 May  8 11:26 BPM
# drwxr-xr-x  2 root root   4096 May  8 11:26 CG-DNA
# drwxr-xr-x  2 root root   4096 May  8 11:26 CG-SPICA
# drwxr-xr-x  2 root root   4096 May  8 11:26 CLASS2
# drwxr-xr-x  2 root root   4096 May  8 11:26 COLLOID
# drwxr-xr-x  2 root root   4096 May  8 11:26 COLVARS
# drwxr-xr-x  2 root root   4096 May  8 11:26 COMPRESS
# drwxr-xr-x  2 root root   4096 May  8 11:26 DEPEND
# drwxr-xr-x  2 root root   4096 May  8 11:26 CORESHELL
# drwxr-xr-x  2 root root   4096 May  8 11:26 DIELECTRIC
# drwxr-xr-x  2 root root   4096 May  8 11:26 DIFFRACTION
# drwxr-xr-x  2 root root   4096 May  8 11:26 DPD-BASIC
# drwxr-xr-x  2 root root   4096 May  8 11:26 DIPOLE
# drwxr-xr-x  2 root root   4096 May  8 11:26 DPD-MESO
# drwxr-xr-x  2 root root   4096 May  8 11:26 DPD-REACT
# drwxr-xr-x  2 root root   4096 May  8 11:26 DPD-SMOOTH
# drwxr-xr-x  2 root root   4096 May  8 11:26 DRUDE
# -rwxr-xr-x  1 root root   3557 May  8 11:26 Depend.sh
# drwxr-xr-x  2 root root   4096 May  8 11:26 EFF
# drwxr-xr-x  2 root root   4096 May  8 11:26 ELECTRODE
# drwxr-xr-x  2 root root   4096 May  8 11:26 EXTRA-COMPUTE
# drwxr-xr-x  2 root root   4096 May  8 11:26 EXTRA-DUMP
# drwxr-xr-x  2 root root   4096 May  8 11:26 EXTRA-FIX
# drwxr-xr-x  2 root root   4096 May  8 11:26 EXTRA-MOLECULE
# drwxr-xr-x  2 root root   4096 May  8 11:26 EXTRA-PAIR
# -rwxr-xr-x  1 root root   1127 May  8 11:26 Fetch.sh
# drwxr-xr-x  2 root root   4096 May  8 11:26 FEP
# drwxr-xr-x  2 root root  12288 May  8 11:26 GPU
# drwxr-xr-x  2 root root   4096 May  8 11:26 H5MD
# drwxr-xr-x  2 root root   4096 May  8 11:26 GRANULAR
# drwxr-xr-x  3 root root   4096 May  8 11:26 INTEL
# drwxr-xr-x  2 root root   4096 May  8 11:26 INTERLAYER
# -rwxr-xr-x  1 root root    788 May  8 11:26 Install.sh
# drwxr-xr-x  2 root root   4096 May  8 11:26 KIM
# drwxr-xr-x  2 root root  16384 May  8 11:26 KOKKOS
# drwxr-xr-x  2 root root   4096 May  8 11:26 KSPACE
# drwxr-xr-x  2 root root   4096 May  8 11:26 LATBOLTZ
# drwxr-xr-x  2 root root   4096 May  8 11:26 LEPTON
# drwxr-xr-x  2 root root   4096 May  8 11:26 MACHDYN
# drwxr-xr-x  5 root root   4096 May  8 11:26 MAKE
# drwxr-xr-x  2 root root   4096 May  8 11:26 MANIFOLD
# drwxr-xr-x  2 root root   4096 May  8 11:26 MANYBODY
# drwxr-xr-x  2 root root   4096 May  8 11:26 MC
# drwxr-xr-x  2 root root   4096 May  8 11:26 MDI
# drwxr-xr-x  2 root root   4096 May  8 11:26 MEAM
# drwxr-xr-x  2 root root   4096 May  8 11:26 MESONT
# drwxr-xr-x  2 root root   4096 May  8 11:26 MGPT
# drwxr-xr-x  2 root root   4096 May  8 11:26 MISC
# drwxr-xr-x  2 root root   4096 May  8 11:26 ML-HDNNP
# drwxr-xr-x  2 root root   4096 May  8 11:26 ML-IAP
# drwxr-xr-x  2 root root   4096 May  8 11:26 ML-PACE
# drwxr-xr-x  2 root root   4096 May  8 11:26 ML-QUIP
# drwxr-xr-x  2 root root   4096 May  8 11:26 ML-POD
# drwxr-xr-x  2 root root   4096 May  8 11:26 ML-RANN
# drwxr-xr-x  2 root root   4096 May  8 11:26 ML-SNAP
# drwxr-xr-x  2 root root   4096 May  8 11:26 MOFFF
# drwxr-xr-x  2 root root   4096 May  8 11:26 MOLECULE
# drwxr-xr-x  2 root root   4096 May  8 11:26 MOLFILE
# drwxr-xr-x  2 root root   4096 May  8 11:26 MSCG
# drwxr-xr-x  2 root root   4096 May  8 11:26 MPIIO
# -rwxr-xr-x  1 root root   4559 May  8 11:26 Make.sh
# -rw-r--r--  1 root root    245 May  8 11:26 Makefile.package.empty
# -rw-r--r--  1 root root   9848 May  8 11:26 Makefile.list
# -rw-r--r--  1 root root  18973 May  8 11:26 Makefile
# -rw-r--r--  1 root root    851 May  8 11:26 Makefile.print
# -rw-r--r--  1 root root    147 May  8 11:26 Makefile.package.settings.empty
# drwxr-xr-x  2 root root   4096 May  8 11:26 NETCDF
# drwxr-xr-x  2 root root  28672 May  8 11:26 OPENMP
# drwxr-xr-x  2 root root   4096 May  8 11:26 OPT
# drwxr-xr-x  2 root root   4096 May  8 11:26 ORIENT
# drwxr-xr-x  2 root root   4096 May  8 11:26 PLUGIN
# drwxr-xr-x  2 root root   4096 May  8 11:26 PHONON
# drwxr-xr-x  2 root root   4096 May  8 11:26 PERI
# drwxr-xr-x  2 root root   4096 May  8 11:26 POEMS
# drwxr-xr-x  2 root root   4096 May  8 11:26 PLUMED
# drwxr-xr-x  2 root root   4096 May  8 11:26 PTM
# drwxr-xr-x  2 root root   4096 May  8 11:26 PYTHON
# -rwxr-xr-x  1 root root   2554 May  8 11:26 Package.sh
# -rw-r--r--  1 root root  16470 May  8 11:26 Purge.list
# drwxr-xr-x  2 root root   4096 May  8 11:26 QMMM
# drwxr-xr-x  2 root root   4096 May  8 11:26 QEQ
# drwxr-xr-x  2 root root   4096 May  8 11:26 QTB
# drwxr-xr-x  2 root root   4096 May  8 11:26 REACTION
# drwxr-xr-x  2 root root   4096 May  8 11:26 REAXFF
# drwxr-xr-x  2 root root   4096 May  8 11:26 REPLICA
# drwxr-xr-x  2 root root   4096 May  8 11:26 RIGID
# drwxr-xr-x  2 root root   4096 May  8 11:26 SCAFACOS
# drwxr-xr-x  2 root root   4096 May  8 11:26 SHOCK
# drwxr-xr-x  2 root root   4096 May  8 11:26 SMTBQ
# drwxr-xr-x  2 root root   4096 May  8 11:26 SPH
# drwxr-xr-x  2 root root   4096 May  8 11:26 SPIN
# drwxr-xr-x  2 root root   4096 May  8 11:26 SRD
# drwxr-xr-x  2 root root   4096 May  8 11:26 STUBS
# drwxr-xr-x  2 root root   4096 May  8 11:26 TALLY
# drwxr-xr-x  2 root root   4096 May  8 11:26 VORONOI
# drwxr-xr-x  2 root root   4096 May  8 11:26 UEF
# drwxr-xr-x  2 root root   4096 May  8 11:26 VTK
# drwxr-xr-x  2 root root   4096 May  8 11:26 YAFF
# -rw-r--r--  1 root root   1762 May  8 11:26 angle_hybrid.h
# -rw-r--r--  1 root root  12155 May  8 11:26 angle_hybrid.cpp
# -rw-r--r--  1 root root   3478 May  8 11:26 angle.h
# -rw-r--r--  1 root root   1314 May  8 11:26 angle_deprecated.h
# -rw-r--r--  1 root root   1684 May  8 11:26 angle_deprecated.cpp
# -rw-r--r--  1 root root  17562 May  8 11:26 angle.cpp
# -rw-r--r--  1 root root   1381 May  8 11:26 accelerator_omp.h
# -rw-r--r--  1 root root   3123 May  8 11:26 accelerator_kokkos.h
# -rw-r--r--  1 root root 106887 May  8 11:26 atom.cpp
# -rw-r--r--  1 root root   3540 May  8 11:26 arg_info.h
# -rw-r--r--  1 root root   3529 May  8 11:26 arg_info.cpp
# -rw-r--r--  1 root root   1352 May  8 11:26 angle_zero.h
# -rw-r--r--  1 root root   4529 May  8 11:26 angle_zero.cpp
# -rw-r--r--  1 root root   1021 May  8 11:26 angle_write.h
# -rw-r--r--  1 root root   8649 May  8 11:26 angle_write.cpp
# -rw-r--r--  1 root root   8057 May  8 11:26 atom_vec.h
# -rw-r--r--  1 root root  77758 May  8 11:26 atom_vec.cpp
# -rw-r--r--  1 root root    979 May  8 11:26 atom_vec_atomic.h
# -rw-r--r--  1 root root   1267 May  8 11:26 atom_vec_atomic.cpp
# -rw-r--r--  1 root root   3038 May  8 11:26 atom_masks.h
# -rw-r--r--  1 root root    638 May  8 11:26 atom_map.h
# -rw-r--r--  1 root root  11807 May  8 11:26 atom_map.cpp
# -rw-r--r--  1 root root  13255 May  8 11:26 atom.h
# -rw-r--r--  1 root root   2359 May  8 11:26 atom_vec_line.h
# -rw-r--r--  1 root root  15651 May  8 11:26 atom_vec_line.cpp
# -rw-r--r--  1 root root   2555 May  8 11:26 atom_vec_hybrid.h
# -rw-r--r--  1 root root  16926 May  8 11:26 atom_vec_hybrid.cpp
# -rw-r--r--  1 root root   2365 May  8 11:26 atom_vec_ellipsoid.h
# -rw-r--r--  1 root root  16714 May  8 11:26 atom_vec_ellipsoid.cpp
# -rw-r--r--  1 root root    979 May  8 11:26 atom_vec_charge.h
# -rw-r--r--  1 root root   1470 May  8 11:26 atom_vec_charge.cpp
# -rw-r--r--  1 root root   2639 May  8 11:26 atom_vec_body.h
# -rw-r--r--  1 root root  21806 May  8 11:26 atom_vec_body.cpp
# -rw-r--r--  1 root root  13918 May  8 11:26 bond.cpp
# -rw-r--r--  1 root root   2034 May  8 11:26 body.h
# -rw-r--r--  1 root root   1016 May  8 11:26 body.cpp
# -rw-r--r--  1 root root   3516 May  8 11:26 balance.h
# -rw-r--r--  1 root root  42890 May  8 11:26 balance.cpp
# -rw-r--r--  1 root root   2371 May  8 11:26 atom_vec_tri.h
# -rw-r--r--  1 root root  24166 May  8 11:26 atom_vec_tri.cpp
# -rw-r--r--  1 root root   1335 May  8 11:26 atom_vec_sphere.h
# -rw-r--r--  1 root root   5398 May  8 11:26 atom_vec_sphere.cpp
# -rw-r--r--  1 root root   1572 May  8 11:26 citeme.h
# -rw-r--r--  1 root root   3910 May  8 11:26 citeme.cpp
# -rw-r--r--  1 root root   1374 May  8 11:26 change_box.h
# -rw-r--r--  1 root root  17005 May  8 11:26 change_box.cpp
# -rw-r--r--  1 root root   1409 May  8 11:26 bond_zero.h
# -rw-r--r--  1 root root   4649 May  8 11:26 bond_zero.cpp
# -rw-r--r--  1 root root   1937 May  8 11:26 bond_hybrid.h
# -rw-r--r--  1 root root  13211 May  8 11:26 bond_hybrid.cpp
# -rw-r--r--  1 root root   3813 May  8 11:26 bond.h
# -rw-r--r--  1 root root   1320 May  8 11:26 bond_deprecated.h
# -rw-r--r--  1 root root   1676 May  8 11:26 bond_deprecated.cpp
# -rw-r--r--  1 root root   7884 May  8 11:26 comm.h
# -rw-r--r--  1 root root  48383 May  8 11:26 comm.cpp
# -rw-r--r--  1 root root   7409 May  8 11:26 comm_tiled.h
# -rw-r--r--  1 root root  87247 May  8 11:26 comm_tiled.cpp
# -rw-r--r--  1 root root   5301 May  8 11:26 comm_brick.h
# -rw-r--r--  1 root root  58078 May  8 11:26 comm_brick.cpp
# -rw-r--r--  1 root root    930 May  8 11:26 command.h
# -rw-r--r--  1 root root   7634 May  8 11:26 compute.h
# -rw-r--r--  1 root root   6304 May  8 11:26 compute.cpp
# -rw-r--r--  1 root root   2373 May  8 11:26 compute_bond.cpp
# -rw-r--r--  1 root root   1262 May  8 11:26 compute_angmom_chunk.h
# -rw-r--r--  1 root root   5120 May  8 11:26 compute_angmom_chunk.cpp
# -rw-r--r--  1 root root   1361 May  8 11:26 compute_angle_local.h
# -rw-r--r--  1 root root   9733 May  8 11:26 compute_angle_local.cpp
# -rw-r--r--  1 root root   1136 May  8 11:26 compute_angle.h
# -rw-r--r--  1 root root   2405 May  8 11:26 compute_angle.cpp
# -rw-r--r--  1 root root   1548 May  8 11:26 compute_aggregate_atom.h
# -rw-r--r--  1 root root   8719 May  8 11:26 compute_aggregate_atom.cpp
# -rw-r--r--  1 root root   1410 May  8 11:26 compute_chunk.h
# -rw-r--r--  1 root root   4814 May  8 11:26 compute_chunk.cpp
# -rw-r--r--  1 root root  64040 May  8 11:26 compute_chunk_atom.cpp
# -rw-r--r--  1 root root   1507 May  8 11:26 compute_centroid_stress_atom.h
# -rw-r--r--  1 root root  16942 May  8 11:26 compute_centroid_stress_atom.cpp
# -rw-r--r--  1 root root   1395 May  8 11:26 compute_centro_atom.h
# -rw-r--r--  1 root root  11729 May  8 11:26 compute_centro_atom.cpp
# -rw-r--r--  1 root root   1531 May  8 11:26 compute_bond_local.h
# -rw-r--r--  1 root root  15848 May  8 11:26 compute_bond_local.cpp
# -rw-r--r--  1 root root   1127 May  8 11:26 compute_bond.h
# -rw-r--r--  1 root root   9880 May  8 11:26 compute_coord_atom.cpp
# -rw-r--r--  1 root root   1085 May  8 11:26 compute_com.h
# -rw-r--r--  1 root root   1607 May  8 11:26 compute_com.cpp
# -rw-r--r--  1 root root   1243 May  8 11:26 compute_com_chunk.h
# -rw-r--r--  1 root root   4430 May  8 11:26 compute_com_chunk.cpp
# -rw-r--r--  1 root root   1288 May  8 11:26 compute_cna_atom.h
# -rw-r--r--  1 root root  10804 May  8 11:26 compute_cna_atom.cpp
# -rw-r--r--  1 root root   1409 May  8 11:26 compute_cluster_atom.h
# -rw-r--r--  1 root root   6062 May  8 11:26 compute_cluster_atom.cpp
# -rw-r--r--  1 root root   1453 May  8 11:26 compute_chunk_spread_atom.h
# -rw-r--r--  1 root root   9885 May  8 11:26 compute_chunk_spread_atom.cpp
# -rw-r--r--  1 root root   3661 May  8 11:26 compute_chunk_atom.h
# -rw-r--r--  1 root root   2206 May  8 11:26 compute_erotate_sphere.cpp
# -rw-r--r--  1 root root   1446 May  8 11:26 compute_displace_atom.h
# -rw-r--r--  1 root root   7470 May  8 11:26 compute_displace_atom.cpp
# -rw-r--r--  1 root root   1141 May  8 11:26 compute_dipole.h
# -rw-r--r--  1 root root   4190 May  8 11:26 compute_dipole.cpp
# -rw-r--r--  1 root root   1350 May  8 11:26 compute_dipole_chunk.h
# -rw-r--r--  1 root root   6779 May  8 11:26 compute_dipole_chunk.cpp
# -rw-r--r--  1 root root   1378 May  8 11:26 compute_dihedral_local.h
# -rw-r--r--  1 root root  10198 May  8 11:26 compute_dihedral_local.cpp
# -rw-r--r--  1 root root   1163 May  8 11:26 compute_dihedral.h
# -rw-r--r--  1 root root   2493 May  8 11:26 compute_dihedral.cpp
# -rw-r--r--  1 root root   1131 May  8 11:26 compute_deprecated.h
# -rw-r--r--  1 root root   1434 May  8 11:26 compute_deprecated.cpp
# -rw-r--r--  1 root root   1335 May  8 11:26 compute_count_type.h
# -rw-r--r--  1 root root  12001 May  8 11:26 compute_count_type.cpp
# -rw-r--r--  1 root root   1652 May  8 11:26 compute_coord_atom.h
# -rw-r--r--  1 root root   1445 May  8 11:26 compute_global_atom.h
# -rw-r--r--  1 root root  15892 May  8 11:26 compute_global_atom.cpp
# -rw-r--r--  1 root root   1380 May  8 11:26 compute_fragment_atom.h
# -rw-r--r--  1 root root   8043 May  8 11:26 compute_fragment_atom.cpp
# -rw-r--r--  1 root root   1125 May  8 11:26 compute_erotate_sphere.h
# -rw-r--r--  1 root root   1250 May  8 11:26 compute_erotate_sphere_atom.h
# -rw-r--r--  1 root root   3217 May  8 11:26 compute_erotate_sphere_atom.cpp
# -rw-r--r--  1 root root   1179 May  8 11:26 compute_heat_flux.h
# -rw-r--r--  1 root root   6275 May  8 11:26 compute_heat_flux.cpp
# -rw-r--r--  1 root root   1156 May  8 11:26 compute_gyration.h
# -rw-r--r--  1 root root   3198 May  8 11:26 compute_gyration.cpp
# -rw-r--r--  1 root root   1364 May  8 11:26 compute_gyration_chunk.h
# -rw-r--r--  1 root root   7749 May  8 11:26 compute_gyration_chunk.cpp
# -rw-r--r--  1 root root   1516 May  8 11:26 compute_group_group.h
# -rw-r--r--  1 root root  12074 May  8 11:26 compute_group_group.cpp
# -rw-r--r--  1 root root  22786 May  8 11:26 compute_orientorder_atom.cpp
# -rw-r--r--  1 root root   1308 May  8 11:26 compute_omega_chunk.h
# -rw-r--r--  1 root root   9957 May  8 11:26 compute_omega_chunk.cpp
# -rw-r--r--  1 root root   1384 May  8 11:26 compute_msd.h
# -rw-r--r--  1 root root   7519 May  8 11:26 compute_msd.cpp
# -rw-r--r--  1 root root   1320 May  8 11:26 compute_msd_chunk.h
# -rw-r--r--  1 root root   6678 May  8 11:26 compute_msd_chunk.cpp
# -rw-r--r--  1 root root   1053 May  8 11:26 compute_ke.h
# -rw-r--r--  1 root root   1959 May  8 11:26 compute_ke.cpp
# -rw-r--r--  1 root root   1150 May  8 11:26 compute_ke_atom.h
# -rw-r--r--  1 root root   3003 May  8 11:26 compute_ke_atom.cpp
# -rw-r--r--  1 root root   1271 May  8 11:26 compute_inertia_chunk.h
# -rw-r--r--  1 root root   5241 May  8 11:26 compute_inertia_chunk.cpp
# -rw-r--r--  1 root root   1312 May  8 11:26 compute_improper_local.h
# -rw-r--r--  1 root root   7624 May  8 11:26 compute_improper_local.cpp
# -rw-r--r--  1 root root   1163 May  8 11:26 compute_improper.h
# -rw-r--r--  1 root root   2493 May  8 11:26 compute_improper.cpp
# -rw-r--r--  1 root root   1540 May  8 11:26 compute_property_chunk.h
# -rw-r--r--  1 root root   6648 May  8 11:26 compute_property_chunk.cpp
# -rw-r--r--  1 root root   3410 May  8 11:26 compute_property_atom.h
# -rw-r--r--  1 root root  54964 May  8 11:26 compute_property_atom.cpp
# -rw-r--r--  1 root root   1613 May  8 11:26 compute_pressure.h
# -rw-r--r--  1 root root  11113 May  8 11:26 compute_pressure.cpp
# -rw-r--r--  1 root root   1123 May  8 11:26 compute_pe.h
# -rw-r--r--  1 root root   3385 May  8 11:26 compute_pe.cpp
# -rw-r--r--  1 root root   1361 May  8 11:26 compute_pe_atom.h
# -rw-r--r--  1 root root   5932 May  8 11:26 compute_pe_atom.cpp
# -rw-r--r--  1 root root   1485 May  8 11:26 compute_pair_local.h
# -rw-r--r--  1 root root  10189 May  8 11:26 compute_pair_local.cpp
# -rw-r--r--  1 root root   1186 May  8 11:26 compute_pair.h
# -rw-r--r--  1 root root   3877 May  8 11:26 compute_pair.cpp
# -rw-r--r--  1 root root   2024 May  8 11:26 compute_orientorder_atom.h
# -rw-r--r--  1 root root   1122 May  8 11:26 compute_reduce_region.h
# -rw-r--r--  1 root root   8022 May  8 11:26 compute_reduce_region.cpp
# -rw-r--r--  1 root root   1886 May  8 11:26 compute_reduce.h
# -rw-r--r--  1 root root  22987 May  8 11:26 compute_reduce.cpp
# -rw-r--r--  1 root root   1599 May  8 11:26 compute_reduce_chunk.h
# -rw-r--r--  1 root root  12217 May  8 11:26 compute_reduce_chunk.cpp
# -rw-r--r--  1 root root   1855 May  8 11:26 compute_rdf.h
# -rw-r--r--  1 root root  12613 May  8 11:26 compute_rdf.cpp
# -rw-r--r--  1 root root   2177 May  8 11:26 compute_property_local.h
# -rw-r--r--  1 root root  29197 May  8 11:26 compute_property_local.cpp
# -rw-r--r--  1 root root   2050 May  8 11:26 compute_property_grid.h
# -rw-r--r--  1 root root  19820 May  8 11:26 compute_property_grid.cpp
# -rw-r--r--  1 root root   1973 May  8 11:26 compute_temp_profile.h
# -rw-r--r--  1 root root  18119 May  8 11:26 compute_temp_profile.cpp
# -rw-r--r--  1 root root   1637 May  8 11:26 compute_temp_partial.h
# -rw-r--r--  1 root root   9363 May  8 11:26 compute_temp_partial.cpp
# -rw-r--r--  1 root root   1186 May  8 11:26 compute_temp.h
# -rw-r--r--  1 root root   1541 May  8 11:26 compute_temp_deform.h
# -rw-r--r--  1 root root   9935 May  8 11:26 compute_temp_deform.cpp
# -rw-r--r--  1 root root   3712 May  8 11:26 compute_temp.cpp
# -rw-r--r--  1 root root   1487 May  8 11:26 compute_temp_com.h
# -rw-r--r--  1 root root   6866 May  8 11:26 compute_temp_com.cpp
# -rw-r--r--  1 root root   1780 May  8 11:26 compute_temp_chunk.h
# -rw-r--r--  1 root root  21649 May  8 11:26 compute_temp_chunk.cpp
# -rw-r--r--  1 root root   1448 May  8 11:26 compute_stress_atom.h
# -rw-r--r--  1 root root  11631 May  8 11:26 compute_stress_atom.cpp
# -rw-r--r--  1 root root   1369 May  8 11:26 compute_slice.h
# -rw-r--r--  1 root root  10790 May  8 11:26 compute_slice.cpp
# -rw-r--r--  1 root root   1235 May  8 11:26 compute_vcm_chunk.h
# -rw-r--r--  1 root root   4324 May  8 11:26 compute_vcm_chunk.cpp
# -rw-r--r--  1 root root   1166 May  8 11:26 compute_vacf.h
# -rw-r--r--  1 root root   3929 May  8 11:26 compute_vacf.cpp
# -rw-r--r--  1 root root   1264 May  8 11:26 compute_torque_chunk.h
# -rw-r--r--  1 root root   5011 May  8 11:26 compute_torque_chunk.cpp
# -rw-r--r--  1 root root   1510 May  8 11:26 compute_temp_sphere.h
# -rw-r--r--  1 root root  10630 May  8 11:26 compute_temp_sphere.cpp
# -rw-r--r--  1 root root   1601 May  8 11:26 compute_temp_region.h
# -rw-r--r--  1 root root   8309 May  8 11:26 compute_temp_region.cpp
# -rw-r--r--  1 root root   1640 May  8 11:26 compute_temp_ramp.h
# -rw-r--r--  1 root root   9917 May  8 11:26 compute_temp_ramp.cpp
# -rw-r--r--  1 root root  20512 May  8 11:26 delete_bonds.cpp
# -rw-r--r--  1 root root   1620 May  8 11:26 delete_atoms.h
# -rw-r--r--  1 root root  29612 May  8 11:26 delete_atoms.cpp
# -rw-r--r--  1 root root    997 May  8 11:26 create_box.h
# -rw-r--r--  1 root root   7213 May  8 11:26 create_box.cpp
# -rw-r--r--  1 root root   1298 May  8 11:26 create_bonds.h
# -rw-r--r--  1 root root  20359 May  8 11:26 create_bonds.cpp
# -rw-r--r--  1 root root   2209 May  8 11:26 create_atoms.h
# -rw-r--r--  1 root root  51100 May  8 11:26 create_atoms.cpp
# -rw-r--r--  1 root root   1377 May  8 11:26 dihedral_zero.h
# -rw-r--r--  1 root root   3640 May  8 11:26 dihedral_zero.cpp
# -rw-r--r--  1 root root   1039 May  8 11:26 dihedral_write.h
# -rw-r--r--  1 root root   8252 May  8 11:26 dihedral_write.cpp
# -rw-r--r--  1 root root   1743 May  8 11:26 dihedral_hybrid.h
# -rw-r--r--  1 root root  12278 May  8 11:26 dihedral_hybrid.cpp
# -rw-r--r--  1 root root   3120 May  8 11:26 dihedral.h
# -rw-r--r--  1 root root   1226 May  8 11:26 dihedral_deprecated.h
# -rw-r--r--  1 root root   1723 May  8 11:26 dihedral_deprecated.cpp
# -rw-r--r--  1 root root  14002 May  8 11:26 dihedral.cpp
# -rw-r--r--  1 root root   1423 May  8 11:26 deprecated.h
# -rw-r--r--  1 root root   2594 May  8 11:26 deprecated.cpp
# -rw-r--r--  1 root root   1009 May  8 11:26 delete_bonds.h
# -rw-r--r--  1 root root   6365 May  8 11:26 domain.h
# -rw-r--r--  1 root root  65742 May  8 11:26 domain.cpp
# -rw-r--r--  1 root root   1183 May  8 11:26 displace_atoms.h
# -rw-r--r--  1 root root  13795 May  8 11:26 displace_atoms.cpp
# -rw-r--r--  1 root root   6957 May  8 11:26 dump.h
# -rw-r--r--  1 root root  42939 May  8 11:26 dump.cpp
# -rw-r--r--  1 root root   1189 May  8 11:26 dump_deprecated.h
# -rw-r--r--  1 root root   1151 May  8 11:26 dump_deprecated.cpp
# -rw-r--r--  1 root root   7093 May  8 11:26 dump_custom.h
# -rw-r--r--  1 root root  92316 May  8 11:26 dump_custom.cpp
# -rw-r--r--  1 root root   1523 May  8 11:26 dump_cfg.h
# -rw-r--r--  1 root root  10078 May  8 11:26 dump_cfg.cpp
# -rw-r--r--  1 root root   2767 May  8 11:26 dump_atom.h
# -rw-r--r--  1 root root  17512 May  8 11:26 dump_atom.cpp
# -rw-r--r--  1 root root   2682 May  8 11:26 dump_local.h
# -rw-r--r--  1 root root  19382 May  8 11:26 dump_local.cpp
# -rw-r--r--  1 root root   4573 May  8 11:26 dump_image.h
# -rw-r--r--  1 root root  54449 May  8 11:26 dump_image.cpp
# -rw-r--r--  1 root root   1245 May  8 11:26 dump_grid_vtk.h
# -rw-r--r--  1 root root   5106 May  8 11:26 dump_grid_vtk.cpp
# -rw-r--r--  1 root root   4005 May  8 11:26 dump_grid.h
# -rw-r--r--  1 root root  27835 May  8 11:26 dump_grid.cpp
# -rw-r--r--  1 root root  13838 May  8 11:26 fix.h
# -rw-r--r--  1 root root  17882 May  8 11:26 fix.cpp
# -rw-r--r--  1 root root    938 May  8 11:26 finish.h
# -rw-r--r--  1 root root  24892 May  8 11:26 finish.cpp
# -rw-r--r--  1 root root   1517 May  8 11:26 file_writer.h
# -rw-r--r--  1 root root   1310 May  8 11:26 exceptions.h
# -rw-r--r--  1 root root   3206 May  8 11:26 error.h
# -rw-r--r--  1 root root  11450 May  8 11:26 error.cpp
# -rw-r--r--  1 root root   1433 May  8 11:26 dump_xyz.h
# -rw-r--r--  1 root root   5513 May  8 11:26 dump_xyz.cpp
# -rw-r--r--  1 root root   1206 May  8 11:26 dump_movie.h
# -rw-r--r--  1 root root   3070 May  8 11:26 dump_movie.cpp
# -rw-r--r--  1 root root   2545 May  8 11:26 fix_ave_chunk.h
# -rw-r--r--  1 root root  37260 May  8 11:26 fix_ave_chunk.cpp
# -rw-r--r--  1 root root   1722 May  8 11:26 fix_ave_atom.h
# -rw-r--r--  1 root root  14119 May  8 11:26 fix_ave_atom.cpp
# -rw-r--r--  1 root root   1641 May  8 11:26 fix_addforce.h
# -rw-r--r--  1 root root  12454 May  8 11:26 fix_addforce.cpp
# -rw-r--r--  1 root root   2176 May  8 11:26 fix_adapt.h
# -rw-r--r--  1 root root  25422 May  8 11:26 fix_adapt.cpp
# -rw-r--r--  1 root root  33534 May  8 11:26 fix_ave_histo.cpp
# -rw-r--r--  1 root root   3609 May  8 11:26 fix_ave_grid.h
# -rw-r--r--  1 root root  72739 May  8 11:26 fix_ave_grid.cpp
# -rw-r--r--  1 root root   2098 May  8 11:26 fix_ave_correlate.h
# -rw-r--r--  1 root root  19823 May  8 11:26 fix_ave_correlate.cpp
# -rw-r--r--  1 root root  11250 May  8 11:26 fix_bond_history.cpp
# -rw-r--r--  1 root root   2003 May  8 11:26 fix_balance.h
# -rw-r--r--  1 root root  10790 May  8 11:26 fix_balance.cpp
# -rw-r--r--  1 root root   2491 May  8 11:26 fix_ave_time.h
# -rw-r--r--  1 root root  39269 May  8 11:26 fix_ave_time.cpp
# -rw-r--r--  1 root root   1225 May  8 11:26 fix_ave_histo_weight.h
# -rw-r--r--  1 root root  18202 May  8 11:26 fix_ave_histo_weight.cpp
# -rw-r--r--  1 root root   2131 May  8 11:26 fix_ave_histo.h
# -rw-r--r--  1 root root   1498 May  8 11:26 fix_aveforce.h
# -rw-r--r--  1 root root   9037 May  8 11:26 fix_aveforce.cpp
# -rw-r--r--  1 root root   2617 May  8 11:26 fix_deprecated.cpp
# -rw-r--r--  1 root root   1972 May  8 11:26 fix_deposit.h
# -rw-r--r--  1 root root  29965 May  8 11:26 fix_deposit.cpp
# -rw-r--r--  1 root root   2249 May  8 11:26 fix_deform.h
# -rw-r--r--  1 root root  37949 May  8 11:26 fix_deform.cpp
# -rw-r--r--  1 root root   2973 May  8 11:26 fix_box_relax.h
# -rw-r--r--  1 root root  33106 May  8 11:26 fix_box_relax.cpp
# -rw-r--r--  1 root root   2173 May  8 11:26 fix_bond_history.h
# -rw-r--r--  1 root root  10869 May  8 11:26 fix_gravity.cpp
# -rw-r--r--  1 root root   2092 May  8 11:26 fix_external.h
# -rw-r--r--  1 root root  12290 May  8 11:26 fix_external.cpp
# -rw-r--r--  1 root root   1314 May  8 11:26 fix_evaporate.h
# -rw-r--r--  1 root root  12631 May  8 11:26 fix_evaporate.cpp
# -rw-r--r--  1 root root   1277 May  8 11:26 fix_enforce2d.h
# -rw-r--r--  1 root root   4567 May  8 11:26 fix_enforce2d.cpp
# -rw-r--r--  1 root root   1729 May  8 11:26 fix_efield.h
# -rw-r--r--  1 root root  13994 May  8 11:26 fix_efield.cpp
# -rw-r--r--  1 root root   1145 May  8 11:26 fix_dummy.h
# -rw-r--r--  1 root root   2679 May  8 11:26 fix_dummy.cpp
# -rw-r--r--  1 root root   1263 May  8 11:26 fix_dt_reset.h
# -rw-r--r--  1 root root   6007 May  8 11:26 fix_dt_reset.cpp
# -rw-r--r--  1 root root   1284 May  8 11:26 fix_deprecated.h
# -rw-r--r--  1 root root  10373 May  8 11:26 fix_heat.cpp
# -rw-r--r--  1 root root   1320 May  8 11:26 fix_halt.h
# -rw-r--r--  1 root root  10501 May  8 11:26 fix_halt.cpp
# -rw-r--r--  1 root root   1506 May  8 11:26 fix_group.h
# -rw-r--r--  1 root root   8414 May  8 11:26 fix_group.cpp
# -rw-r--r--  1 root root   1745 May  8 11:26 fix_gravity.h
# -rw-r--r--  1 root root   2645 May  8 11:26 fix_move.h
# -rw-r--r--  1 root root  47871 May  8 11:26 fix_move.cpp
# -rw-r--r--  1 root root   1137 May  8 11:26 fix_momentum.h
# -rw-r--r--  1 root root   5919 May  8 11:26 fix_momentum.cpp
# -rw-r--r--  1 root root   1499 May  8 11:26 fix_minimize.h
# -rw-r--r--  1 root root   6775 May  8 11:26 fix_minimize.cpp
# -rw-r--r--  1 root root   1213 May  8 11:26 fix_lineforce.h
# -rw-r--r--  1 root root   3092 May  8 11:26 fix_lineforce.cpp
# -rw-r--r--  1 root root   2448 May  8 11:26 fix_langevin.h
# -rw-r--r--  1 root root  37650 May  8 11:26 fix_langevin.cpp
# -rw-r--r--  1 root root   1609 May  8 11:26 fix_indent.h
# -rw-r--r--  1 root root  15715 May  8 11:26 fix_indent.cpp
# -rw-r--r--  1 root root   1309 May  8 11:26 fix_heat.h
# -rw-r--r--  1 root root    991 May  8 11:26 fix_npt_sphere.h
# -rw-r--r--  1 root root   1756 May  8 11:26 fix_npt_sphere.cpp
# -rw-r--r--  1 root root    939 May  8 11:26 fix_npt.h
# -rw-r--r--  1 root root   1710 May  8 11:26 fix_npt.cpp
# -rw-r--r--  1 root root    991 May  8 11:26 fix_nph_sphere.h
# -rw-r--r--  1 root root   1758 May  8 11:26 fix_nph_sphere.cpp
# -rw-r--r--  1 root root    939 May  8 11:26 fix_nph.h
# -rw-r--r--  1 root root   1712 May  8 11:26 fix_nph.cpp
# -rw-r--r--  1 root root   1005 May  8 11:26 fix_nh_sphere.h
# -rw-r--r--  1 root root   8698 May  8 11:26 fix_nh_sphere.cpp
# -rw-r--r--  1 root root   5222 May  8 11:26 fix_nh.h
# -rw-r--r--  1 root root  74278 May  8 11:26 fix_nh.cpp
# -rw-r--r--  1 root root   3666 May  8 11:26 fix_neigh_history.h
# -rw-r--r--  1 root root  29068 May  8 11:26 fix_neigh_history.cpp
# -rw-r--r--  1 root root   3106 May  8 11:26 fix_planeforce.cpp
# -rw-r--r--  1 root root   1697 May  8 11:26 fix_pair.h
# -rw-r--r--  1 root root  11061 May  8 11:26 fix_pair.cpp
# -rw-r--r--  1 root root    991 May  8 11:26 fix_nvt_sphere.h
# -rw-r--r--  1 root root   1367 May  8 11:26 fix_nvt_sphere.cpp
# -rw-r--r--  1 root root   1112 May  8 11:26 fix_nvt_sllod.h
# -rw-r--r--  1 root root   4248 May  8 11:26 fix_nvt_sllod.cpp
# -rw-r--r--  1 root root    939 May  8 11:26 fix_nvt.h
# -rw-r--r--  1 root root   1321 May  8 11:26 fix_nvt.cpp
# -rw-r--r--  1 root root   1135 May  8 11:26 fix_nve_sphere.h
# -rw-r--r--  1 root root   9423 May  8 11:26 fix_nve_sphere.cpp
# -rw-r--r--  1 root root   1202 May  8 11:26 fix_nve_noforce.h
# -rw-r--r--  1 root root   2396 May  8 11:26 fix_nve_noforce.cpp
# -rw-r--r--  1 root root   1354 May  8 11:26 fix_nve_limit.h
# -rw-r--r--  1 root root   6463 May  8 11:26 fix_nve_limit.cpp
# -rw-r--r--  1 root root   1267 May  8 11:26 fix_nve.h
# -rw-r--r--  1 root root   4566 May  8 11:26 fix_nve.cpp
# -rw-r--r--  1 root root   1390 May  8 11:26 fix_recenter.h
# -rw-r--r--  1 root root   6658 May  8 11:26 fix_recenter.cpp
# -rw-r--r--  1 root root   1350 May  8 11:26 fix_read_restart.h
# -rw-r--r--  1 root root   3884 May  8 11:26 fix_read_restart.cpp
# -rw-r--r--  1 root root   2495 May  8 11:26 fix_property_atom.h
# -rw-r--r--  1 root root  32793 May  8 11:26 fix_property_atom.cpp
# -rw-r--r--  1 root root   1234 May  8 11:26 fix_print.h
# -rw-r--r--  1 root root   5416 May  8 11:26 fix_print.cpp
# -rw-r--r--  1 root root   1738 May  8 11:26 fix_press_berendsen.h
# -rw-r--r--  1 root root  16543 May  8 11:26 fix_press_berendsen.cpp
# -rw-r--r--  1 root root   1219 May  8 11:26 fix_planeforce.h
# -rw-r--r--  1 root root   1764 May  8 11:26 fix_spring_self.h
# -rw-r--r--  1 root root   8984 May  8 11:26 fix_spring_self.cpp
# -rw-r--r--  1 root root   1552 May  8 11:26 fix_spring.h
# -rw-r--r--  1 root root   9692 May  8 11:26 fix_spring.cpp
# -rw-r--r--  1 root root   1552 May  8 11:26 fix_spring_chunk.h
# -rw-r--r--  1 root root   8214 May  8 11:26 fix_spring_chunk.cpp
# -rw-r--r--  1 root root   1624 May  8 11:26 fix_setforce.h
# -rw-r--r--  1 root root  10611 May  8 11:26 fix_setforce.cpp
# -rw-r--r--  1 root root   1752 May  8 11:26 fix_restrain.h
# -rw-r--r--  1 root root  22210 May  8 11:26 fix_restrain.cpp
# -rw-r--r--  1 root root   1515 May  8 11:26 fix_respa.h
# -rw-r--r--  1 root root   4548 May  8 11:26 fix_respa.cpp
# -rw-r--r--  1 root root   1538 May  8 11:26 fix_temp_rescale.h
# -rw-r--r--  1 root root   7947 May  8 11:26 fix_temp_rescale.cpp
# -rw-r--r--  1 root root   1531 May  8 11:26 fix_temp_berendsen.h
# -rw-r--r--  1 root root   7722 May  8 11:26 fix_temp_berendsen.cpp
# -rw-r--r--  1 root root   3214 May  8 11:26 fix_store_state.h
# -rw-r--r--  1 root root  44383 May  8 11:26 fix_store_state.cpp
# -rw-r--r--  1 root root   1266 May  8 11:26 fix_store_local.h
# -rw-r--r--  1 root root   3333 May  8 11:26 fix_store_local.cpp
# -rw-r--r--  1 root root   1546 May  8 11:26 fix_store_global.h
# -rw-r--r--  1 root root   5487 May  8 11:26 fix_store_global.cpp
# -rw-r--r--  1 root root   1365 May  8 11:26 fix_store_force.h
# -rw-r--r--  1 root root   3993 May  8 11:26 fix_store_force.cpp
# -rw-r--r--  1 root root   2145 May  8 11:26 fix_store_atom.h
# -rw-r--r--  1 root root   9201 May  8 11:26 fix_store_atom.cpp
# -rw-r--r--  1 root root   1106 May  8 11:26 fix_wall_morse.h
# -rw-r--r--  1 root root   2643 May  8 11:26 fix_wall_morse.cpp
# -rw-r--r--  1 root root   1135 May  8 11:26 fix_wall_lj93.h
# -rw-r--r--  1 root root   3002 May  8 11:26 fix_wall_lj93.cpp
# -rw-r--r--  1 root root   1139 May  8 11:26 fix_wall_lj126.h
# -rw-r--r--  1 root root   2925 May  8 11:26 fix_wall_lj126.cpp
# -rw-r--r--  1 root root   1178 May  8 11:26 fix_wall_lj1043.h
# -rw-r--r--  1 root root   3161 May  8 11:26 fix_wall_lj1043.cpp
# -rw-r--r--  1 root root   1084 May  8 11:26 fix_wall_harmonic.h
# -rw-r--r--  1 root root   2249 May  8 11:26 fix_wall_harmonic.cpp
# -rw-r--r--  1 root root   1894 May  8 11:26 fix_wall.h
# -rw-r--r--  1 root root  13733 May  8 11:26 fix_wall.cpp
# -rw-r--r--  1 root root   1263 May  8 11:26 fix_viscous.h
# -rw-r--r--  1 root root   4067 May  8 11:26 fix_viscous.cpp
# -rw-r--r--  1 root root   1568 May  8 11:26 fix_vector.h
# -rw-r--r--  1 root root  10097 May  8 11:26 fix_vector.cpp
# -rw-r--r--  1 root root   1739 May  8 11:26 fix_update_special_bonds.h
# -rw-r--r--  1 root root   8318 May  8 11:26 fix_update_special_bonds.cpp
# -rw-r--r--  1 root root   1425 May  8 11:26 fix_thermal_conductivity.h
# -rw-r--r--  1 root root  10893 May  8 11:26 fix_thermal_conductivity.cpp
# -rw-r--r--  1 root root   1874 May  8 11:26 fix_wall_table.h
# -rw-r--r--  1 root root  15001 May  8 11:26 fix_wall_table.cpp
# -rw-r--r--  1 root root   1743 May  8 11:26 fix_wall_region.h
# -rw-r--r--  1 root root  14198 May  8 11:26 fix_wall_region.cpp
# -rw-r--r--  1 root root   1441 May  8 11:26 fix_wall_reflect.h
# -rw-r--r--  1 root root   7599 May  8 11:26 fix_wall_reflect.cpp
# -rw-r--r--  1 root root  10891 May  8 11:26 fmtlib_os.cpp
# -rw-r--r--  1 root root   1533 May  8 11:26 fmtlib_format.cpp
# drwxr-xr-x  2 root root   4096 May  8 11:26 fmt
# -rw-r--r--  1 root root  73274 May  8 11:26 grid3d.cpp
# -rw-r--r--  1 root root   9282 May  8 11:26 grid2d.h
# -rw-r--r--  1 root root  66087 May  8 11:26 grid2d.cpp
# -rw-r--r--  1 root root   5446 May  8 11:26 force.h
# -rw-r--r--  1 root root  26372 May  8 11:26 force.cpp
# -rw-r--r--  1 root root    306 May  8 11:26 hashlittle.h
# -rw-r--r--  1 root root  12382 May  8 11:26 hashlittle.cpp
# -rw-r--r--  1 root root   3221 May  8 11:26 group.h
# -rw-r--r--  1 root root  53039 May  8 11:26 group.cpp
# -rw-r--r--  1 root root   9527 May  8 11:26 grid3d.h
# -rw-r--r--  1 root root   1303 May  8 11:26 imbalance_neigh.h
# -rw-r--r--  1 root root   3323 May  8 11:26 imbalance_neigh.cpp
# -rw-r--r--  1 root root   1514 May  8 11:26 imbalance.h
# -rw-r--r--  1 root root   1344 May  8 11:26 imbalance_group.h
# -rw-r--r--  1 root root   2678 May  8 11:26 imbalance_group.cpp
# -rw-r--r--  1 root root    822 May  8 11:26 imbalance.cpp
# -rw-r--r--  1 root root   5015 May  8 11:26 image.h
# -rw-r--r--  1 root root  63363 May  8 11:26 image.cpp
# -rw-r--r--  1 root root   1283 May  8 11:26 improper_zero.h
# -rw-r--r--  1 root root   3640 May  8 11:26 improper_zero.cpp
# -rw-r--r--  1 root root   1743 May  8 11:26 improper_hybrid.h
# -rw-r--r--  1 root root  11757 May  8 11:26 improper_hybrid.cpp
# -rw-r--r--  1 root root   3384 May  8 11:26 improper.h
# -rw-r--r--  1 root root   1226 May  8 11:26 improper_deprecated.h
# -rw-r--r--  1 root root   1723 May  8 11:26 improper_deprecated.cpp
# -rw-r--r--  1 root root  13807 May  8 11:26 improper.cpp
# -rw-r--r--  1 root root   1355 May  8 11:26 imbalance_var.h
# -rw-r--r--  1 root root   2556 May  8 11:26 imbalance_var.cpp
# -rw-r--r--  1 root root   1344 May  8 11:26 imbalance_time.h
# -rw-r--r--  1 root root   3638 May  8 11:26 imbalance_time.cpp
# -rw-r--r--  1 root root   1251 May  8 11:26 imbalance_store.h
# -rw-r--r--  1 root root   1919 May  8 11:26 imbalance_store.cpp
# -rw-r--r--  1 root root   2437 May  8 11:26 info.h
# -rw-r--r--  1 root root  42970 May  8 11:26 info.cpp
# -rw-r--r--  1 root root   3738 May  8 11:26 irregular.h
# -rw-r--r--  1 root root  32210 May  8 11:26 irregular.cpp
# -rw-r--r--  1 root root   1863 May  8 11:26 integrate.h
# -rw-r--r--  1 root root   6618 May  8 11:26 integrate.cpp
# -rw-r--r--  1 root root   4520 May  8 11:26 input.h
# -rw-r--r--  1 root root  60424 May  8 11:26 input.cpp
# -rw-r--r--  1 root root  20592 May  8 11:26 lattice.cpp
# -rw-r--r--  1 root root   1449 May  8 11:26 lammpsplugin.h
# -rw-r--r--  1 root root   4415 May  8 11:26 lammps.h
# -rw-r--r--  1 root root  49381 May  8 11:26 lammps.cpp
# -rw-r--r--  1 root root   2675 May  8 11:26 label_map.h
# -rw-r--r--  1 root root  16943 May  8 11:26 label_map.cpp
# -rw-r--r--  1 root root   8007 May  8 11:26 kspace.h
# -rw-r--r--  1 root root   1139 May  8 11:26 kspace_deprecated.h
# -rw-r--r--  1 root root   1349 May  8 11:26 kspace_deprecated.cpp
# -rw-r--r--  1 root root  22024 May  8 11:26 kspace.cpp
# -rw-r--r--  1 root root 224658 May  8 11:26 library.cpp
# -rw-r--r--  1 root root   2192 May  8 11:26 lattice.h
# -rw-r--r--  1 root root   2687 May  8 11:26 math_eigen.cpp
# -rw-r--r--  1 root root   2150 May  8 11:26 math_const.h
# -rw-r--r--  1 root root   3191 May  8 11:26 main.cpp
# -rw-r--r--  1 root root   1499 May  8 11:26 lmpwindows.h
# -rw-r--r--  1 root root   7936 May  8 11:26 lmptype.h
# -rw-r--r--  1 root root   1726 May  8 11:26 lmprestart.h
# -rw-r--r--  1 root root   1715 May  8 11:26 lmppython.h
# -rw-r--r--  1 root root   3185 May  8 11:26 lmppython.cpp
# -rw-r--r--  1 root root   1427 May  8 11:26 lmpfftsettings.h
# -rw-r--r--  1 root root  13131 May  8 11:26 library.h
# -rw-r--r--  1 root root  39226 May  8 11:26 math_special.cpp
# -rw-r--r--  1 root root  30284 May  8 11:26 math_extra.h
# -rw-r--r--  1 root root  21469 May  8 11:26 math_extra.cpp
# -rw-r--r--  1 root root  47701 May  8 11:26 math_eigen_impl.h
# -rw-r--r--  1 root root   1278 May  8 11:26 math_eigen.h
# -rw-r--r--  1 root root   5398 May  8 11:26 min.h
# -rw-r--r--  1 root root   1242 May  8 11:26 min_fire.h
# -rw-r--r--  1 root root  19583 May  8 11:26 min_fire.cpp
# -rw-r--r--  1 root root   1146 May  8 11:26 min_deprecated.h
# -rw-r--r--  1 root root   1587 May  8 11:26 min_deprecated.cpp
# -rw-r--r--  1 root root  33856 May  8 11:26 min.cpp
# -rw-r--r--  1 root root    974 May  8 11:26 min_cg.h
# -rw-r--r--  1 root root   5675 May  8 11:26 min_cg.cpp
# -rw-r--r--  1 root root  31610 May  8 11:26 memory.h
# -rw-r--r--  1 root root   3746 May  8 11:26 memory.cpp
# -rw-r--r--  1 root root   5982 May  8 11:26 math_special.h
# -rw-r--r--  1 root root   3357 May  8 11:26 min_sd.cpp
# -rw-r--r--  1 root root   1126 May  8 11:26 min_quickmin.h
# -rw-r--r--  1 root root   7061 May  8 11:26 min_quickmin.cpp
# -rw-r--r--  1 root root   1732 May  8 11:26 min_linesearch.h
# -rw-r--r--  1 root root  27719 May  8 11:26 min_linesearch.cpp
# -rw-r--r--  1 root root   3969 May  8 11:26 min_hftn.h
# -rw-r--r--  1 root root  59005 May  8 11:26 min_hftn.cpp
# -rw-r--r--  1 root root   1406 May  8 11:26 mpiio.h
# -rw-r--r--  1 root root   5367 May  8 11:26 molecule.h
# -rw-r--r--  1 root root  74931 May  8 11:26 molecule.cpp
# -rw-r--r--  1 root root   7493 May  8 11:26 modify.h
# -rw-r--r--  1 root root  63346 May  8 11:26 modify.cpp
# -rw-r--r--  1 root root    974 May  8 11:26 min_sd.h
# -rw-r--r--  1 root root    988 May  8 11:26 minimize.h
# -rw-r--r--  1 root root   2489 May  8 11:26 minimize.cpp
# -rw-r--r--  1 root root   4880 May  8 11:26 neigh_list.h
# -rw-r--r--  1 root root   9570 May  8 11:26 neigh_list.cpp
# -rw-r--r--  1 root root   1128 May  8 11:26 nbin_standard.h
# -rw-r--r--  1 root root   9089 May  8 11:26 nbin_standard.cpp
# -rw-r--r--  1 root root   1107 May  8 11:26 nbin_multi.h
# -rw-r--r--  1 root root  12989 May  8 11:26 nbin_multi.cpp
# -rw-r--r--  1 root root   2851 May  8 11:26 nbin.h
# -rw-r--r--  1 root root   6832 May  8 11:26 nbin.cpp
# -rw-r--r--  1 root root   2583 May  8 11:26 my_pool_chunk.h
# -rw-r--r--  1 root root   6632 May  8 11:26 my_pool_chunk.cpp
# -rw-r--r--  1 root root   3433 May  8 11:26 my_page.h
# -rw-r--r--  1 root root   5903 May  8 11:26 my_page.cpp
# -rw-r--r--  1 root root   5278 May  8 11:26 neigh_request.h
# -rw-r--r--  1 root root   8838 May  8 11:26 neigh_request.cpp
# -rw-r--r--  1 root root  96429 May  8 11:26 neighbor.cpp
# -rw-r--r--  1 root root   9454 May  8 11:26 npair.cpp
# -rw-r--r--  1 root root  12795 May  8 11:26 neighbor.h
# -rw-r--r--  1 root root   1175 May  8 11:26 npair_half_bin_atomonly_newton.h
# -rw-r--r--  1 root root   3525 May  8 11:26 npair_half_bin_atomonly_newton.cpp
# -rw-r--r--  1 root root   4936 May  8 11:26 npair.h
# -rw-r--r--  1 root root   1093 May  8 11:26 npair_full_nsq.h
# -rw-r--r--  1 root root   1148 May  8 11:26 npair_full_nsq_ghost.h
# -rw-r--r--  1 root root   4292 May  8 11:26 npair_full_nsq_ghost.cpp
# -rw-r--r--  1 root root   3822 May  8 11:26 npair_full_nsq.cpp
# -rw-r--r--  1 root root   1132 May  8 11:26 npair_full_multi_old.h
# -rw-r--r--  1 root root   4158 May  8 11:26 npair_full_multi_old.cpp
# -rw-r--r--  1 root root   1107 May  8 11:26 npair_full_multi.h
# -rw-r--r--  1 root root   4625 May  8 11:26 npair_full_multi.cpp
# -rw-r--r--  1 root root   1117 May  8 11:26 npair_full_bin.h
# -rw-r--r--  1 root root   1148 May  8 11:26 npair_full_bin_ghost.h
# -rw-r--r--  1 root root   5020 May  8 11:26 npair_full_bin_ghost.cpp
# -rw-r--r--  1 root root   3863 May  8 11:26 npair_full_bin.cpp
# -rw-r--r--  1 root root   1169 May  8 11:26 npair_full_bin_atomonly.h
# -rw-r--r--  1 root root   2700 May  8 11:26 npair_full_bin_atomonly.cpp
# -rw-r--r--  1 root root   1018 May  8 11:26 npair_copy.h
# -rw-r--r--  1 root root   1344 May  8 11:26 npair_copy.cpp
# -rw-r--r--  1 root root   5581 May  8 11:26 npair_half_multi_old_newton.cpp
# -rw-r--r--  1 root root   1165 May  8 11:26 npair_half_multi_old_newtoff.h
# -rw-r--r--  1 root root   4395 May  8 11:26 npair_half_multi_old_newtoff.cpp
# -rw-r--r--  1 root root   1143 May  8 11:26 npair_half_multi_newton_tri.h
# -rw-r--r--  1 root root   5456 May  8 11:26 npair_half_multi_newton_tri.cpp
# -rw-r--r--  1 root root   1124 May  8 11:26 npair_half_multi_newton.h
# -rw-r--r--  1 root root   6819 May  8 11:26 npair_half_multi_newton.cpp
# -rw-r--r--  1 root root   1140 May  8 11:26 npair_half_multi_newtoff.h
# -rw-r--r--  1 root root   4790 May  8 11:26 npair_half_multi_newtoff.cpp
# -rw-r--r--  1 root root   1129 May  8 11:26 npair_half_bin_newton_tri.h
# -rw-r--r--  1 root root   4331 May  8 11:26 npair_half_bin_newton_tri.cpp
# -rw-r--r--  1 root root   1123 May  8 11:26 npair_half_bin_newton.h
# -rw-r--r--  1 root root   5374 May  8 11:26 npair_half_bin_newton.cpp
# -rw-r--r--  1 root root   1126 May  8 11:26 npair_half_bin_newtoff.h
# -rw-r--r--  1 root root   1170 May  8 11:26 npair_half_bin_newtoff_ghost.h
# -rw-r--r--  1 root root   5387 May  8 11:26 npair_half_bin_newtoff_ghost.cpp
# -rw-r--r--  1 root root   4154 May  8 11:26 npair_half_bin_newtoff.cpp
# -rw-r--r--  1 root root   5671 May  8 11:26 npair_half_size_bin_newton.cpp
# -rw-r--r--  1 root root   1163 May  8 11:26 npair_half_size_bin_newtoff.h
# -rw-r--r--  1 root root   4367 May  8 11:26 npair_half_size_bin_newtoff.cpp
# -rw-r--r--  1 root root   1154 May  8 11:26 npair_half_respa_nsq_newton.h
# -rw-r--r--  1 root root   6372 May  8 11:26 npair_half_respa_nsq_newton.cpp
# -rw-r--r--  1 root root   1170 May  8 11:26 npair_half_respa_nsq_newtoff.h
# -rw-r--r--  1 root root   5878 May  8 11:26 npair_half_respa_nsq_newtoff.cpp
# -rw-r--r--  1 root root   1173 May  8 11:26 npair_half_respa_bin_newton_tri.h
# -rw-r--r--  1 root root   6411 May  8 11:26 npair_half_respa_bin_newton_tri.cpp
# -rw-r--r--  1 root root   1154 May  8 11:26 npair_half_respa_bin_newton.h
# -rw-r--r--  1 root root   7882 May  8 11:26 npair_half_respa_bin_newton.cpp
# -rw-r--r--  1 root root   1170 May  8 11:26 npair_half_respa_bin_newtoff.h
# -rw-r--r--  1 root root   6142 May  8 11:26 npair_half_respa_bin_newtoff.cpp
# -rw-r--r--  1 root root   1119 May  8 11:26 npair_half_nsq_newton.h
# -rw-r--r--  1 root root   4355 May  8 11:26 npair_half_nsq_newton.cpp
# -rw-r--r--  1 root root   1126 May  8 11:26 npair_half_nsq_newtoff.h
# -rw-r--r--  1 root root   1170 May  8 11:26 npair_half_nsq_newtoff_ghost.h
# -rw-r--r--  1 root root   4825 May  8 11:26 npair_half_nsq_newtoff_ghost.cpp
# -rw-r--r--  1 root root   3907 May  8 11:26 npair_half_nsq_newtoff.cpp
# -rw-r--r--  1 root root   1168 May  8 11:26 npair_half_multi_old_newton_tri.h
# -rw-r--r--  1 root root   4751 May  8 11:26 npair_half_multi_old_newton_tri.cpp
# -rw-r--r--  1 root root   1149 May  8 11:26 npair_half_multi_old_newton.h
# -rw-r--r--  1 root root   1156 May  8 11:26 npair_half_size_nsq_newton.h
# -rw-r--r--  1 root root   4621 May  8 11:26 npair_half_size_nsq_newton.cpp
# -rw-r--r--  1 root root   1163 May  8 11:26 npair_half_size_nsq_newtoff.h
# -rw-r--r--  1 root root   4172 May  8 11:26 npair_half_size_nsq_newtoff.cpp
# -rw-r--r--  1 root root   1205 May  8 11:26 npair_half_size_multi_old_newton_tri.h
# -rw-r--r--  1 root root   5102 May  8 11:26 npair_half_size_multi_old_newton_tri.cpp
# -rw-r--r--  1 root root   1186 May  8 11:26 npair_half_size_multi_old_newton.h
# -rw-r--r--  1 root root   6064 May  8 11:26 npair_half_size_multi_old_newton.cpp
# -rw-r--r--  1 root root   1202 May  8 11:26 npair_half_size_multi_old_newtoff.h
# -rw-r--r--  1 root root   4764 May  8 11:26 npair_half_size_multi_old_newtoff.cpp
# -rw-r--r--  1 root root   1180 May  8 11:26 npair_half_size_multi_newton_tri.h
# -rw-r--r--  1 root root   5855 May  8 11:26 npair_half_size_multi_newton_tri.cpp
# -rw-r--r--  1 root root   1161 May  8 11:26 npair_half_size_multi_newton.h
# -rw-r--r--  1 root root   7206 May  8 11:26 npair_half_size_multi_newton.cpp
# -rw-r--r--  1 root root   1177 May  8 11:26 npair_half_size_multi_newtoff.h
# -rw-r--r--  1 root root   5154 May  8 11:26 npair_half_size_multi_newtoff.cpp
# -rw-r--r--  1 root root   1166 May  8 11:26 npair_half_size_bin_newton_tri.h
# -rw-r--r--  1 root root   4637 May  8 11:26 npair_half_size_bin_newton_tri.cpp
# -rw-r--r--  1 root root   1147 May  8 11:26 npair_half_size_bin_newton.h
# -rw-r--r--  1 root root   1909 May  8 11:26 npair_halffull_newtoff_trim.h
# -rw-r--r--  1 root root   3027 May  8 11:26 npair_halffull_newtoff_trim.cpp
# -rw-r--r--  1 root root   1815 May  8 11:26 npair_halffull_newtoff.h
# -rw-r--r--  1 root root   2581 May  8 11:26 npair_halffull_newtoff.cpp
# -rw-r--r--  1 root root   4135 May  8 11:26 nstencil.h
# -rw-r--r--  1 root root   1268 May  8 11:26 nstencil_full_bin_2d.cpp
# -rw-r--r--  1 root root  15894 May  8 11:26 nstencil.cpp
# -rw-r--r--  1 root root   1028 May  8 11:26 npair_trim.h
# -rw-r--r--  1 root root   2588 May  8 11:26 npair_trim.cpp
# -rw-r--r--  1 root root   1285 May  8 11:26 npair_skip_size_off2on_oneside.h
# -rw-r--r--  1 root root   4680 May  8 11:26 npair_skip_size_off2on_oneside.cpp
# -rw-r--r--  1 root root   1227 May  8 11:26 npair_skip_size_off2on.h
# -rw-r--r--  1 root root   2910 May  8 11:26 npair_skip_size_off2on.cpp
# -rw-r--r--  1 root root   1180 May  8 11:26 npair_skip_size.h
# -rw-r--r--  1 root root   2563 May  8 11:26 npair_skip_size.cpp
# -rw-r--r--  1 root root   1198 May  8 11:26 npair_skip_respa.h
# -rw-r--r--  1 root root   5002 May  8 11:26 npair_skip_respa.cpp
# -rw-r--r--  1 root root   1358 May  8 11:26 npair_skip.h
# -rw-r--r--  1 root root   2981 May  8 11:26 npair_skip.cpp
# -rw-r--r--  1 root root   1438 May  8 11:26 npair_halffull_newton_trim.h
# -rw-r--r--  1 root root   3036 May  8 11:26 npair_halffull_newton_trim.cpp
# -rw-r--r--  1 root root   1382 May  8 11:26 npair_halffull_newton.h
# -rw-r--r--  1 root root   2748 May  8 11:26 npair_halffull_newton.cpp
# -rw-r--r--  1 root root   1388 May  8 11:26 nstencil_half_bin_3d.cpp
# -rw-r--r--  1 root root   1118 May  8 11:26 nstencil_half_bin_2d_tri.h
# -rw-r--r--  1 root root   1279 May  8 11:26 nstencil_half_bin_2d_tri.cpp
# -rw-r--r--  1 root root   1099 May  8 11:26 nstencil_half_bin_2d.h
# -rw-r--r--  1 root root   1306 May  8 11:26 nstencil_half_bin_2d.cpp
# -rw-r--r--  1 root root   1147 May  8 11:26 nstencil_full_multi_old_3d.h
# -rw-r--r--  1 root root   1710 May  8 11:26 nstencil_full_multi_old_3d.cpp
# -rw-r--r--  1 root root   1147 May  8 11:26 nstencil_full_multi_old_2d.h
# -rw-r--r--  1 root root   1639 May  8 11:26 nstencil_full_multi_old_2d.cpp
# -rw-r--r--  1 root root   1163 May  8 11:26 nstencil_full_multi_3d.h
# -rw-r--r--  1 root root   2769 May  8 11:26 nstencil_full_multi_3d.cpp
# -rw-r--r--  1 root root   1163 May  8 11:26 nstencil_full_multi_2d.h
# -rw-r--r--  1 root root   2551 May  8 11:26 nstencil_full_multi_2d.cpp
# -rw-r--r--  1 root root   1152 May  8 11:26 nstencil_full_ghost_bin_3d.h
# -rw-r--r--  1 root root   1503 May  8 11:26 nstencil_full_ghost_bin_3d.cpp
# -rw-r--r--  1 root root   1152 May  8 11:26 nstencil_full_ghost_bin_2d.h
# -rw-r--r--  1 root root   1434 May  8 11:26 nstencil_full_ghost_bin_2d.cpp
# -rw-r--r--  1 root root   1108 May  8 11:26 nstencil_full_bin_3d.h
# -rw-r--r--  1 root root   1337 May  8 11:26 nstencil_full_bin_3d.cpp
# -rw-r--r--  1 root root   1108 May  8 11:26 nstencil_full_bin_2d.h
# -rw-r--r--  1 root root   1124 May  8 11:26 nstencil_half_multi_old_3d.h
# -rw-r--r--  1 root root   1771 May  8 11:26 nstencil_half_multi_old_3d.cpp
# -rw-r--r--  1 root root   1143 May  8 11:26 nstencil_half_multi_old_2d_tri.h
# -rw-r--r--  1 root root   1650 May  8 11:26 nstencil_half_multi_old_2d_tri.cpp
# -rw-r--r--  1 root root   1124 May  8 11:26 nstencil_half_multi_old_2d.h
# -rw-r--r--  1 root root   1689 May  8 11:26 nstencil_half_multi_old_2d.cpp
# -rw-r--r--  1 root root   1173 May  8 11:26 nstencil_half_multi_3d_tri.h
# -rw-r--r--  1 root root   3507 May  8 11:26 nstencil_half_multi_3d_tri.cpp
# -rw-r--r--  1 root root   1154 May  8 11:26 nstencil_half_multi_3d.h
# -rw-r--r--  1 root root   3569 May  8 11:26 nstencil_half_multi_3d.cpp
# -rw-r--r--  1 root root   1173 May  8 11:26 nstencil_half_multi_2d_tri.h
# -rw-r--r--  1 root root   3261 May  8 11:26 nstencil_half_multi_2d_tri.cpp
# -rw-r--r--  1 root root   1154 May  8 11:26 nstencil_half_multi_2d.h
# -rw-r--r--  1 root root   3309 May  8 11:26 nstencil_half_multi_2d.cpp
# -rw-r--r--  1 root root   1118 May  8 11:26 nstencil_half_bin_3d_tri.h
# -rw-r--r--  1 root root   1348 May  8 11:26 nstencil_half_bin_3d_tri.cpp
# -rw-r--r--  1 root root   1099 May  8 11:26 nstencil_half_bin_3d.h
# -rw-r--r--  1 root root   3322 May  8 11:26 ntopo_improper_all.cpp
# -rw-r--r--  1 root root   1414 May  8 11:26 ntopo.h
# -rw-r--r--  1 root root   1048 May  8 11:26 ntopo_dihedral_template.h
# -rw-r--r--  1 root root   3970 May  8 11:26 ntopo_dihedral_template.cpp
# -rw-r--r--  1 root root   1042 May  8 11:26 ntopo_dihedral_partial.h
# -rw-r--r--  1 root root   3384 May  8 11:26 ntopo_dihedral_partial.cpp
# -rw-r--r--  1 root root   1018 May  8 11:26 ntopo_dihedral_all.h
# -rw-r--r--  1 root root   3322 May  8 11:26 ntopo_dihedral_all.cpp
# -rw-r--r--  1 root root   7291 May  8 11:26 ntopo.cpp
# -rw-r--r--  1 root root   1024 May  8 11:26 ntopo_bond_template.h
# -rw-r--r--  1 root root   2947 May  8 11:26 ntopo_bond_template.cpp
# -rw-r--r--  1 root root   1018 May  8 11:26 ntopo_bond_partial.h
# -rw-r--r--  1 root root   2516 May  8 11:26 ntopo_bond_partial.cpp
# -rw-r--r--  1 root root    994 May  8 11:26 ntopo_bond_all.h
# -rw-r--r--  1 root root   2458 May  8 11:26 ntopo_bond_all.cpp
# -rw-r--r--  1 root root   1030 May  8 11:26 ntopo_angle_template.h
# -rw-r--r--  1 root root   3523 May  8 11:26 ntopo_angle_template.cpp
# -rw-r--r--  1 root root   1024 May  8 11:26 ntopo_angle_partial.h
# -rw-r--r--  1 root root   2950 May  8 11:26 ntopo_angle_partial.cpp
# -rw-r--r--  1 root root   1000 May  8 11:26 ntopo_angle_all.h
# -rw-r--r--  1 root root   2891 May  8 11:26 ntopo_angle_all.cpp
# -rw-r--r--  1 root root   1143 May  8 11:26 nstencil_half_multi_old_3d_tri.h
# -rw-r--r--  1 root root   1721 May  8 11:26 nstencil_half_multi_old_3d_tri.cpp
# -rw-r--r--  1 root root  63959 May  8 11:26 pair.cpp
# -rw-r--r--  1 root root  23397 May  8 11:26 pack.h
# -rw-r--r--  1 root root   5189 May  8 11:26 output.h
# -rw-r--r--  1 root root  35145 May  8 11:26 output.cpp
# -rw-r--r--  1 root root   2030 May  8 11:26 omp_compat.h
# -rw-r--r--  1 root root   1048 May  8 11:26 ntopo_improper_template.h
# -rw-r--r--  1 root root   3970 May  8 11:26 ntopo_improper_template.cpp
# -rw-r--r--  1 root root   1042 May  8 11:26 ntopo_improper_partial.h
# -rw-r--r--  1 root root   3378 May  8 11:26 ntopo_improper_partial.cpp
# -rw-r--r--  1 root root   1018 May  8 11:26 ntopo_improper_all.h
# -rw-r--r--  1 root root  12206 May  8 11:26 pair.h
# -rw-r--r--  1 root root   1569 May  8 11:26 pair_coul_dsf.h
# -rw-r--r--  1 root root   9970 May  8 11:26 pair_coul_dsf.cpp
# -rw-r--r--  1 root root   1356 May  8 11:26 pair_coul_debye.h
# -rw-r--r--  1 root root   6333 May  8 11:26 pair_coul_debye.cpp
# -rw-r--r--  1 root root   1718 May  8 11:26 pair_coul_cut.h
# -rw-r--r--  1 root root  10770 May  8 11:26 pair_coul_cut.cpp
# -rw-r--r--  1 root root   1728 May  8 11:26 pair_buck.h
# -rw-r--r--  1 root root  13163 May  8 11:26 pair_buck.cpp
# -rw-r--r--  1 root root   1883 May  8 11:26 pair_buck_coul_cut.h
# -rw-r--r--  1 root root  17013 May  8 11:26 pair_buck_coul_cut.cpp
# -rw-r--r--  1 root root   1736 May  8 11:26 pair_born.h
# -rw-r--r--  1 root root  14845 May  8 11:26 pair_born.cpp
# -rw-r--r--  1 root root   1901 May  8 11:26 pair_lj_cut.h
# -rw-r--r--  1 root root  21550 May  8 11:26 pair_lj_cut.cpp
# -rw-r--r--  1 root root   1633 May  8 11:26 pair_hybrid_scaled.h
# -rw-r--r--  1 root root  21150 May  8 11:26 pair_hybrid_scaled.cpp
# -rw-r--r--  1 root root   1116 May  8 11:26 pair_hybrid_overlay.h
# -rw-r--r--  1 root root   4865 May  8 11:26 pair_hybrid_overlay.cpp
# -rw-r--r--  1 root root   3329 May  8 11:26 pair_hybrid.h
# -rw-r--r--  1 root root  40374 May  8 11:26 pair_hybrid.cpp
# -rw-r--r--  1 root root   1175 May  8 11:26 pair_deprecated.h
# -rw-r--r--  1 root root   2144 May  8 11:26 pair_deprecated.cpp
# -rw-r--r--  1 root root   1491 May  8 11:26 pair_coul_wolf.h
# -rw-r--r--  1 root root   9906 May  8 11:26 pair_coul_wolf.cpp
# -rw-r--r--  1 root root  10034 May  8 11:26 pair_yukawa.cpp
# -rw-r--r--  1 root root   2256 May  8 11:26 pair_table.h
# -rw-r--r--  1 root root  35585 May  8 11:26 pair_table.cpp
# -rw-r--r--  1 root root   1599 May  8 11:26 pair_soft.h
# -rw-r--r--  1 root root   9451 May  8 11:26 pair_soft.cpp
# -rw-r--r--  1 root root   1638 May  8 11:26 pair_morse.h
# -rw-r--r--  1 root root  10942 May  8 11:26 pair_morse.cpp
# -rw-r--r--  1 root root   1679 May  8 11:26 pair_lj_expand.h
# -rw-r--r--  1 root root  13674 May  8 11:26 pair_lj_expand.cpp
# -rw-r--r--  1 root root   1896 May  8 11:26 pair_lj_cut_coul_cut.h
# -rw-r--r--  1 root root  16398 May  8 11:26 pair_lj_cut_coul_cut.cpp
# -rw-r--r--  1 root root   8934 May  8 11:26 potential_file_reader.cpp
# -rw-r--r--  1 root root   3860 May  8 11:26 pointers.h
# -rw-r--r--  1 root root  13474 May  8 11:26 platform.h
# -rw-r--r--  1 root root  32294 May  8 11:26 platform.cpp
# -rw-r--r--  1 root root   2079 May  8 11:26 pair_zero.h
# -rw-r--r--  1 root root   7856 May  8 11:26 pair_zero.cpp
# -rw-r--r--  1 root root   1819 May  8 11:26 pair_zbl.h
# -rw-r--r--  1 root root  15162 May  8 11:26 pair_zbl.cpp
# -rw-r--r--  1 root root   1239 May  8 11:26 pair_zbl_const.h
# -rw-r--r--  1 root root   1575 May  8 11:26 pair_yukawa.h
# -rw-r--r--  1 root root   3973 May  8 11:26 rcb.h
# -rw-r--r--  1 root root  45577 May  8 11:26 rcb.cpp
# -rw-r--r--  1 root root    998 May  8 11:26 random_park.h
# -rw-r--r--  1 root root   3421 May  8 11:26 random_park.cpp
# -rw-r--r--  1 root root   1242 May  8 11:26 random_mars.h
# -rw-r--r--  1 root root   8415 May  8 11:26 random_mars.cpp
# -rw-r--r--  1 root root   2002 May  8 11:26 procmap.h
# -rw-r--r--  1 root root  31027 May  8 11:26 procmap.cpp
# -rw-r--r--  1 root root   2242 May  8 11:26 potential_file_reader.h
# -rw-r--r--  1 root root  40342 May  8 11:26 read_dump.cpp
# -rw-r--r--  1 root root   3005 May  8 11:26 read_data.h
# -rw-r--r--  1 root root  90618 May  8 11:26 read_data.cpp
# -rw-r--r--  1 root root   1997 May  8 11:26 read_restart.h
# -rw-r--r--  1 root root  41440 May  8 11:26 read_restart.cpp
# -rw-r--r--  1 root root   1550 May  8 11:26 reader_xyz.h
# -rw-r--r--  1 root root   6437 May  8 11:26 reader_xyz.cpp
# -rw-r--r--  1 root root   2241 May  8 11:26 reader_native.h
# -rw-r--r--  1 root root  15861 May  8 11:26 reader_native.cpp
# -rw-r--r--  1 root root   1465 May  8 11:26 reader.h
# -rw-r--r--  1 root root   2580 May  8 11:26 reader.cpp
# -rw-r--r--  1 root root   4316 May  8 11:26 read_dump.h
# -rw-r--r--  1 root root   4636 May  8 11:26 region.h
# -rw-r--r--  1 root root   1888 May  8 11:26 region_ellipsoid.h
# -rw-r--r--  1 root root  19195 May  8 11:26 region_ellipsoid.cpp
# -rw-r--r--  1 root root   1272 May  8 11:26 region_deprecated.h
# -rw-r--r--  1 root root   1163 May  8 11:26 region_deprecated.cpp
# -rw-r--r--  1 root root   1532 May  8 11:26 region_cylinder.h
# -rw-r--r--  1 root root  23210 May  8 11:26 region_cylinder.cpp
# -rw-r--r--  1 root root  19775 May  8 11:26 region.cpp
# -rw-r--r--  1 root root   1294 May  8 11:26 region_cone.h
# -rw-r--r--  1 root root  20092 May  8 11:26 region_cone.cpp
# -rw-r--r--  1 root root   1646 May  8 11:26 region_block.h
# -rw-r--r--  1 root root  19190 May  8 11:26 region_block.cpp
# -rw-r--r--  1 root root  10775 May  8 11:26 region_union.cpp
# -rw-r--r--  1 root root   1488 May  8 11:26 region_sphere.h
# -rw-r--r--  1 root root   8562 May  8 11:26 region_sphere.cpp
# -rw-r--r--  1 root root   1776 May  8 11:26 region_prism.h
# -rw-r--r--  1 root root  15649 May  8 11:26 region_prism.cpp
# -rw-r--r--  1 root root   1189 May  8 11:26 region_plane.h
# -rw-r--r--  1 root root   3909 May  8 11:26 region_plane.cpp
# -rw-r--r--  1 root root   1465 May  8 11:26 region_intersect.h
# -rw-r--r--  1 root root  11024 May  8 11:26 region_intersect.cpp
# -rw-r--r--  1 root root   5139 May  8 11:26 reset_atoms_image.cpp
# -rw-r--r--  1 root root   1462 May  8 11:26 reset_atoms_id.h
# -rw-r--r--  1 root root  18513 May  8 11:26 reset_atoms_id.cpp
# -rw-r--r--  1 root root    970 May  8 11:26 rerun.h
# -rw-r--r--  1 root root  10199 May  8 11:26 rerun.cpp
# -rw-r--r--  1 root root    994 May  8 11:26 replicate.h
# -rw-r--r--  1 root root  27310 May  8 11:26 replicate.cpp
# -rw-r--r--  1 root root   1437 May  8 11:26 region_union.h
# -rw-r--r--  1 root root   1505 May  8 11:26 set.h
# -rw-r--r--  1 root root  60180 May  8 11:26 set.cpp
# -rw-r--r--  1 root root    958 May  8 11:26 run.h
# -rw-r--r--  1 root root   7808 May  8 11:26 run.cpp
# -rw-r--r--  1 root root   2569 May  8 11:26 respa.h
# -rw-r--r--  1 root root  27457 May  8 11:26 respa.cpp
# -rw-r--r--  1 root root   1431 May  8 11:26 reset_atoms_mol.h
# -rw-r--r--  1 root root   8117 May  8 11:26 reset_atoms_mol.cpp
# -rw-r--r--  1 root root   1034 May  8 11:26 reset_atoms_image.h
# -rw-r--r--  1 root root   2244 May  8 11:26 text_file_reader.h
# -rw-r--r--  1 root root   6337 May  8 11:26 text_file_reader.cpp
# -rw-r--r--  1 root root   1581 May  8 11:26 tabular_function.h
# -rw-r--r--  1 root root   2700 May  8 11:26 tabular_function.cpp
# -rw-r--r--  1 root root   1262 May  8 11:26 table_file_reader.h
# -rw-r--r--  1 root root   1485 May  8 11:26 table_file_reader.cpp
# -rw-r--r--  1 root root    858 May  8 11:26 suffix.h
# -rw-r--r--  1 root root   1731 May  8 11:26 special.h
# -rw-r--r--  1 root root  43376 May  8 11:26 special.cpp
# -rw-r--r--  1 root root   2899 May  8 11:26 update.h
# -rw-r--r--  1 root root  15797 May  8 11:26 update.cpp
# -rw-r--r--  1 root root   1633 May  8 11:26 universe.h
# -rw-r--r--  1 root root   6988 May  8 11:26 universe.cpp
# -rw-r--r--  1 root root   3773 May  8 11:26 tokenizer.h
# -rw-r--r--  1 root root   7733 May  8 11:26 tokenizer.cpp
# -rw-r--r--  1 root root   3412 May  8 11:26 timer.h
# -rw-r--r--  1 root root   7235 May  8 11:26 timer.cpp
# -rw-r--r--  1 root root   5943 May  8 11:26 thermo.h
# -rw-r--r--  1 root root  67959 May  8 11:26 thermo.cpp
# -rw-r--r--  1 root root  32507 May  8 11:26 utils.h
# -rw-r--r--  1 root root  70990 May  8 11:26 utils.cpp
# -rw-r--r--  1 root root 183736 May  8 11:26 variable.cpp
# -rw-r--r--  1 root root  25423 May  8 11:26 write_data.cpp
# -rw-r--r--  1 root root   1023 May  8 11:26 write_coeff.h
# -rw-r--r--  1 root root   6019 May  8 11:26 write_coeff.cpp
# -rw-r--r--  1 root root     73 May  8 11:26 version.h
# -rw-r--r--  1 root root   1239 May  8 11:26 verlet.h
# -rw-r--r--  1 root root  11753 May  8 11:26 verlet.cpp
# -rw-r--r--  1 root root   1504 May  8 11:26 velocity.h
# -rw-r--r--  1 root root  28620 May  8 11:26 velocity.cpp
# -rw-r--r--  1 root root   5602 May  8 11:26 variable.h
# -rw-r--r--  1 root root   2148 May  8 11:26 write_restart.h
# -rw-r--r--  1 root root  22434 May  8 11:26 write_restart.cpp
# -rw-r--r--  1 root root   1017 May  8 11:26 write_dump.h
# -rw-r--r--  1 root root   2779 May  8 11:26 write_dump.cpp
# -rw-r--r--  1 root root   1501 May  8 11:26 write_data.h
# drwxr-xr-x 98 root root  36864 May  8 11:26 .
# drwxr-xr-x 16 root root   4096 May  8 11:26 ..
