# %% [markdown]
# <a href="https://colab.research.google.com/github/knc6/jarvis-tools-notebooks/blob/master/jarvis-tools-notebooks/AtomGen_Carbon_Example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%time
# Install required packages.
import os
import torch
os.environ['TORCH'] = torch.__version__
print(torch.__version__)

# !pip install -q torch-scatter -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q torch-sparse -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q git+https://github.com/pyg-team/pytorch_geometric.git
# !pip install -q pytorch-lightning wandb torchmetrics==0.6.0 pymatgen==2022.4.26
# !pip install -q hydra-core jarvis-tools python-dotenv p-tqdm accelerate
# Out:
# 2.1.0+cu121
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 75.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 40.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for torch_geometric (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 777.7/777.7 kB 4.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 29.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 329.4/329.4 kB 29.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 65.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.4/116.4 kB 12.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.9/42.9 kB 4.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 807.7/807.7 kB 54.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 332.3/332.3 kB 29.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.4/98.4 kB 10.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 561.4/561.4 kB 41.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 776.9/776.9 kB 48.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 776.3/776.3 kB 55.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 774.6/774.6 kB 54.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 727.7/727.7 kB 48.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 727.7/727.7 kB 48.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 727.0/727.0 kB 52.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 725.0/725.0 kB 50.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 722.8/722.8 kB 55.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 722.4/722.4 kB 54.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 721.2/721.2 kB 52.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 720.6/720.6 kB 47.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 719.0/719.0 kB 49.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 718.6/718.6 kB 46.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 716.4/716.4 kB 47.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 715.6/715.6 kB 50.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 829.5/829.5 kB 54.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 827.8/827.8 kB 53.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 826.4/826.4 kB 54.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 826.2/826.2 kB 51.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 825.8/825.8 kB 50.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 825.8/825.8 kB 49.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 800.3/800.3 kB 50.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 11.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 800.5/800.5 kB 54.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 800.4/800.4 kB 49.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 800.3/800.3 kB 36.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 800.0/800.0 kB 50.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 798.9/798.9 kB 49.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 798.9/798.9 kB 34.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 799.0/799.0 kB 51.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 798.9/798.9 kB 53.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 798.7/798.7 kB 49.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 798.4/798.4 kB 52.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 796.1/796.1 kB 52.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 136.4/136.4 kB 14.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 795.8/795.8 kB 49.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 136.4/136.4 kB 14.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 708.1/708.1 kB 50.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 707.5/707.5 kB 48.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 706.6/706.6 kB 50.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 706.5/706.5 kB 49.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 705.8/705.8 kB 52.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 705.6/705.6 kB 51.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 701.5/701.5 kB 52.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 700.9/700.9 kB 44.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 585.9/585.9 kB 39.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 59.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.4/196.4 kB 21.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 257.5/257.5 kB 23.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 6.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 526.7/526.7 kB 10.7 MB/s eta 0:00:00
#   Building wheel for pymatgen (pyproject.toml) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-ai-generativelanguage 0.4.0 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 3.20.1 which is incompatible.
# google-api-core 2.11.1 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5, but you have protobuf 3.20.1 which is incompatible.
# google-cloud-aiplatform 1.39.0 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 3.20.1 which is incompatible.
# google-cloud-bigquery 3.12.0 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 3.20.1 which is incompatible.
# google-cloud-bigquery-connection 1.12.1 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 3.20.1 which is incompatible.
# google-cloud-bigquery-storage 2.24.0 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 3.20.1 which is incompatible.
# google-cloud-datastore 2.15.2 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 3.20.1 which is incompatible.
# google-cloud-firestore 2.11.1 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 3.20.1 which is incompatible.
# google-cloud-functions 1.13.3 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 3.20.1 which is incompatible.
# google-cloud-iam 2.13.0 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 3.20.1 which is incompatible.
# google-cloud-language 2.9.1 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 3.20.1 which is incompatible.
# google-cloud-resource-manager 1.11.0 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 3.20.1 which is incompatible.
# google-cloud-translate 3.11.3 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 3.20.1 which is incompatible.
# googleapis-common-protos 1.62.0 requires protobuf!=3.20.0,!=3.20.1,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5, but you have protobuf 3.20.1 which is incompatible.
# grpc-google-iam-v1 0.13.0 requires protobuf!=3.20.0,!=3.20.1,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 3.20.1 which is incompatible.
# tensorflow 2.15.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 3.20.1 which is incompatible.
# tensorflow-metadata 1.14.0 requires protobuf<4.21,>=3.20.3, but you have protobuf 3.20.1 which is incompatible.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 1.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 975.7/975.7 kB 9.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 270.9/270.9 kB 26.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 8.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 12.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 23.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 8.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 56.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.8/250.8 kB 26.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 kB 6.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 13.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 13.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 5.8 MB/s eta 0:00:00
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Building wheel for p-tqdm (setup.py) ... done
#   Building wheel for paginate (setup.py) ... done
# CPU times: user 2.85 s, sys: 594 ms, total: 3.44 s
# Wall time: 2min 21s

# %%
import os
os.chdir('/content')
if not os.path.exists('cdvae'):
  # !git clone https://github.com/JARVIS-Materials-Design/cdvae.git

os.chdir('cdvae')
# !pip install -e .
# Out:
# Cloning into 'cdvae'...
# remote: Enumerating objects: 253, done.
# remote: Counting objects: 100% (89/89), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 253 (delta 38), reused 52 (delta 32), pack-reused 164
# Receiving objects: 100% (253/253), 146.69 MiB | 36.85 MiB/s, done.
# Resolving deltas: 100% (90/90), done.
# Updating files: 100% (99/99), done.
# Obtaining file:///content/cdvae
#   Preparing metadata (setup.py) ... done
# Installing collected packages: cdvae
#   Running setup.py develop for cdvae
# Successfully installed cdvae-0.0.1

# %%
import os
if not os.path.exists("/content/cdvae/WABDB"):
  os.makedirs("/content/cdvae/WABDB")
if not os.path.exists("/content/cdvae/HYDRA_JOBS"):
  os.makedirs("/content/cdvae/HYDRA_JOBS")
os.environ["PROJECT_ROOT"]="/content/cdvae"
os.environ["WABDB"]="/content/cdvae/WABDB"
os.environ["WABDB_DIR"]="/content/cdvae/WABDB"
os.environ["HYDRA_JOBS"]="/content/cdvae/HYDRA_JOBS"
# %env HYDRA_FULL_ERROR=1
# Out:
# env: HYDRA_FULL_ERROR=1

# %%
# !echo $HYDRA_FULL_ERROR
# Out:
# 1

# %%
import yaml
import pprint

with open('/content/cdvae/conf/train/default.yaml','r') as f:
  yam = yaml.safe_load(f)
#yam.pop('early_stopping')
#yam['pl_trainer']['fast_dev_run']=True
yam['pl_trainer']['gpus']=0

with open('/content/cdvae/conf/train/default.yaml','w') as f:
  yaml.dump(yam,f)

pprint.pprint(yam)

with open('/content/cdvae/conf/optim/default.yaml','r') as f:
  yam = yaml.safe_load(f)

yam['use_lr_scheduler']=False

with open('/content/cdvae/conf/optim/default.yaml','w') as f:
  yaml.dump(yam,f)

pprint.pprint(yam)
# Out:
# {'deterministic': False,
#  'early_stopping': {'patience': '${data.early_stopping_patience}',
#                     'verbose': False},
#  'model_checkpoints': {'save_top_k': 1, 'verbose': False},
#  'monitor_metric': 'val_loss',
#  'monitor_metric_mode': 'min',
#  'pl_trainer': {'accumulate_grad_batches': 1,
#                 'fast_dev_run': False,
#                 'gpus': 0,
#                 'gradient_clip_algorithm': 'value',
#                 'gradient_clip_val': 0.5,
#                 'max_epochs': '${data.train_max_epochs}',
#                 'num_sanity_val_steps': 2,
#                 'precision': 32,
#                 'profiler': 'simple'},
#  'random_seed': 42}
# {'lr_scheduler': {'_target_': 'torch.optim.lr_scheduler.ReduceLROnPlateau',
#                   'factor': 0.6,
#                   'min_lr': '1e-4',
#                   'patience': 30},
#  'optimizer': {'_target_': 'torch.optim.Adam',
#                'betas': [0.9, 0.999],
#                'eps': '1e-08',
#                'lr': 0.001,
#                'weight_decay': 0},
#  'use_lr_scheduler': False}

# %%
# %%time
import os
os.environ["WANDB_ANONYMOUS"] = "must"
# !python cdvae/run.py data=carbon expname=carbon_test model.predict_property=True
# Out:
# 2024-02-01 02:24:01.441702: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-01 02:24:01.441767: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-01 02:24:01.443753: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-01 02:24:03.023573: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /content/cdvae/cdvae/run.py:164: UserWarning:
# The version_base parameter is not specified.
# Please specify a compatability version level, or None.
# Will assume defaults for version 1.1
#   @hydra.main(config_path=str(PROJECT_ROOT / "conf"), config_name="default")
# /usr/local/lib/python3.10/dist-packages/hydra/_internal/defaults_list.py:251: UserWarning: In 'default': Defaults list is missing `_self_`. See https://hydra.cc/docs/1.2/upgrades/1.0_to_1.1/default_composition_order for more information
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/hydra/_internal/hydra.py:119: UserWarning: Future Hydra versions will no longer change working directory at job runtime by default.
# See https://hydra.cc/docs/1.2/upgrades/1.1_to_1.2/changes_to_job_working_dir/ for more information.
#   ret = run_job(
# [2024-02-01 02:24:04,904][hydra.utils][INFO] - Instantiating <cdvae.pl_data.datamodule.CrystDataModule>
# /content/cdvae/cdvae/pl_data/datamodule.py:142: UserWarning:
# The version_base parameter is not specified.
# Please specify a compatability version level, or None.
# Will assume defaults for version 1.1
#   @hydra.main(config_path=str(PROJECT_ROOT / "conf"), config_name="default")
# /content/cdvae/cdvae/pl_data/dataset.py:126: UserWarning:
# The version_base parameter is not specified.
# Please specify a compatability version level, or None.
# Will assume defaults for version 1.1
#   @hydra.main(config_path=str(PROJECT_ROOT / "conf"), config_name="default")
#  25% 1526/6091 [02:02<08:34,  8.87it/s]/usr/local/lib/python3.10/dist-packages/pymatgen/io/cif.py:1155: UserWarning: Issues encountered while parsing CIF: Some fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: " + "\n".join(self.warnings))
#  34% 2081/6091 [02:46<06:58,  9.58it/s]/usr/local/lib/python3.10/dist-packages/pymatgen/io/cif.py:1155: UserWarning: Issues encountered while parsing CIF: Some fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: " + "\n".join(self.warnings))
#  46% 2820/6091 [03:43<05:06, 10.68it/s]/usr/local/lib/python3.10/dist-packages/pymatgen/io/cif.py:1155: UserWarning: Issues encountered while parsing CIF: Some fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: " + "\n".join(self.warnings))
#  50% 3021/6091 [03:58<04:22, 11.70it/s]/usr/local/lib/python3.10/dist-packages/pymatgen/io/cif.py:1155: UserWarning: Issues encountered while parsing CIF: Some fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: " + "\n".join(self.warnings))
#  51% 3084/6091 [04:03<03:41, 13.55it/s]/usr/local/lib/python3.10/dist-packages/pymatgen/io/cif.py:1155: UserWarning: Issues encountered while parsing CIF: Some fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: " + "\n".join(self.warnings))
#  52% 3140/6091 [04:07<04:32, 10.84it/s]/usr/local/lib/python3.10/dist-packages/pymatgen/io/cif.py:1155: UserWarning: Issues encountered while parsing CIF: Some fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: " + "\n".join(self.warnings))
#  52% 3148/6091 [04:07<03:58, 12.32it/s]/usr/local/lib/python3.10/dist-packages/pymatgen/io/cif.py:1155: UserWarning: Issues encountered while parsing CIF: Some fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: " + "\n".join(self.warnings))
#  60% 3677/6091 [04:47<03:35, 11.20it/s]/usr/local/lib/python3.10/dist-packages/pymatgen/io/cif.py:1155: UserWarning: Issues encountered while parsing CIF: Some fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: " + "\n".join(self.warnings))
#  66% 4022/6091 [05:13<03:04, 11.20it/s]/usr/local/lib/python3.10/dist-packages/pymatgen/io/cif.py:1155: UserWarning: Issues encountered while parsing CIF: Some fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: " + "\n".join(self.warnings))
#  67% 4088/6091 [05:17<01:37, 20.49it/s]/usr/local/lib/python3.10/dist-packages/pymatgen/io/cif.py:1155: UserWarning: Issues encountered while parsing CIF: Some fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: " + "\n".join(self.warnings))
#  67% 4104/6091 [05:19<03:38,  9.09it/s]/usr/local/lib/python3.10/dist-packages/pymatgen/io/cif.py:1155: UserWarning: Issues encountered while parsing CIF: Some fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: " + "\n".join(self.warnings))
#  69% 4231/6091 [05:28<02:54, 10.67it/s]/usr/local/lib/python3.10/dist-packages/pymatgen/io/cif.py:1155: UserWarning: Issues encountered while parsing CIF: Some fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: " + "\n".join(self.warnings))
#  74% 4535/6091 [05:52<01:30, 17.16it/s]/usr/local/lib/python3.10/dist-packages/pymatgen/io/cif.py:1155: UserWarning: Issues encountered while parsing CIF: Some fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: " + "\n".join(self.warnings))
#  80% 4874/6091 [06:16<01:17, 15.78it/s]/usr/local/lib/python3.10/dist-packages/pymatgen/io/cif.py:1155: UserWarning: Issues encountered while parsing CIF: Some fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: " + "\n".join(self.warnings))
#  84% 5108/6091 [06:34<01:18, 12.46it/s]/usr/local/lib/python3.10/dist-packages/pymatgen/io/cif.py:1155: UserWarning: Issues encountered while parsing CIF: Some fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: " + "\n".join(self.warnings))
#  91% 5569/6091 [07:10<00:43, 12.12it/s]/usr/local/lib/python3.10/dist-packages/pymatgen/io/cif.py:1155: UserWarning: Issues encountered while parsing CIF: Some fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: " + "\n".join(self.warnings))
#  95% 5791/6091 [07:26<00:17, 16.77it/s]/usr/local/lib/python3.10/dist-packages/pymatgen/io/cif.py:1155: UserWarning: Issues encountered while parsing CIF: Some fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: " + "\n".join(self.warnings))
#  96% 5825/6091 [07:29<00:18, 14.55it/s]/usr/local/lib/python3.10/dist-packages/pymatgen/io/cif.py:1155: UserWarning: Issues encountered while parsing CIF: Some fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: " + "\n".join(self.warnings))
#  98% 5974/6091 [07:40<00:10, 10.88it/s]/usr/local/lib/python3.10/dist-packages/pymatgen/io/cif.py:1155: UserWarning: Issues encountered while parsing CIF: Some fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: " + "\n".join(self.warnings))
# 100% 6091/6091 [07:48<00:00, 12.99it/s]
# /content/cdvae/cdvae/common/data_utils.py:644: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:261.)
#   targets = torch.tensor([d[key] for d in data_list])
# /content/cdvae/cdvae/common/data_utils.py:612: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X = torch.tensor(X, dtype=torch.float)
# [2024-02-01 02:32:00,030][hydra.utils][INFO] - Instantiating <cdvae.pl_modules.model.CDVAE>
# /content/cdvae/cdvae/pl_modules/model.py:635: UserWarning:
# The version_base parameter is not specified.
# Please specify a compatability version level, or None.
# Will assume defaults for version 1.1
#   @hydra.main(config_path=str(PROJECT_ROOT / "conf"), config_name="default")
# [2024-02-01 02:32:22,574][hydra.utils][INFO] - Passing scaler from datamodule to model <StandardScalerTorch(means: -154.2510223388672, stds: 0.13738815486431122)>
# [2024-02-01 02:32:22,575][hydra.utils][INFO] - Adding callback <LearningRateMonitor>
# [2024-02-01 02:32:22,576][hydra.utils][INFO] - Adding callback <EarlyStopping>
# [2024-02-01 02:32:22,577][hydra.utils][INFO] - Adding callback <ModelCheckpoint>
# [2024-02-01 02:32:22,580][hydra.utils][INFO] - Instantiating <WandbLogger>
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Tracking run with wandb version 0.16.2
# wandb: Run data is saved locally in /content/cdvae/WABDB/wandb/run-20240201_023223-xthfyorj
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run carbon_test
# wandb: ⭐️ View project at https://wandb.ai/anony-moose-294051274941231696/crystal_generation_mit?apiKey=09c1fe110b07c00021d7692f481b734e954081ac
# wandb: 🚀 View run at https://wandb.ai/anony-moose-294051274941231696/crystal_generation_mit/runs/xthfyorj?apiKey=09c1fe110b07c00021d7692f481b734e954081ac
# wandb: WARNING Do NOT share these links with anyone. They can be used to claim your runs.
# [2024-02-01 02:32:24,366][hydra.utils][INFO] - W&B is now watching <{cfg.logging.wandb_watch.log}>!
# wandb: logging graph, to disable use `wandb.watch(log_graph=False)`
# [2024-02-01 02:32:24,395][hydra.utils][INFO] - Instantiating the Trainer
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/connectors/callback_connector.py:96: LightningDeprecationWarning: Setting `Trainer(progress_bar_refresh_rate=20)` is deprecated in v1.5 and will be removed in v1.7. Please pass `pytorch_lightning.callbacks.progress.TQDMProgressBar` with `refresh_rate` directly to the Trainer's `callbacks` argument instead. Or, to disable the progress bar pass `enable_progress_bar = False` to the Trainer.
#   rank_zero_deprecation(
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# [2024-02-01 02:32:24,441][hydra.utils][INFO] - Starting training!
#  25% 1526/6091 [02:02<07:48,  9.74it/s]/usr/local/lib/python3.10/dist-packages/pymatgen/io/cif.py:1155: UserWarning: Issues encountered while parsing CIF: Some fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: " + "\n".join(self.warnings))
#  34% 2082/6091 [02:46<06:16, 10.64it/s]/usr/local/lib/python3.10/dist-packages/pymatgen/io/cif.py:1155: UserWarning: Issues encountered while parsing CIF: Some fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: " + "\n".join(self.warnings))
#  46% 2819/6091 [03:43<04:27, 12.25it/s]/usr/local/lib/python3.10/dist-packages/pymatgen/io/cif.py:1155: UserWarning: Issues encountered while parsing CIF: Some fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: " + "\n".join(self.warnings))
#  50% 3020/6091 [03:58<02:45, 18.52it/s]/usr/local/lib/python3.10/dist-packages/pymatgen/io/cif.py:1155: UserWarning: Issues encountered while parsing CIF: Some fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: " + "\n".join(self.warnings))
#  51% 3084/6091 [04:04<04:37, 10.84it/s]/usr/local/lib/python3.10/dist-packages/pymatgen/io/cif.py:1155: UserWarning: Issues encountered while parsing CIF: Some fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: " + "\n".join(self.warnings))
#  52% 3139/6091 [04:08<04:45, 10.34it/s]/usr/local/lib/python3.10/dist-packages/pymatgen/io/cif.py:1155: UserWarning: Issues encountered while parsing CIF: Some fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: " + "\n".join(self.warnings))
#  52% 3149/6091 [04:09<03:18, 14.82it/s]/usr/local/lib/python3.10/dist-packages/pymatgen/io/cif.py:1155: UserWarning: Issues encountered while parsing CIF: Some fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: " + "\n".join(self.warnings))
#  60% 3678/6091 [04:50<02:43, 14.75it/s]/usr/local/lib/python3.10/dist-packages/pymatgen/io/cif.py:1155: UserWarning: Issues encountered while parsing CIF: Some fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: " + "\n".join(self.warnings))
#  66% 4021/6091 [05:16<04:04,  8.45it/s]/usr/local/lib/python3.10/dist-packages/pymatgen/io/cif.py:1155: UserWarning: Issues encountered while parsing CIF: Some fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: " + "\n".join(self.warnings))
#  67% 4087/6091 [05:21<01:56, 17.18it/s]/usr/local/lib/python3.10/dist-packages/pymatgen/io/cif.py:1155: UserWarning: Issues encountered while parsing CIF: Some fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: " + "\n".join(self.warnings))
#  67% 4103/6091 [05:22<02:44, 12.10it/s]/usr/local/lib/python3.10/dist-packages/pymatgen/io/cif.py:1155: UserWarning: Issues encountered while parsing CIF: Some fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: " + "\n".join(self.warnings))
#  70% 4234/6091 [05:32<01:49, 16.92it/s]/usr/local/lib/python3.10/dist-packages/pymatgen/io/cif.py:1155: UserWarning: Issues encountered while parsing CIF: Some fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: " + "\n".join(self.warnings))
#  74% 4536/6091 [05:56<02:12, 11.76it/s]/usr/local/lib/python3.10/dist-packages/pymatgen/io/cif.py:1155: UserWarning: Issues encountered while parsing CIF: Some fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: " + "\n".join(self.warnings))
#  80% 4877/6091 [06:20<01:29, 13.50it/s]/usr/local/lib/python3.10/dist-packages/pymatgen/io/cif.py:1155: UserWarning: Issues encountered while parsing CIF: Some fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: " + "\n".join(self.warnings))
#  84% 5109/6091 [06:39<01:30, 10.87it/s]/usr/local/lib/python3.10/dist-packages/pymatgen/io/cif.py:1155: UserWarning: Issues encountered while parsing CIF: Some fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: " + "\n".join(self.warnings))
#  91% 5569/6091 [07:14<00:47, 10.94it/s]/usr/local/lib/python3.10/dist-packages/pymatgen/io/cif.py:1155: UserWarning: Issues encountered while parsing CIF: Some fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: " + "\n".join(self.warnings))
#  95% 5791/6091 [07:31<00:25, 11.83it/s]/usr/local/lib/python3.10/dist-packages/pymatgen/io/cif.py:1155: UserWarning: Issues encountered while parsing CIF: Some fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: " + "\n".join(self.warnings))
#  96% 5824/6091 [07:33<00:16, 16.50it/s]/usr/local/lib/python3.10/dist-packages/pymatgen/io/cif.py:1155: UserWarning: Issues encountered while parsing CIF: Some fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: " + "\n".join(self.warnings))
#  98% 5973/6091 [07:45<00:11,  9.95it/s]/usr/local/lib/python3.10/dist-packages/pymatgen/io/cif.py:1155: UserWarning: Issues encountered while parsing CIF: Some fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: " + "\n".join(self.warnings))
# 100% 6091/6091 [07:54<00:00, 12.85it/s]
#  29% 584/2032 [00:47<01:57, 12.35it/s]/usr/local/lib/python3.10/dist-packages/pymatgen/io/cif.py:1155: UserWarning: Issues encountered while parsing CIF: Some fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: " + "\n".join(self.warnings))
#  42% 847/2032 [01:07<02:32,  7.76it/s]/usr/local/lib/python3.10/dist-packages/pymatgen/io/cif.py:1155: UserWarning: Issues encountered while parsing CIF: Some fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: " + "\n".join(self.warnings))
#  44% 885/2032 [01:11<01:12, 15.74it/s]/usr/local/lib/python3.10/dist-packages/pymatgen/io/cif.py:1155: UserWarning: Issues encountered while parsing CIF: Some fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: " + "\n".join(self.warnings))
#  54% 1092/2032 [01:26<00:56, 16.76it/s]/usr/local/lib/python3.10/dist-packages/pymatgen/io/cif.py:1155: UserWarning: Issues encountered while parsing CIF: Some fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: " + "\n".join(self.warnings))
#  60% 1215/2032 [01:35<01:03, 12.82it/s]/usr/local/lib/python3.10/dist-packages/pymatgen/io/cif.py:1155: UserWarning: Issues encountered while parsing CIF: Some fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: " + "\n".join(self.warnings))
#  61% 1237/2032 [01:36<00:54, 14.72it/s]/usr/local/lib/python3.10/dist-packages/pymatgen/io/cif.py:1155: UserWarning: Issues encountered while parsing CIF: Some fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: " + "\n".join(self.warnings))
#  63% 1274/2032 [01:39<00:53, 14.16it/s]/usr/local/lib/python3.10/dist-packages/pymatgen/io/cif.py:1155: UserWarning: Issues encountered while parsing CIF: Some fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: " + "\n".join(self.warnings))
#  69% 1408/2032 [01:50<00:49, 12.63it/s]/usr/local/lib/python3.10/dist-packages/pymatgen/io/cif.py:1155: UserWarning: Issues encountered while parsing CIF: Some fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: " + "\n".join(self.warnings))
#  86% 1745/2032 [02:15<00:19, 14.69it/s]/usr/local/lib/python3.10/dist-packages/pymatgen/io/cif.py:1155: UserWarning: Issues encountered while parsing CIF: Some fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: " + "\n".join(self.warnings))
#  86% 1749/2032 [02:16<00:20, 13.77it/s]/usr/local/lib/python3.10/dist-packages/pymatgen/io/cif.py:1155: UserWarning: Issues encountered while parsing CIF: Some fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: " + "\n".join(self.warnings))
#  95% 1926/2032 [02:28<00:05, 19.18it/s]/usr/local/lib/python3.10/dist-packages/pymatgen/io/cif.py:1155: UserWarning: Issues encountered while parsing CIF: Some fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: " + "\n".join(self.warnings))
#  96% 1955/2032 [02:31<00:07,  9.76it/s]/usr/local/lib/python3.10/dist-packages/pymatgen/io/cif.py:1155: UserWarning: Issues encountered while parsing CIF: Some fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: " + "\n".join(self.warnings))
#  97% 1963/2032 [02:31<00:06, 10.75it/s]/usr/local/lib/python3.10/dist-packages/pymatgen/io/cif.py:1155: UserWarning: Issues encountered while parsing CIF: Some fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: " + "\n".join(self.warnings))
# 100% 2032/2032 [02:36<00:00, 12.96it/s]
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/callbacks/model_checkpoint.py:611: UserWarning: Checkpoint directory /content/cdvae/HYDRA_JOBS/singlerun/2024-02-01/carbon_test exists and is not empty.
#   rank_zero_warn(f"Checkpoint directory {dirpath} exists and is not empty.")
#
#   | Name           | Type                | Params
# -------------------------------------------------------
# 0 | encoder        | DimeNetPlusPlusWrap | 2.2 M
# 1 | decoder        | GemNetTDecoder      | 2.3 M
# 2 | fc_mu          | Linear              | 65.8 K
# 3 | fc_var         | Linear              | 65.8 K
# 4 | fc_num_atoms   | Sequential          | 72.2 K
# 5 | fc_lattice     | Sequential          | 67.3 K
# 6 | fc_composition | Sequential          | 91.5 K
# 7 | fc_property    | Sequential          | 66.0 K
# -------------------------------------------------------
# 5.0 M     Trainable params
# 117       Non-trainable params
# 5.0 M     Total params
# 19.950    Total estimated model params size (MB)
# Sanity Checking: 0it [00:00, ?it/s]/usr/local/lib/python3.10/dist-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:240: PossibleUserWarning: The dataloader, val_dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 8 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Sanity Checking DataLoader 0:   0% 0/2 [00:00<?, ?it/s]/content/cdvae/cdvae/common/data_utils.py:622: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X = torch.tensor(X, dtype=torch.float)
# /content/cdvae/cdvae/common/data_utils.py:618: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X = torch.tensor(X, dtype=torch.float)
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:240: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 8 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/trainer.py:1933: PossibleUserWarning: The number of training batches (24) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   rank_zero_warn(
# Epoch 4:  62% 20/32 [02:44<01:38,  8.24s/it, loss=18.6, v_num=yorj, train_loss_step=18.70, train_natom_loss_step=1.750, train_lattice_loss_step=0.806, train_coord_loss_step=0.812, train_type_loss_step=0.0075, train_kld_loss_step=28.90, train_composition_loss_step=0.0419, train_loss_epoch=19.50, train_natom_loss_epoch=1.740, train_lattice_loss_epoch=0.859, train_coord_loss_epoch=0.822, train_type_loss_epoch=0.00652, train_kld_loss_epoch=31.80, train_composition_loss_epoch=0.0279]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 8/8 [00:22<00:00,  2.81s/it]
# Epoch 4: 100% 32/32 [03:38<00:00,  6.82s/it, loss=18.6, v_num=yorj, train_loss_step=18.00, train_natom_loss_step=1.660, train_lattice_loss_step=0.773, train_coord_loss_step=0.791, train_type_loss_step=0.0028, train_kld_loss_step=32.70, train_composition_loss_step=0.0196, train_loss_epoch=19.50, train_natom_loss_epoch=1.740, train_lattice_loss_epoch=0.859, train_coord_loss_epoch=0.822, train_type_loss_epoch=0.00652, train_kld_loss_epoch=31.80, train_composition_loss_epoch=0.0279, val_loss=11.30, val_natom_loss=1.690, val_lattice_loss=0.795, val_coord_loss=1.130, val_type_loss=0.00725, val_kld_loss=38.20, val_composition_loss=0.0042, val_property_loss=0.525, val_natom_accuracy=0.333, val_lengths_mard=0.0992, val_angles_mae=9.510, val_volumes_mard=0.0865, val_type_accuracy=1.000]
# Epoch 9:  62% 20/32 [02:39<01:35,  7.97s/it, loss=16.5, v_num=yorj, train_loss_step=16.00, train_natom_loss_step=1.550, train_lattice_loss_step=0.732, train_coord_loss_step=0.653, train_type_loss_step=0.0322, train_kld_loss_step=29.90, train_composition_loss_step=0.00592, train_loss_epoch=16.50, train_natom_loss_epoch=1.610, train_lattice_loss_epoch=0.736, train_coord_loss_epoch=0.700, train_type_loss_epoch=0.0061, train_kld_loss_epoch=32.50, train_composition_loss_epoch=0.00608, val_loss=11.30, val_natom_loss=1.690, val_lattice_loss=0.795, val_coord_loss=1.130, val_type_loss=0.00725, val_kld_loss=38.20, val_composition_loss=0.0042, val_property_loss=0.525, val_natom_accuracy=0.333, val_lengths_mard=0.0992, val_angles_mae=9.510, val_volumes_mard=0.0865, val_type_accuracy=1.000]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 8/8 [00:21<00:00,  2.70s/it]
# Epoch 9: 100% 32/32 [03:30<00:00,  6.59s/it, loss=16.4, v_num=yorj, train_loss_step=16.10, train_natom_loss_step=1.560, train_lattice_loss_step=0.722, train_coord_loss_step=0.669, train_type_loss_step=0.00451, train_kld_loss_step=37.10, train_composition_loss_step=0.00238, train_loss_epoch=16.50, train_natom_loss_epoch=1.610, train_lattice_loss_epoch=0.736, train_coord_loss_epoch=0.700, train_type_loss_epoch=0.0061, train_kld_loss_epoch=32.50, train_composition_loss_epoch=0.00608, val_loss=10.40, val_natom_loss=1.540, val_lattice_loss=0.737, val_coord_loss=1.040, val_type_loss=0.00511, val_kld_loss=37.60, val_composition_loss=0.00217, val_property_loss=0.168, val_natom_accuracy=0.420, val_lengths_mard=0.0887, val_angles_mae=9.460, val_volumes_mard=0.102, val_type_accuracy=1.000]
# Epoch 14:  62% 20/32 [02:39<01:35,  8.00s/it, loss=14.9, v_num=yorj, train_loss_step=15.40, train_natom_loss_step=1.310, train_lattice_loss_step=0.695, train_coord_loss_step=0.660, train_type_loss_step=0.00314, train_kld_loss_step=36.20, train_composition_loss_step=0.00269, train_loss_epoch=14.90, train_natom_loss_epoch=1.230, train_lattice_loss_epoch=0.674, train_coord_loss_epoch=0.639, train_type_loss_epoch=0.00444, train_kld_loss_epoch=38.40, train_composition_loss_epoch=0.00577, val_loss=10.40, val_natom_loss=1.540, val_lattice_loss=0.737, val_coord_loss=1.040, val_type_loss=0.00511, val_kld_loss=37.60, val_composition_loss=0.00217, val_property_loss=0.168, val_natom_accuracy=0.420, val_lengths_mard=0.0887, val_angles_mae=9.460, val_volumes_mard=0.102, val_type_accuracy=1.000]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 8/8 [00:21<00:00,  2.74s/it]
# Epoch 14: 100% 32/32 [03:32<00:00,  6.64s/it, loss=14.8, v_num=yorj, train_loss_step=14.40, train_natom_loss_step=1.240, train_lattice_loss_step=0.641, train_coord_loss_step=0.621, train_type_loss_step=0.00104, train_kld_loss_step=37.30, train_composition_loss_step=0.00265, train_loss_epoch=14.90, train_natom_loss_epoch=1.230, train_lattice_loss_epoch=0.674, train_coord_loss_epoch=0.639, train_type_loss_epoch=0.00444, train_kld_loss_epoch=38.40, train_composition_loss_epoch=0.00577, val_loss=9.760, val_natom_loss=1.230, val_lattice_loss=0.670, val_coord_loss=0.976, val_type_loss=0.00248, val_kld_loss=38.70, val_composition_loss=0.00277, val_property_loss=0.149, val_natom_accuracy=0.533, val_lengths_mard=0.0742, val_angles_mae=9.380, val_volumes_mard=0.105, val_type_accuracy=1.000]
# Epoch 19:  62% 20/32 [02:35<01:33,  7.78s/it, loss=13.8, v_num=yorj, train_loss_step=14.00, train_natom_loss_step=1.070, train_lattice_loss_step=0.656, train_coord_loss_step=0.576, train_type_loss_step=0.00142, train_kld_loss_step=43.50, train_composition_loss_step=0.000708, train_loss_epoch=14.20, train_natom_loss_epoch=1.130, train_lattice_loss_epoch=0.638, train_coord_loss_epoch=0.613, train_type_loss_epoch=0.00263, train_kld_loss_epoch=39.00, train_composition_loss_epoch=0.00279, val_loss=9.760, val_natom_loss=1.230, val_lattice_loss=0.670, val_coord_loss=0.976, val_type_loss=0.00248, val_kld_loss=38.70, val_composition_loss=0.00277, val_property_loss=0.149, val_natom_accuracy=0.533, val_lengths_mard=0.0742, val_angles_mae=9.380, val_volumes_mard=0.105, val_type_accuracy=1.000]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 8/8 [00:21<00:00,  2.68s/it]
# Epoch 19: 100% 32/32 [03:26<00:00,  6.46s/it, loss=13.8, v_num=yorj, train_loss_step=14.10, train_natom_loss_step=1.140, train_lattice_loss_step=0.658, train_coord_loss_step=0.589, train_type_loss_step=0.000743, train_kld_loss_step=32.90, train_composition_loss_step=0.00395, train_loss_epoch=14.20, train_natom_loss_epoch=1.130, train_lattice_loss_epoch=0.638, train_coord_loss_epoch=0.613, train_type_loss_epoch=0.00263, train_kld_loss_epoch=39.00, train_composition_loss_epoch=0.00279, val_loss=9.300, val_natom_loss=1.060, val_lattice_loss=0.628, val_coord_loss=0.930, val_type_loss=0.0019, val_kld_loss=37.60, val_composition_loss=0.00289, val_property_loss=0.161, val_natom_accuracy=0.614, val_lengths_mard=0.0674, val_angles_mae=9.150, val_volumes_mard=0.0986, val_type_accuracy=1.000]
# Epoch 24:  62% 20/32 [02:36<01:33,  7.83s/it, loss=13.3, v_num=yorj, train_loss_step=13.80, train_natom_loss_step=0.975, train_lattice_loss_step=0.604, train_coord_loss_step=0.615, train_type_loss_step=0.00294, train_kld_loss_step=46.70, train_composition_loss_step=0.000505, train_loss_epoch=13.50, train_natom_loss_epoch=1.040, train_lattice_loss_epoch=0.608, train_coord_loss_epoch=0.589, train_type_loss_epoch=0.0013, train_kld_loss_epoch=39.40, train_composition_loss_epoch=0.00202, val_loss=9.300, val_natom_loss=1.060, val_lattice_loss=0.628, val_coord_loss=0.930, val_type_loss=0.0019, val_kld_loss=37.60, val_composition_loss=0.00289, val_property_loss=0.161, val_natom_accuracy=0.614, val_lengths_mard=0.0674, val_angles_mae=9.150, val_volumes_mard=0.0986, val_type_accuracy=1.000]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 8/8 [00:20<00:00,  2.62s/it]
# Epoch 24: 100% 32/32 [03:26<00:00,  6.46s/it, loss=13.4, v_num=yorj, train_loss_step=12.50, train_natom_loss_step=0.861, train_lattice_loss_step=0.545, train_coord_loss_step=0.574, train_type_loss_step=0.0025, train_kld_loss_step=37.60, train_composition_loss_step=0.0017, train_loss_epoch=13.50, train_natom_loss_epoch=1.040, train_lattice_loss_epoch=0.608, train_coord_loss_epoch=0.589, train_type_loss_epoch=0.0013, train_kld_loss_epoch=39.40, train_composition_loss_epoch=0.00202, val_loss=9.520, val_natom_loss=0.994, val_lattice_loss=0.621, val_coord_loss=0.951, val_type_loss=0.00154, val_kld_loss=35.10, val_composition_loss=0.00131, val_property_loss=0.124, val_natom_accuracy=0.639, val_lengths_mard=0.0653, val_angles_mae=9.120, val_volumes_mard=0.0961, val_type_accuracy=1.000]
# Epoch 29:  62% 20/32 [02:37<01:34,  7.89s/it, loss=12.8, v_num=yorj, train_loss_step=12.60, train_natom_loss_step=0.887, train_lattice_loss_step=0.590, train_coord_loss_step=0.527, train_type_loss_step=0.000912, train_kld_loss_step=38.70, train_composition_loss_step=0.000891, train_loss_epoch=12.80, train_natom_loss_epoch=0.934, train_lattice_loss_epoch=0.581, train_coord_loss_epoch=0.550, train_type_loss_epoch=0.00136, train_kld_loss_epoch=40.40, train_composition_loss_epoch=0.0013, val_loss=9.520, val_natom_loss=0.994, val_lattice_loss=0.621, val_coord_loss=0.951, val_type_loss=0.00154, val_kld_loss=35.10, val_composition_loss=0.00131, val_property_loss=0.124, val_natom_accuracy=0.639, val_lengths_mard=0.0653, val_angles_mae=9.120, val_volumes_mard=0.0961, val_type_accuracy=1.000]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 8/8 [00:23<00:00,  2.88s/it]
# Epoch 29: 100% 32/32 [03:33<00:00,  6.66s/it, loss=12.8, v_num=yorj, train_loss_step=13.10, train_natom_loss_step=0.856, train_lattice_loss_step=0.599, train_coord_loss_step=0.576, train_type_loss_step=0.000973, train_kld_loss_step=42.50, train_composition_loss_step=0.00304, train_loss_epoch=12.80, train_natom_loss_epoch=0.934, train_lattice_loss_epoch=0.581, train_coord_loss_epoch=0.550, train_type_loss_epoch=0.00136, train_kld_loss_epoch=40.40, train_composition_loss_epoch=0.0013, val_loss=9.540, val_natom_loss=0.962, val_lattice_loss=0.621, val_coord_loss=0.954, val_type_loss=0.00099, val_kld_loss=39.90, val_composition_loss=0.0016, val_property_loss=0.159, val_natom_accuracy=0.654, val_lengths_mard=0.0649, val_angles_mae=9.080, val_volumes_mard=0.109, val_type_accuracy=1.000]
# Epoch 34:  62% 20/32 [02:52<01:43,  8.61s/it, loss=12.6, v_num=yorj, train_loss_step=12.20, train_natom_loss_step=0.903, train_lattice_loss_step=0.564, train_coord_loss_step=0.511, train_type_loss_step=0.000635, train_kld_loss_step=45.80, train_composition_loss_step=0.000169, train_loss_epoch=12.60, train_natom_loss_epoch=0.884, train_lattice_loss_epoch=0.560, train_coord_loss_epoch=0.557, train_type_loss_epoch=0.0013, train_kld_loss_epoch=41.20, train_composition_loss_epoch=0.00111, val_loss=9.540, val_natom_loss=0.962, val_lattice_loss=0.621, val_coord_loss=0.954, val_type_loss=0.00099, val_kld_loss=39.90, val_composition_loss=0.0016, val_property_loss=0.159, val_natom_accuracy=0.654, val_lengths_mard=0.0649, val_angles_mae=9.080, val_volumes_mard=0.109, val_type_accuracy=1.000]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 8/8 [00:24<00:00,  3.07s/it]
# Epoch 34: 100% 32/32 [03:50<00:00,  7.21s/it, loss=12.4, v_num=yorj, train_loss_step=12.80, train_natom_loss_step=0.787, train_lattice_loss_step=0.610, train_coord_loss_step=0.542, train_type_loss_step=0.000931, train_kld_loss_step=41.60, train_composition_loss_step=0.000643, train_loss_epoch=12.60, train_natom_loss_epoch=0.884, train_lattice_loss_epoch=0.560, train_coord_loss_epoch=0.557, train_type_loss_epoch=0.0013, train_kld_loss_epoch=41.20, train_composition_loss_epoch=0.00111, val_loss=9.590, val_natom_loss=0.863, val_lattice_loss=0.595, val_coord_loss=0.959, val_type_loss=0.00118, val_kld_loss=40.20, val_composition_loss=0.000747, val_property_loss=0.0994, val_natom_accuracy=0.684, val_lengths_mard=0.0593, val_angles_mae=8.890, val_volumes_mard=0.0864, val_type_accuracy=1.000]
# Epoch 39:  62% 20/32 [02:49<01:41,  8.47s/it, loss=12.1, v_num=yorj, train_loss_step=11.90, train_natom_loss_step=0.754, train_lattice_loss_step=0.565, train_coord_loss_step=0.503, train_type_loss_step=0.00225, train_kld_loss_step=40.30, train_composition_loss_step=0.00051, train_loss_epoch=12.10, train_natom_loss_epoch=0.800, train_lattice_loss_epoch=0.535, train_coord_loss_epoch=0.546, train_type_loss_epoch=0.00138, train_kld_loss_epoch=42.10, train_composition_loss_epoch=0.000698, val_loss=9.590, val_natom_loss=0.863, val_lattice_loss=0.595, val_coord_loss=0.959, val_type_loss=0.00118, val_kld_loss=40.20, val_composition_loss=0.000747, val_property_loss=0.0994, val_natom_accuracy=0.684, val_lengths_mard=0.0593, val_angles_mae=8.890, val_volumes_mard=0.0864, val_type_accuracy=1.000]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 8/8 [00:23<00:00,  2.95s/it]
# Epoch 39: 100% 32/32 [03:45<00:00,  7.05s/it, loss=12.1, v_num=yorj, train_loss_step=12.00, train_natom_loss_step=0.767, train_lattice_loss_step=0.506, train_coord_loss_step=0.561, train_type_loss_step=0.000542, train_kld_loss_step=41.00, train_composition_loss_step=0.00104, train_loss_epoch=12.10, train_natom_loss_epoch=0.800, train_lattice_loss_epoch=0.535, train_coord_loss_epoch=0.546, train_type_loss_epoch=0.00138, train_kld_loss_epoch=42.10, train_composition_loss_epoch=0.000698, val_loss=9.230, val_natom_loss=0.834, val_lattice_loss=0.577, val_coord_loss=0.923, val_type_loss=0.000947, val_kld_loss=41.50, val_composition_loss=0.000634, val_property_loss=0.0921, val_natom_accuracy=0.690, val_lengths_mard=0.0571, val_angles_mae=8.710, val_volumes_mard=0.0775, val_type_accuracy=1.000]
# Epoch 44:  62% 20/32 [02:36<01:33,  7.81s/it, loss=11.7, v_num=yorj, train_loss_step=12.30, train_natom_loss_step=0.828, train_lattice_loss_step=0.562, train_coord_loss_step=0.533, train_type_loss_step=0.0013, train_kld_loss_step=41.40, train_composition_loss_step=0.00219, train_loss_epoch=11.90, train_natom_loss_epoch=0.776, train_lattice_loss_epoch=0.523, train_coord_loss_epoch=0.539, train_type_loss_epoch=0.000393, train_kld_loss_epoch=41.30, train_composition_loss_epoch=0.000595, val_loss=9.230, val_natom_loss=0.834, val_lattice_loss=0.577, val_coord_loss=0.923, val_type_loss=0.000947, val_kld_loss=41.50, val_composition_loss=0.000634, val_property_loss=0.0921, val_natom_accuracy=0.690, val_lengths_mard=0.0571, val_angles_mae=8.710, val_volumes_mard=0.0775, val_type_accuracy=1.000]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 8/8 [00:21<00:00,  2.69s/it]
# Epoch 44: 100% 32/32 [03:26<00:00,  6.45s/it, loss=11.7, v_num=yorj, train_loss_step=11.40, train_natom_loss_step=0.764, train_lattice_loss_step=0.498, train_coord_loss_step=0.518, train_type_loss_step=0.000704, train_kld_loss_step=39.40, train_composition_loss_step=0.0006, train_loss_epoch=11.90, train_natom_loss_epoch=0.776, train_lattice_loss_epoch=0.523, train_coord_loss_epoch=0.539, train_type_loss_epoch=0.000393, train_kld_loss_epoch=41.30, train_composition_loss_epoch=0.000595, val_loss=9.240, val_natom_loss=0.794, val_lattice_loss=0.564, val_coord_loss=0.924, val_type_loss=0.00106, val_kld_loss=39.90, val_composition_loss=0.000808, val_property_loss=0.0736, val_natom_accuracy=0.709, val_lengths_mard=0.055, val_angles_mae=8.690, val_volumes_mard=0.0892, val_type_accuracy=1.000]
# Epoch 49:  62% 20/32 [02:35<01:33,  7.77s/it, loss=11.7, v_num=yorj, train_loss_step=11.40, train_natom_loss_step=0.624, train_lattice_loss_step=0.491, train_coord_loss_step=0.538, train_type_loss_step=0.000577, train_kld_loss_step=43.20, train_composition_loss_step=0.000141, train_loss_epoch=11.60, train_natom_loss_epoch=0.719, train_lattice_loss_epoch=0.503, train_coord_loss_epoch=0.531, train_type_loss_epoch=0.000495, train_kld_loss_epoch=41.70, train_composition_loss_epoch=0.000746, val_loss=9.240, val_natom_loss=0.794, val_lattice_loss=0.564, val_coord_loss=0.924, val_type_loss=0.00106, val_kld_loss=39.90, val_composition_loss=0.000808, val_property_loss=0.0736, val_natom_accuracy=0.709, val_lengths_mard=0.055, val_angles_mae=8.690, val_volumes_mard=0.0892, val_type_accuracy=1.000]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 8/8 [00:21<00:00,  2.63s/it]
# Epoch 49: 100% 32/32 [03:26<00:00,  6.45s/it, loss=11.7, v_num=yorj, train_loss_step=11.70, train_natom_loss_step=0.676, train_lattice_loss_step=0.521, train_coord_loss_step=0.536, train_type_loss_step=0.000783, train_kld_loss_step=39.50, train_composition_loss_step=0.000399, train_loss_epoch=11.60, train_natom_loss_epoch=0.719, train_lattice_loss_epoch=0.503, train_coord_loss_epoch=0.531, train_type_loss_epoch=0.000495, train_kld_loss_epoch=41.70, train_composition_loss_epoch=0.000746, val_loss=9.640, val_natom_loss=0.778, val_lattice_loss=0.579, val_coord_loss=0.964, val_type_loss=0.00116, val_kld_loss=38.30, val_composition_loss=0.000955, val_property_loss=0.072, val_natom_accuracy=0.728, val_lengths_mard=0.0578, val_angles_mae=8.790, val_volumes_mard=0.0855, val_type_accuracy=1.000]
# Epoch 54:  62% 20/32 [02:37<01:34,  7.89s/it, loss=11.1, v_num=yorj, train_loss_step=11.70, train_natom_loss_step=0.670, train_lattice_loss_step=0.493, train_coord_loss_step=0.565, train_type_loss_step=0.000381, train_kld_loss_step=38.60, train_composition_loss_step=0.00022, train_loss_epoch=11.30, train_natom_loss_epoch=0.694, train_lattice_loss_epoch=0.490, train_coord_loss_epoch=0.521, train_type_loss_epoch=0.000808, train_kld_loss_epoch=40.50, train_composition_loss_epoch=0.000367, val_loss=9.640, val_natom_loss=0.778, val_lattice_loss=0.579, val_coord_loss=0.964, val_type_loss=0.00116, val_kld_loss=38.30, val_composition_loss=0.000955, val_property_loss=0.072, val_natom_accuracy=0.728, val_lengths_mard=0.0578, val_angles_mae=8.790, val_volumes_mard=0.0855, val_type_accuracy=1.000]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 8/8 [00:21<00:00,  2.66s/it]
# Epoch 54: 100% 32/32 [03:27<00:00,  6.49s/it, loss=11.4, v_num=yorj, train_loss_step=12.00, train_natom_loss_step=0.649, train_lattice_loss_step=0.482, train_coord_loss_step=0.607, train_type_loss_step=0.000403, train_kld_loss_step=41.80, train_composition_loss_step=8.34e-5, train_loss_epoch=11.30, train_natom_loss_epoch=0.694, train_lattice_loss_epoch=0.490, train_coord_loss_epoch=0.521, train_type_loss_epoch=0.000808, train_kld_loss_epoch=40.50, train_composition_loss_epoch=0.000367, val_loss=9.730, val_natom_loss=0.778, val_lattice_loss=0.566, val_coord_loss=0.973, val_type_loss=0.000328, val_kld_loss=39.30, val_composition_loss=0.000367, val_property_loss=0.0863, val_natom_accuracy=0.712, val_lengths_mard=0.0555, val_angles_mae=8.580, val_volumes_mard=0.0904, val_type_accuracy=1.000]
# Epoch 59:  62% 20/32 [02:35<01:33,  7.78s/it, loss=10.8, v_num=yorj, train_loss_step=11.40, train_natom_loss_step=0.685, train_lattice_loss_step=0.522, train_coord_loss_step=0.509, train_type_loss_step=0.00039, train_kld_loss_step=37.20, train_composition_loss_step=0.000415, train_loss_epoch=10.90, train_natom_loss_epoch=0.642, train_lattice_loss_epoch=0.470, train_coord_loss_epoch=0.508, train_type_loss_epoch=0.00102, train_kld_loss_epoch=40.80, train_composition_loss_epoch=0.000496, val_loss=9.730, val_natom_loss=0.778, val_lattice_loss=0.566, val_coord_loss=0.973, val_type_loss=0.000328, val_kld_loss=39.30, val_composition_loss=0.000367, val_property_loss=0.0863, val_natom_accuracy=0.712, val_lengths_mard=0.0555, val_angles_mae=8.580, val_volumes_mard=0.0904, val_type_accuracy=1.000]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 8/8 [00:20<00:00,  2.59s/it]
# Epoch 59: 100% 32/32 [03:26<00:00,  6.46s/it, loss=10.7, v_num=yorj, train_loss_step=11.00, train_natom_loss_step=0.754, train_lattice_loss_step=0.487, train_coord_loss_step=0.493, train_type_loss_step=0.000461, train_kld_loss_step=38.60, train_composition_loss_step=0.000209, train_loss_epoch=10.90, train_natom_loss_epoch=0.642, train_lattice_loss_epoch=0.470, train_coord_loss_epoch=0.508, train_type_loss_epoch=0.00102, train_kld_loss_epoch=40.80, train_composition_loss_epoch=0.000496, val_loss=9.410, val_natom_loss=0.709, val_lattice_loss=0.555, val_coord_loss=0.941, val_type_loss=0.000241, val_kld_loss=37.00, val_composition_loss=0.000728, val_property_loss=0.057, val_natom_accuracy=0.736, val_lengths_mard=0.0524, val_angles_mae=8.440, val_volumes_mard=0.0761, val_type_accuracy=1.000]
# Epoch 64:  62% 20/32 [02:32<01:31,  7.62s/it, loss=10.8, v_num=yorj, train_loss_step=11.20, train_natom_loss_step=0.615, train_lattice_loss_step=0.495, train_coord_loss_step=0.523, train_type_loss_step=0.00069, train_kld_loss_step=38.10, train_composition_loss_step=0.000156, train_loss_epoch=10.90, train_natom_loss_epoch=0.625, train_lattice_loss_epoch=0.458, train_coord_loss_epoch=0.522, train_type_loss_epoch=0.000682, train_kld_loss_epoch=39.10, train_composition_loss_epoch=0.000328, val_loss=9.410, val_natom_loss=0.709, val_lattice_loss=0.555, val_coord_loss=0.941, val_type_loss=0.000241, val_kld_loss=37.00, val_composition_loss=0.000728, val_property_loss=0.057, val_natom_accuracy=0.736, val_lengths_mard=0.0524, val_angles_mae=8.440, val_volumes_mard=0.0761, val_type_accuracy=1.000]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 8/8 [00:21<00:00,  2.67s/it]
# ...
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 8/8 [00:21<00:00,  2.75s/it]
# Epoch 234: 100% 32/32 [03:34<00:00,  6.72s/it, loss=8.76, v_num=yorj, train_loss_step=8.010, train_natom_loss_step=0.166, train_lattice_loss_step=0.312, train_coord_loss_step=0.446, train_type_loss_step=0.000187, train_kld_loss_step=25.00, train_composition_loss_step=9.86e-6, train_loss_epoch=8.860, train_natom_loss_epoch=0.237, train_lattice_loss_epoch=0.363, train_coord_loss_epoch=0.472, train_type_loss_epoch=0.000178, train_kld_loss_epoch=25.40, train_composition_loss_epoch=6.94e-6, val_loss=8.900, val_natom_loss=1.220, val_lattice_loss=0.537, val_coord_loss=0.890, val_type_loss=0.000267, val_kld_loss=24.00, val_composition_loss=7.18e-6, val_property_loss=0.0327, val_natom_accuracy=0.789, val_lengths_mard=0.0428, val_angles_mae=7.880, val_volumes_mard=0.0569, val_type_accuracy=1.000]
# Epoch 239:  62% 20/32 [02:37<01:34,  7.89s/it, loss=8.91, v_num=yorj, train_loss_step=8.320, train_natom_loss_step=0.289, train_lattice_loss_step=0.345, train_coord_loss_step=0.431, train_type_loss_step=6.59e-5, train_kld_loss_step=24.40, train_composition_loss_step=8.38e-6, train_loss_epoch=8.850, train_natom_loss_epoch=0.248, train_lattice_loss_epoch=0.366, train_coord_loss_epoch=0.466, train_type_loss_epoch=7.81e-5, train_kld_loss_epoch=25.00, train_composition_loss_epoch=7.11e-6, val_loss=8.900, val_natom_loss=1.220, val_lattice_loss=0.537, val_coord_loss=0.890, val_type_loss=0.000267, val_kld_loss=24.00, val_composition_loss=7.18e-6, val_property_loss=0.0327, val_natom_accuracy=0.789, val_lengths_mard=0.0428, val_angles_mae=7.880, val_volumes_mard=0.0569, val_type_accuracy=1.000]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 8/8 [00:20<00:00,  2.62s/it]
# Epoch 239: 100% 32/32 [03:28<00:00,  6.50s/it, loss=8.86, v_num=yorj, train_loss_step=7.450, train_natom_loss_step=0.207, train_lattice_loss_step=0.282, train_coord_loss_step=0.413, train_type_loss_step=3.59e-5, train_kld_loss_step=27.40, train_composition_loss_step=5.6e-6, train_loss_epoch=8.850, train_natom_loss_epoch=0.248, train_lattice_loss_epoch=0.366, train_coord_loss_epoch=0.466, train_type_loss_epoch=7.81e-5, train_kld_loss_epoch=25.00, train_composition_loss_epoch=7.11e-6, val_loss=9.040, val_natom_loss=1.280, val_lattice_loss=0.533, val_coord_loss=0.904, val_type_loss=4.78e-5, val_kld_loss=25.50, val_composition_loss=6.15e-6, val_property_loss=0.0282, val_natom_accuracy=0.783, val_lengths_mard=0.0447, val_angles_mae=7.820, val_volumes_mard=0.0583, val_type_accuracy=1.000]
# Epoch 244:  62% 20/32 [02:55<01:45,  8.78s/it, loss=8.88, v_num=yorj, train_loss_step=8.600, train_natom_loss_step=0.236, train_lattice_loss_step=0.385, train_coord_loss_step=0.423, train_type_loss_step=8.17e-5, train_kld_loss_step=24.80, train_composition_loss_step=6.35e-6, train_loss_epoch=8.790, train_natom_loss_epoch=0.247, train_lattice_loss_epoch=0.362, train_coord_loss_epoch=0.464, train_type_loss_epoch=0.000154, train_kld_loss_epoch=25.20, train_composition_loss_epoch=6.01e-6, val_loss=9.040, val_natom_loss=1.280, val_lattice_loss=0.533, val_coord_loss=0.904, val_type_loss=4.78e-5, val_kld_loss=25.50, val_composition_loss=6.15e-6, val_property_loss=0.0282, val_natom_accuracy=0.783, val_lengths_mard=0.0447, val_angles_mae=7.820, val_volumes_mard=0.0583, val_type_accuracy=1.000]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 8/8 [00:30<00:00,  3.85s/it]
# Epoch 244: 100% 32/32 [04:04<00:00,  7.65s/it, loss=8.84, v_num=yorj, train_loss_step=8.580, train_natom_loss_step=0.194, train_lattice_loss_step=0.342, train_coord_loss_step=0.468, train_type_loss_step=4.56e-5, train_kld_loss_step=25.50, train_composition_loss_step=4.87e-6, train_loss_epoch=8.790, train_natom_loss_epoch=0.247, train_lattice_loss_epoch=0.362, train_coord_loss_epoch=0.464, train_type_loss_epoch=0.000154, train_kld_loss_epoch=25.20, train_composition_loss_epoch=6.01e-6, val_loss=8.870, val_natom_loss=1.270, val_lattice_loss=0.534, val_coord_loss=0.887, val_type_loss=0.000131, val_kld_loss=24.20, val_composition_loss=6.7e-6, val_property_loss=0.0347, val_natom_accuracy=0.787, val_lengths_mard=0.0436, val_angles_mae=7.870, val_volumes_mard=0.052, val_type_accuracy=1.000]
# Epoch 249:  62% 20/32 [03:23<02:01, 10.16s/it, loss=8.86, v_num=yorj, train_loss_step=8.560, train_natom_loss_step=0.216, train_lattice_loss_step=0.332, train_coord_loss_step=0.474, train_type_loss_step=4.56e-5, train_kld_loss_step=25.70, train_composition_loss_step=4.37e-6, train_loss_epoch=8.770, train_natom_loss_epoch=0.240, train_lattice_loss_epoch=0.358, train_coord_loss_epoch=0.467, train_type_loss_epoch=4.18e-5, train_kld_loss_epoch=24.90, train_composition_loss_epoch=5.94e-6, val_loss=8.870, val_natom_loss=1.270, val_lattice_loss=0.534, val_coord_loss=0.887, val_type_loss=0.000131, val_kld_loss=24.20, val_composition_loss=6.7e-6, val_property_loss=0.0347, val_natom_accuracy=0.787, val_lengths_mard=0.0436, val_angles_mae=7.870, val_volumes_mard=0.052, val_type_accuracy=1.000]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 8/8 [00:27<00:00,  3.40s/it]
# Epoch 249: 100% 32/32 [04:23<00:00,  8.24s/it, loss=8.9, v_num=yorj, train_loss_step=8.750, train_natom_loss_step=0.218, train_lattice_loss_step=0.340, train_coord_loss_step=0.483, train_type_loss_step=7.49e-5, train_kld_loss_step=26.20, train_composition_loss_step=6.66e-6, train_loss_epoch=8.770, train_natom_loss_epoch=0.240, train_lattice_loss_epoch=0.358, train_coord_loss_epoch=0.467, train_type_loss_epoch=4.18e-5, train_kld_loss_epoch=24.90, train_composition_loss_epoch=5.94e-6, val_loss=8.890, val_natom_loss=1.250, val_lattice_loss=0.526, val_coord_loss=0.889, val_type_loss=0.000201, val_kld_loss=24.70, val_composition_loss=6.55e-6, val_property_loss=0.0357, val_natom_accuracy=0.789, val_lengths_mard=0.0425, val_angles_mae=7.760, val_volumes_mard=0.0683, val_type_accuracy=1.000]
# Epoch 254:  62% 20/32 [02:54<01:44,  8.70s/it, loss=8.87, v_num=yorj, train_loss_step=8.640, train_natom_loss_step=0.230, train_lattice_loss_step=0.346, train_coord_loss_step=0.468, train_type_loss_step=3.14e-5, train_kld_loss_step=25.10, train_composition_loss_step=3.83e-6, train_loss_epoch=8.790, train_natom_loss_epoch=0.240, train_lattice_loss_epoch=0.360, train_coord_loss_epoch=0.468, train_type_loss_epoch=0.000148, train_kld_loss_epoch=24.40, train_composition_loss_epoch=5.62e-6, val_loss=8.890, val_natom_loss=1.250, val_lattice_loss=0.526, val_coord_loss=0.889, val_type_loss=0.000201, val_kld_loss=24.70, val_composition_loss=6.55e-6, val_property_loss=0.0357, val_natom_accuracy=0.789, val_lengths_mard=0.0425, val_angles_mae=7.760, val_volumes_mard=0.0683, val_type_accuracy=1.000]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 8/8 [00:21<00:00,  2.69s/it]
# Epoch 254: 100% 32/32 [03:48<00:00,  7.14s/it, loss=8.88, v_num=yorj, train_loss_step=9.230, train_natom_loss_step=0.285, train_lattice_loss_step=0.366, train_coord_loss_step=0.500, train_type_loss_step=3.04e-5, train_kld_loss_step=24.30, train_composition_loss_step=4.94e-6, train_loss_epoch=8.790, train_natom_loss_epoch=0.240, train_lattice_loss_epoch=0.360, train_coord_loss_epoch=0.468, train_type_loss_epoch=0.000148, train_kld_loss_epoch=24.40, train_composition_loss_epoch=5.62e-6, val_loss=9.610, val_natom_loss=1.250, val_lattice_loss=0.538, val_coord_loss=0.961, val_type_loss=8.87e-5, val_kld_loss=23.30, val_composition_loss=6.18e-6, val_property_loss=0.0344, val_natom_accuracy=0.787, val_lengths_mard=0.0445, val_angles_mae=7.930, val_volumes_mard=0.0641, val_type_accuracy=1.000]
# Epoch 259:  62% 20/32 [02:47<01:40,  8.36s/it, loss=8.81, v_num=yorj, train_loss_step=8.990, train_natom_loss_step=0.235, train_lattice_loss_step=0.350, train_coord_loss_step=0.497, train_type_loss_step=9.27e-5, train_kld_loss_step=25.70, train_composition_loss_step=4.72e-6, train_loss_epoch=8.890, train_natom_loss_epoch=0.243, train_lattice_loss_epoch=0.358, train_coord_loss_epoch=0.479, train_type_loss_epoch=9.48e-5, train_kld_loss_epoch=25.20, train_composition_loss_epoch=4.99e-6, val_loss=9.610, val_natom_loss=1.250, val_lattice_loss=0.538, val_coord_loss=0.961, val_type_loss=8.87e-5, val_kld_loss=23.30, val_composition_loss=6.18e-6, val_property_loss=0.0344, val_natom_accuracy=0.787, val_lengths_mard=0.0445, val_angles_mae=7.930, val_volumes_mard=0.0641, val_type_accuracy=1.000]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 8/8 [00:22<00:00,  2.86s/it]
# Epoch 259: 100% 32/32 [03:41<00:00,  6.93s/it, loss=8.79, v_num=yorj, train_loss_step=8.170, train_natom_loss_step=0.205, train_lattice_loss_step=0.327, train_coord_loss_step=0.443, train_type_loss_step=6.62e-5, train_kld_loss_step=24.90, train_composition_loss_step=5.85e-6, train_loss_epoch=8.890, train_natom_loss_epoch=0.243, train_lattice_loss_epoch=0.358, train_coord_loss_epoch=0.479, train_type_loss_epoch=9.48e-5, train_kld_loss_epoch=25.20, train_composition_loss_epoch=4.99e-6, val_loss=9.350, val_natom_loss=1.240, val_lattice_loss=0.519, val_coord_loss=0.935, val_type_loss=0.000216, val_kld_loss=24.20, val_composition_loss=5.64e-6, val_property_loss=0.0296, val_natom_accuracy=0.778, val_lengths_mard=0.0415, val_angles_mae=7.750, val_volumes_mard=0.0543, val_type_accuracy=1.000]
# Epoch 264:  62% 20/32 [02:55<01:45,  8.77s/it, loss=8.8, v_num=yorj, train_loss_step=9.020, train_natom_loss_step=0.188, train_lattice_loss_step=0.349, train_coord_loss_step=0.506, train_type_loss_step=3.17e-5, train_kld_loss_step=25.30, train_composition_loss_step=4.15e-6, train_loss_epoch=8.830, train_natom_loss_epoch=0.227, train_lattice_loss_epoch=0.358, train_coord_loss_epoch=0.475, train_type_loss_epoch=0.00016, train_kld_loss_epoch=24.50, train_composition_loss_epoch=4.68e-6, val_loss=9.350, val_natom_loss=1.240, val_lattice_loss=0.519, val_coord_loss=0.935, val_type_loss=0.000216, val_kld_loss=24.20, val_composition_loss=5.64e-6, val_property_loss=0.0296, val_natom_accuracy=0.778, val_lengths_mard=0.0415, val_angles_mae=7.750, val_volumes_mard=0.0543, val_type_accuracy=1.000]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 8/8 [00:23<00:00,  2.98s/it]
# Epoch 264: 100% 32/32 [03:51<00:00,  7.22s/it, loss=8.78, v_num=yorj, train_loss_step=9.190, train_natom_loss_step=0.198, train_lattice_loss_step=0.355, train_coord_loss_step=0.516, train_type_loss_step=3.51e-5, train_kld_loss_step=25.50, train_composition_loss_step=3.21e-6, train_loss_epoch=8.830, train_natom_loss_epoch=0.227, train_lattice_loss_epoch=0.358, train_coord_loss_epoch=0.475, train_type_loss_epoch=0.00016, train_kld_loss_epoch=24.50, train_composition_loss_epoch=4.68e-6, val_loss=9.040, val_natom_loss=1.270, val_lattice_loss=0.527, val_coord_loss=0.904, val_type_loss=0.000141, val_kld_loss=23.90, val_composition_loss=4.58e-6, val_property_loss=0.0382, val_natom_accuracy=0.789, val_lengths_mard=0.0416, val_angles_mae=7.770, val_volumes_mard=0.0596, val_type_accuracy=1.000]
# Epoch 269:  62% 20/32 [02:36<01:34,  7.84s/it, loss=8.85, v_num=yorj, train_loss_step=8.910, train_natom_loss_step=0.235, train_lattice_loss_step=0.381, train_coord_loss_step=0.459, train_type_loss_step=7.01e-5, train_kld_loss_step=24.70, train_composition_loss_step=4.51e-6, train_loss_epoch=8.810, train_natom_loss_epoch=0.232, train_lattice_loss_epoch=0.356, train_coord_loss_epoch=0.475, train_type_loss_epoch=6.78e-5, train_kld_loss_epoch=24.80, train_composition_loss_epoch=3.94e-6, val_loss=9.040, val_natom_loss=1.270, val_lattice_loss=0.527, val_coord_loss=0.904, val_type_loss=0.000141, val_kld_loss=23.90, val_composition_loss=4.58e-6, val_property_loss=0.0382, val_natom_accuracy=0.789, val_lengths_mard=0.0416, val_angles_mae=7.770, val_volumes_mard=0.0596, val_type_accuracy=1.000]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 8/8 [00:21<00:00,  2.73s/it]
# Epoch 269: 100% 32/32 [03:29<00:00,  6.55s/it, loss=8.78, v_num=yorj, train_loss_step=8.940, train_natom_loss_step=0.254, train_lattice_loss_step=0.372, train_coord_loss_step=0.470, train_type_loss_step=0.000123, train_kld_loss_step=25.20, train_composition_loss_step=4.82e-6, train_loss_epoch=8.810, train_natom_loss_epoch=0.232, train_lattice_loss_epoch=0.356, train_coord_loss_epoch=0.475, train_type_loss_epoch=6.78e-5, train_kld_loss_epoch=24.80, train_composition_loss_epoch=3.94e-6, val_loss=9.280, val_natom_loss=1.180, val_lattice_loss=0.524, val_coord_loss=0.928, val_type_loss=0.00111, val_kld_loss=23.50, val_composition_loss=4.63e-6, val_property_loss=0.0281, val_natom_accuracy=0.792, val_lengths_mard=0.0412, val_angles_mae=7.780, val_volumes_mard=0.0533, val_type_accuracy=1.000]
# Epoch 274:  62% 20/32 [02:53<01:43,  8.65s/it, loss=8.76, v_num=yorj, train_loss_step=9.040, train_natom_loss_step=0.269, train_lattice_loss_step=0.369, train_coord_loss_step=0.481, train_type_loss_step=2.36e-5, train_kld_loss_step=24.10, train_composition_loss_step=5.27e-6, train_loss_epoch=8.600, train_natom_loss_epoch=0.224, train_lattice_loss_epoch=0.354, train_coord_loss_epoch=0.456, train_type_loss_epoch=5.54e-5, train_kld_loss_epoch=24.60, train_composition_loss_epoch=3.81e-6, val_loss=9.280, val_natom_loss=1.180, val_lattice_loss=0.524, val_coord_loss=0.928, val_type_loss=0.00111, val_kld_loss=23.50, val_composition_loss=4.63e-6, val_property_loss=0.0281, val_natom_accuracy=0.792, val_lengths_mard=0.0412, val_angles_mae=7.780, val_volumes_mard=0.0533, val_type_accuracy=1.000]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/8 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 8/8 [00:25<00:00,  3.24s/it]
# Epoch 274: 100% 32/32 [03:51<00:00,  7.23s/it, loss=8.83, v_num=yorj, train_loss_step=8.530, train_natom_loss_step=0.256, train_lattice_loss_step=0.353, train_coord_loss_step=0.447, train_type_loss_step=4.19e-5, train_kld_loss_step=24.90, train_composition_loss_step=3.19e-6, train_loss_epoch=8.600, train_natom_loss_epoch=0.224, train_lattice_loss_epoch=0.354, train_coord_loss_epoch=0.456, train_type_loss_epoch=5.54e-5, train_kld_loss_epoch=24.60, train_composition_loss_epoch=3.81e-6, val_loss=8.940, val_natom_loss=1.270, val_lattice_loss=0.531, val_coord_loss=0.894, val_type_loss=0.00011, val_kld_loss=23.10, val_composition_loss=4.29e-6, val_property_loss=0.0358, val_natom_accuracy=0.783, val_lengths_mard=0.0411, val_angles_mae=7.890, val_volumes_mard=0.0579, val_type_accuracy=1.000]
# Epoch 277:  83% 20/24 [02:57<00:35,  8.90s/it, loss=8.71, v_num=yorj, train_loss_step=8.910, train_natom_loss_step=0.206, train_lattice_loss_step=0.349, train_coord_loss_step=0.495, train_type_loss_step=5.84e-5, train_kld_loss_step=23.30, train_composition_loss_step=3.4e-6, train_loss_epoch=8.830, train_natom_loss_epoch=0.224, train_lattice_loss_epoch=0.359, train_coord_loss_epoch=0.475, train_type_loss_epoch=4.36e-5, train_kld_loss_epoch=24.30, train_composition_loss_epoch=3.77e-6, val_loss=8.940, val_natom_loss=1.270, val_lattice_loss=0.531, val_coord_loss=0.894, val_type_loss=0.00011, val_kld_loss=23.10, val_composition_loss=4.29e-6, val_property_loss=0.0358, val_natom_accuracy=0.783, val_lengths_mard=0.0411, val_angles_mae=7.890, val_volumes_mard=0.0579, val_type_accuracy=1.000]
