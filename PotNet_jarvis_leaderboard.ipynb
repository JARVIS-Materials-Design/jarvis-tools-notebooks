# %% [markdown]
# <a href="https://colab.research.google.com/github/knc6/jarvis-tools-notebooks/blob/master/PotNet_jarvis_leaderboard.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/conda-forge/miniforge/releases/download/23.11.0-0/Mambaforge-23.11.0-0-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:14
# 🔁 Restarting kernel...

# %%
# %%time
# !conda install pytorch torchvision torchaudio pytorch-cuda -c pytorch -c nvidia -y --quiet
# Out:
# Channels:
#  - pytorch
#  - nvidia
#  - conda-forge
# Platform: linux-64
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - pytorch
#     - pytorch-cuda
#     - torchaudio
#     - torchvision
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _openmp_mutex-4.5          |       2_kmp_llvm           6 KB  conda-forge
#     blas-2.116                 |              mkl          13 KB  conda-forge
#     blas-devel-3.9.0           |   16_linux64_mkl          12 KB  conda-forge
#     ca-certificates-2024.7.4   |       hbcca054_0         151 KB  conda-forge
#     certifi-2024.7.4           |     pyhd8ed1ab_0         156 KB  conda-forge
#     cuda-cudart-12.4.127       |                0         198 KB  nvidia
#     cuda-cupti-12.4.127        |                0        16.4 MB  nvidia
# ...

# %%
# %%time
#2.4.0
import os
import torch
os.environ['TORCH'] = torch.__version__
print(torch.__version__)

# !pip install -q torch-scatter -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q torch-sparse -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q git+https://github.com/pyg-team/pytorch_geometric.git
# Out:
# 2.4.0
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.0/108.0 kB 3.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 210.0/210.0 kB 6.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 4.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 MB 12.9 MB/s eta 0:00:00
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.5/290.5 kB 10.1 MB/s eta 0:00:00
# ...
# CPU times: user 15.4 s, sys: 2.05 s, total: 17.4 s
# Wall time: 38min 44s

# %%
if not os.path.exists('/content/AIRS'):
  # !git clone https://github.com/divelab/AIRS.git
os.chdir('/content/AIRS/OpenMat/PotNet')
# Out:
# Cloning into 'AIRS'...
# remote: Enumerating objects: 2633, done.
# remote: Counting objects: 100% (1505/1505), done.
# remote: Compressing objects: 100% (879/879), done.
# remote: Total 2633 (delta 702), reused 1309 (delta 590), pack-reused 1128 (from 1)
# Receiving objects: 100% (2633/2633), 233.41 MiB | 30.91 MiB/s, done.
# Resolving deltas: 100% (1076/1076), done.
# Updating files: 100% (536/536), done.

# %%
# !ls
# Out:
# algorithm.py  data.py	       functions  __init__.py  main.py	README.md    test_algorithm.py
# configs       environment.yml  graph.png  LICENSE      models	summary.pdf  train_prop.py

# %%
os.chdir('/content/AIRS/OpenMat/PotNet/functions')
# !tar xzvf gsl-latest.tar.gz
# Out:
# gsl-2.7.1/
# gsl-2.7.1/Makefile.am
# gsl-2.7.1/configure
# gsl-2.7.1/configure.ac
# gsl-2.7.1/aclocal.m4
# gsl-2.7.1/templates_on.h
# gsl-2.7.1/templates_off.h
# gsl-2.7.1/build.h
# gsl-2.7.1/gsl_math.h
# gsl-2.7.1/gsl_pow_int.h
# gsl-2.7.1/gsl_nan.h
# gsl-2.7.1/gsl_machine.h
# gsl-2.7.1/gsl_mode.h
# gsl-2.7.1/gsl_precision.h
# gsl-2.7.1/gsl_types.h
# gsl-2.7.1/gsl_version.h
# gsl-2.7.1/gsl_minmax.h
# gsl-2.7.1/gsl_inline.h
# gsl-2.7.1/Makefile.in
# gsl-2.7.1/config.h.in
# gsl-2.7.1/gsl.spec.in
# gsl-2.7.1/gsl_version.h.in
# gsl-2.7.1/AUTHORS
# gsl-2.7.1/COPYING
# gsl-2.7.1/ChangeLog
# gsl-2.7.1/INSTALL
# gsl-2.7.1/NEWS
# gsl-2.7.1/README
# gsl-2.7.1/THANKS
# gsl-2.7.1/TODO
# gsl-2.7.1/compile
# gsl-2.7.1/config.guess
# gsl-2.7.1/config.sub
# gsl-2.7.1/depcomp
# gsl-2.7.1/install-sh
# gsl-2.7.1/ltmain.sh
# gsl-2.7.1/mdate-sh
# gsl-2.7.1/missing
# gsl-2.7.1/mkinstalldirs
# gsl-2.7.1/test-driver
# gsl-2.7.1/version.c
# gsl-2.7.1/gsl-histogram.c
# gsl-2.7.1/gsl-randist.c
# ...

# %%
os.chdir("/content/AIRS/OpenMat/PotNet/functions/gsl-2.7.1")

# %%
# !./configure --prefix='/content'
# !make
# !make install
# Out:
# checking for a BSD-compatible install... /usr/bin/install -c
# checking whether build environment is sane... yes
# checking for a race-free mkdir -p... /usr/bin/mkdir -p
# checking for gawk... no
# checking for mawk... mawk
# checking whether make sets $(MAKE)... yes
# checking whether make supports nested variables... yes
# checking whether to enable maintainer-specific portions of Makefiles... no
# checking for a sed that does not truncate output... /usr/bin/sed
# checking whether make sets $(MAKE)... (cached) yes
# checking build system type... x86_64-unknown-linux-gnu
# checking host system type... x86_64-unknown-linux-gnu
# checking for gcc... gcc
# checking whether the C compiler works... yes
# checking for C compiler default output file name... a.out
# checking for suffix of executables...
# checking whether we are cross compiling... no
# checking for suffix of object files... o
# checking whether the compiler supports GNU C... yes
# checking whether gcc accepts -g... yes
# ...

# %%
# !export LD_LIBRARY_PATH=$LD_LIBRARY_PATH:/content/lib/

# %%
os.chdir("/content/AIRS/OpenMat/PotNet")

# %%
# !python setup.py build_ext --inplace
# Out:
# python: can't open file '/content/AIRS/OpenMat/PotNet/setup.py': [Errno 2] No such file or directory

# %%
# !python test_algorithm.py
# Out:
# Traceback (most recent call last):
#   File "/content/AIRS/OpenMat/PotNet/test_algorithm.py", line 1, in <module>
#     from algorithm import *
#   File "/content/AIRS/OpenMat/PotNet/algorithm.py", line 5, in <module>
#     from functions.series import cython_upper_bessel, cython_upper_bessel_k, cython_gsl_sf_gamma, cython_gsl_sf_gamma_inc
# ModuleNotFoundError: No module named 'functions.series'
